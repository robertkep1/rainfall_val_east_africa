# %%
import pandas as pd
import numpy as np

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
obs_df = pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_station_data_daily_v2.csv')
obs_df = obs_df.set_index('Unnamed: 0')

cmorph_df = pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/merge_model/evaluation/prediction_model_1.csv')
cmorph_df = cmorph_df.set_index('Unnamed: 0')

obs_df_null = obs_df.isnull()
cmorph_df[obs_df_null] = np.nan

cmorph_df_null = cmorph_df.isnull()
obs_df[cmorph_df_null] = np.nan

# print(chirps_df)
cmorph_df.to_csv("/content/gdrive/MyDrive/rainfall-forecast/merge_model/evaluation/final_model1.csv")
obs_df.to_csv('/content/gdrive/MyDrive/rainfall-forecast/merge_model/evaluation/final_station_data_model1.csv')

# %%
obs_df = pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_station_data_daily_v2.csv')
obs_df = obs_df.set_index('Unnamed: 0')

cmorph_df = pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/merge_model/evaluation/prediction_model_2.csv')
cmorph_df = cmorph_df.set_index('Unnamed: 0')

obs_df_null = obs_df.isnull()
cmorph_df[obs_df_null] = np.nan

cmorph_df_null = cmorph_df.isnull()
obs_df[cmorph_df_null] = np.nan

# print(chirps_df)
cmorph_df.to_csv("/content/gdrive/MyDrive/rainfall-forecast/merge_model/evaluation/final_model2.csv")
obs_df.to_csv('/content/gdrive/MyDrive/rainfall-forecast/merge_model/evaluation/final_station_data_model2.csv')
