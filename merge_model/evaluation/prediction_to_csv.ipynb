# %%
# Package Declaration
# !pip install rasterio
# !pip install netCDF4
# !pip install geopandas

# from osgeo import gdal
# from osgeo import ogr
# from osgeo import osr
# from osgeo import gdal_array
# from osgeo import gdalconst

import numpy as np
import pandas as pd
# import geopandas as gpd
import xarray as xr
import netCDF4 as nc

# import rasterio

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Requirement already satisfied: netCDF4 in /usr/local/lib/python3.7/dist-packages (1.5.6)
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.7/dist-packages (from netCDF4) (1.19.5)
# Requirement already satisfied: cftime in /usr/local/lib/python3.7/dist-packages (from netCDF4) (1.5.0)
# Mounted at /content/gdrive

# %%
station_metadata_df = pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/station_data/Final results_csv/station_list_final_v2.csv')
station_data_df = pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_station_data_daily_v2.csv')

# station_data_df = station_data_df[['Unnamed: 0']]
station_data_df = station_data_df.set_index('Unnamed: 0')

prediction_model_1_df = pd.DataFrame().reindex_like(station_data_df)
prediction_model_1_df = prediction_model_1_df.drop(index = (pd.date_range('2016-01-01','2020-01-03').strftime('%Y-%m-%d')))

fname = "/content/gdrive/MyDrive/rainfall-forecast/merge_model/ConvLSTM/convlstm_prediction.nc"

date_range = pd.date_range('2020-01-04', '2020-12-31')
date_fname_list = date_range.strftime('%Y%m%d').to_list()
date_row_list = date_range.strftime('%Y-%m-%d').to_list()

ds = xr.open_dataset(fname)

for station in range(len(station_metadata_df.index)):
  print(station)

  station_id = station_metadata_df['STNID'].iloc[station]
  station_lat = station_metadata_df['LATITUDE'].iloc[station]
  station_lon = station_metadata_df['LONGITUDE'].iloc[station]

  clip = ds.sel(lat = station_lat, lon = station_lon, method='nearest')
  #clip = clip.sel(time=slice("2020-01-04", "2020-12-31"))
  
  val = clip.predict_precip_1.values
  # print(val)

  prediction_model_1_df[station_id] = val

print(tamsat_data_df)

prediction_model_1_df = prediction_model_1_df.round(1)
prediction_model_1_df.to_csv("/content/gdrive/MyDrive/rainfall-forecast/merge_model/evaluation/prediction_model_1.csv")

# %%
station_metadata_df = pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/station_data/Final results_csv/station_list_final_v2.csv')
station_data_df = pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_station_data_daily_v2.csv')

# station_data_df = station_data_df[['Unnamed: 0']]
station_data_df = station_data_df.set_index('Unnamed: 0')

prediction_model_2_df = pd.DataFrame().reindex_like(station_data_df)
prediction_model_2_df = prediction_model_2_df.drop(index = (pd.date_range('2016-01-01','2020-01-03').strftime('%Y-%m-%d')))

fname = "/content/gdrive/MyDrive/rainfall-forecast/merge_model/ConvLSTM/convlstm_prediction.nc"

date_range = pd.date_range('2020-01-04', '2020-12-31')
date_fname_list = date_range.strftime('%Y%m%d').to_list()
date_row_list = date_range.strftime('%Y-%m-%d').to_list()

ds = xr.open_dataset(fname)

for station in range(len(station_metadata_df.index)):
  print(station)

  station_id = station_metadata_df['STNID'].iloc[station]
  station_lat = station_metadata_df['LATITUDE'].iloc[station]
  station_lon = station_metadata_df['LONGITUDE'].iloc[station]

  clip = ds.sel(lat = station_lat, lon = station_lon, method='nearest')
  #clip = clip.sel(time=slice("2020-01-04", "2020-12-31"))
  
  val = clip.predict_precip_2.values
  # print(val)

  prediction_model_2_df[station_id] = val

print(tamsat_data_df)

prediction_model_2_df = prediction_model_2_df.round(1)
prediction_model_2_df.to_csv("/content/gdrive/MyDrive/rainfall-forecast/merge_model/evaluation/prediction_model_2.csv")

# %%
pred
