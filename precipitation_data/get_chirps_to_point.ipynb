# %%
# Read station metadata file

# Loop for each station

  # Get station lat & lon

  # Loop for each nc file

    # Read nc

    # Get data dimension (row, column)

    # Get lat & lon range

    # Create lat & lon array

    # Find nearest station lat & lon from lat & lon array

    # Extract data

  # Save to csv

# %%
pip install netcdf4
# Out:
# ...
#      |████████████████████████████████| 4.7MB 8.5MB/s
# ...
#      |████████████████████████████████| 317kB 45.3MB/s
# ...

# %%
import pandas as pd
import itertools
from google.colab import drive
import numpy as np
import netCDF4 as nc

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
stations= pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/station_data/observations/BDI/643900-99999.csv')

# %%
print(stations)
# Out:
#       Unnamed: 0         STNID            NAME  ...   EA   ES    RH
# 0              1  643900-99999  BUJUMBURA INTL  ...  NaN  3.3   NaN
# 1              2  643900-99999  BUJUMBURA INTL  ...  1.4  3.2  45.0
# 2              3  643900-99999  BUJUMBURA INTL  ...  1.6  3.6  45.5
# 3              4  643900-99999  BUJUMBURA INTL  ...  1.9  3.3  59.4
# 4              5  643900-99999  BUJUMBURA INTL  ...  2.0  3.0  68.3
# ...          ...           ...             ...  ...  ...  ...   ...
# 7015        7016  643900-99999  BUJUMBURA INTL  ...  2.2  3.3  68.2
# 7016        7017  643900-99999  BUJUMBURA INTL  ...  2.2  3.2  70.3
# 7017        7018  643900-99999  BUJUMBURA INTL  ...  2.4  3.6  65.2
# 7018        7019  643900-99999  BUJUMBURA INTL  ...  2.3  2.6  89.0
# 7019        7020  643900-99999  BUJUMBURA INTL  ...  2.1  3.5  60.4
#
# [7020 rows x 48 columns]

# %%
# read station meta data and create list

df_station = pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/station_data/station_list.csv')

n_station = len(df_station.index)

station_lat = []
station_lon = []

for station in range(0,n_station):
  station_lat.append(df_station['LATITUDE'].iloc[station])
  station_lon.append(df_station['LONGITUDE'].iloc[station])

# print(station_lon)

station_coord = pd.DataFrame(columns = [station_lat, station_lon])

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
#create list of nc file

dataset = nc.Dataset('/content/gdrive/MyDrive/rainfall-forecast/precipitation_data/CHIRPS/daily/05/chirps-v2.0.1981.days_p05.nc')
precip = dataset.variables['precip']
print(dataset)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     Conventions: CF-1.6
#     title: CHIRPS Version 2.0
#     history: created by Climate Hazards Group
#     version: Version 2.0
#     date_created: 2015-11-20
#     creator_name: Pete Peterson
#     creator_email: pete@geog.ucsb.edu
#     institution: Climate Hazards Group.  University of California at Santa Barbara
#     documentation: http://pubs.usgs.gov/ds/832/
#     reference: Funk, C.C., Peterson, P.J., Landsfeld, M.F., Pedreros, D.H., Verdin, J.P., Rowland, J.D., Romero, B.E., Husak, G.J., Michaelsen, J.C., and Verdin, A.P., 2014, A quasi-global precipitation time series for drought monitoring: U.S. Geological Survey Data Series 832, 4 p., http://dx.doi.org/110.3133/ds832.
#     comments:  time variable denotes the first day of the given day.
# ...

# %%
#loop for each nc file


for year in range (2016,2021):
  fname= "CHIRPS"+str(year)+"/content/gdrive/MyDrive/rainfall-forecast/precipitation_data/CHIRPS/daily/05/chirps-v2.0."+str(year)+".days_p05.nc"
  print(fname)
# Out:
# CHIRPS2016/content/gdrive/MyDrive/rainfall-forecast/precipitation_data/CHIRPS/daily/05/chirps-v2.0.2016.days_p05.nc
# CHIRPS2017/content/gdrive/MyDrive/rainfall-forecast/precipitation_data/CHIRPS/daily/05/chirps-v2.0.2017.days_p05.nc
# CHIRPS2018/content/gdrive/MyDrive/rainfall-forecast/precipitation_data/CHIRPS/daily/05/chirps-v2.0.2018.days_p05.nc
# CHIRPS2019/content/gdrive/MyDrive/rainfall-forecast/precipitation_data/CHIRPS/daily/05/chirps-v2.0.2019.days_p05.nc
# CHIRPS2020/content/gdrive/MyDrive/rainfall-forecast/precipitation_data/CHIRPS/daily/05/chirps-v2.0.2020.days_p05.nc

# %%
#get data dimension
print(precip)
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 precip(time, latitude, longitude)
#     units: mm/day
#     standard_name: convective precipitation rate
#     long_name: Climate Hazards group InfraRed Precipitation with Stations
#     time_step: day
#     missing_value: -9999.0
#     _FillValue: -9999.0
#     geostatial_lat_min: -50.0
#     geostatial_lat_max: 50.0
#     geostatial_lon_min: -180.0
#     geostatial_lon_max: 180.0
# unlimited dimensions:
# current shape = (365, 2000, 7200)
# filling on

# %%
print(longitude)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b57401d2241e> in <module>()
# ----> 1 print(longitude)
#
# NameError: name 'longitude' is not defined
