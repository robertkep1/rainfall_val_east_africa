# %%
import pandas as pd
import numpy as np

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy import stats

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df_obs_daily = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_station_data_daily_v2_cmorph.csv")
df_obs_daily = df_obs_daily.set_index('Unnamed: 0')

df_obs_monthly = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_station_data_monthly_v2_cmorph.csv")
df_obs_monthly = df_obs_monthly.set_index('Unnamed: 0')

df_sat_daily = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_cmorph_data_daily_v2.csv")
df_sat_daily = df_sat_daily.set_index('Unnamed: 0')

df_sat_monthly = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_cmorph_data_monthly_v2.csv")
df_sat_monthly = df_sat_monthly.set_index('Unnamed: 0')

df_obs_metadata = pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/station_data/Final results_csv/station_list_final_v2.csv')
df_obs_metadata = df_obs_metadata.set_index('STNID')

# %%
index = pd.Index(['Lat', 'Lon', 'ObsNumber', 'RMSE', 'MAE', 'Bias', 'PearsonR', 'SpearmanR', 'R2', 'POD', 'POFD', 'FAR', 'FB'], name="rows")
column = df_obs_daily.columns

daily_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)
monthly_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)

for station, station_id in enumerate(df_obs_daily.columns):
  print(station)
  # if station == 102:
  #   continue
  
  obs_daily = df_obs_daily[station_id]  
  sat_daily = df_sat_daily[station_id]

  obs_daily = obs_daily.to_numpy(copy=True)
  sat_daily = sat_daily.to_numpy(copy=True)

  obs_daily = obs_daily[~np.isnan(obs_daily)]
  sat_daily = sat_daily[~np.isnan(sat_daily)]

  n_of_sample = len(obs_daily)

  rmse = mean_squared_error(obs_daily, sat_daily, squared=False)
  mae = mean_absolute_error(obs_daily, sat_daily)
  pearsonr = stats.pearsonr(obs_daily, sat_daily)
  spearmanr = stats.spearmanr(obs_daily, sat_daily)
  rsq = r2_score(obs_daily, sat_daily)

  # correlation_matrix = np.corrcoef(obs_daily, sat_daily)
  # correlation_xy = correlation_matrix[0,1]
  # rsq = correlation_xy**2

  bias = sat_daily - obs_daily
  bias = bias.mean()

  obs_daily_bool = obs_daily.copy()
  sat_daily_bool = sat_daily.copy()

  obs_daily_bool[obs_daily_bool < 1] = 0
  obs_daily_bool[obs_daily_bool >= 1] = 1

  sat_daily_bool[sat_daily_bool < 1] = 0
  sat_daily_bool[sat_daily_bool >= 1] = 1

  category = np.empty([n_of_sample])

  for i in range(n_of_sample):
    if obs_daily_bool[i] == 1 and sat_daily_bool[i] == 1:
      category[i] = 1
    elif obs_daily_bool[i] == 1 and sat_daily_bool[i] == 0:
      category[i] = 2
    elif obs_daily_bool[i] == 0 and sat_daily_bool[i] == 1:
      category[i] = 3
    elif obs_daily_bool[i] == 0 and sat_daily_bool[i] == 0:
      category[i] = 4

  hit = np.count_nonzero(category == 1)
  miss = np.count_nonzero(category == 2)
  false_alarm = np.count_nonzero(category == 3)
  correct_negative = np.count_nonzero(category == 4)

  pod = hit/(hit + miss)
  pofd = miss/(miss+correct_negative)
  far = false_alarm/(hit + false_alarm)
  freq_bias = (hit+false_alarm)/(hit+miss)

  daily_metrics_df[station_id].loc['Lat'] = df_obs_metadata['LATITUDE'].loc[station_id]
  daily_metrics_df[station_id].loc['Lon'] = df_obs_metadata['LONGITUDE'].loc[station_id]
  daily_metrics_df[station_id].loc['RMSE'] = round(rmse,2)
  daily_metrics_df[station_id].loc['MAE'] = round(mae,2)
  daily_metrics_df[station_id].loc['Bias'] = round(bias,2)
  daily_metrics_df[station_id].loc['PearsonR'] = round(pearsonr[0],2)
  daily_metrics_df[station_id].loc['SpearmanR'] = round(spearmanr[0],2)
  daily_metrics_df[station_id].loc['R2'] = round(rsq,2)
  daily_metrics_df[station_id].loc['Probability of Detection'] = round(pod,2)
  daily_metrics_df[station_id].loc['Probability of False Detection'] = round(pofd,2)
  daily_metrics_df[station_id].loc['False Alarm Rate'] = round(far,2)
  daily_metrics_df[station_id].loc['Frequency Bias'] = round(freq_bias,2)
                                  
  print(station_id)
  print("Number of Observation: ", n_of_sample)
  print("RMSE: ", str(round(rmse,1)))
  print("MAE: ", str(round(mae,1)))
  print("Bias: ", str(round(bias,1)))
  print("Rsquare: ", str(round(rsq,1)))
  print("Probability of Detection: ", pod)
  print("Probability of False Detection: ", pofd)
  print("False Alarm Rate: ", far)
  print("Frequency Bias: ", freq_bias)


  # # print(obs_daily)
  # # print(sat_daily)

  # # print(obs_daily_bool)
  # # print(sat_daily_bool)
  print(" ")

  # obs_monthly = df_obs_monthly[station_id]
  # sat_monthly = df_sat_monthly[station_id]

  # obs_monthly = obs_monthly.to_numpy()
  # sat_monthly = sat_monthly.to_numpy()

  # print(station, station_id)

daily_metrics_df = daily_metrics_df.T
daily_metrics_df.to_csv('/content/gdrive/MyDrive/rainfall-forecast/verification_validation/metrics/metrics_cmorph_daily.csv')

# %%
index = pd.Index(['Lat', 'Lon', 'ObsN', 'RMSE', 'MAE', 'Bias', 'PearsonR', 'SpearmanR', 'R2', 'POD', 'POFD', 'FAR', 'FB'], name="rows")
column = df_obs_monthly.columns

monthly_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)
monthly_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)

for station, station_id in enumerate(df_obs_monthly.columns):
  print(station)
  # if station == 102:
  #   continue
  
  obs_monthly = df_obs_monthly[station_id]  
  sat_monthly = df_sat_monthly[station_id]

  obs_monthly = obs_monthly.to_numpy(copy=True)
  sat_monthly = sat_monthly.to_numpy(copy=True)

  obs_monthly = obs_monthly[~np.isnan(obs_monthly)]
  sat_monthly = sat_monthly[~np.isnan(sat_monthly)]

  n_of_sample = len(obs_monthly)

  rmse = mean_squared_error(obs_monthly, sat_monthly, squared=False)
  mae = mean_absolute_error(obs_monthly, sat_monthly)
  pearsonr = stats.pearsonr(obs_monthly, sat_monthly)
  spearmanr = stats.spearmanr(obs_monthly, sat_monthly)
  rsq = r2_score(obs_monthly, sat_monthly)

  # correlation_matrix = np.corrcoef(obs_monthly, sat_monthly)
  # correlation_xy = correlation_matrix[0,1]
  # rsq = correlation_xy**2

  bias = sat_monthly - obs_monthly
  bias = bias.mean()

  obs_monthly_bool = obs_monthly.copy()
  sat_monthly_bool = sat_monthly.copy()

  obs_monthly_bool[obs_monthly_bool < 10] = 0
  obs_monthly_bool[obs_monthly_bool >= 10] = 1

  sat_monthly_bool[sat_monthly_bool < 10] = 0
  sat_monthly_bool[sat_monthly_bool >= 10] = 1

  category = np.empty([n_of_sample])

  for i in range(n_of_sample):
    if obs_monthly_bool[i] == 1 and sat_monthly_bool[i] == 1:
      category[i] = 1
    elif obs_monthly_bool[i] == 1 and sat_monthly_bool[i] == 0:
      category[i] = 2
    elif obs_monthly_bool[i] == 0 and sat_monthly_bool[i] == 1:
      category[i] = 3
    elif obs_monthly_bool[i] == 0 and sat_monthly_bool[i] == 0:
      category[i] = 4

  hit = np.count_nonzero(category == 1)
  miss = np.count_nonzero(category == 2)
  false_alarm = np.count_nonzero(category == 3)
  correct_negative = np.count_nonzero(category == 4)

  if hit + miss == 0:
    pod = np.nan
  else:
    pod = hit/(hit + miss)

  if miss + correct_negative == 0:
    pofd = np.nan
  else:
    pofd = miss/(miss + correct_negative)

  if hit + false_alarm == 0:
    far = np.nan
  else:
    far = false_alarm/(hit + false_alarm)

  if hit + miss == 0:
    freq_bias = np.nan
  else:
    freq_bias = (hit+false_alarm)/(hit+miss)

  monthly_metrics_df[station_id].loc['Lat'] = df_obs_metadata['LATITUDE'].loc[station_id]
  monthly_metrics_df[station_id].loc['Lon'] = df_obs_metadata['LONGITUDE'].loc[station_id]
  monthly_metrics_df[station_id].loc['ObsN'] = n_of_sample
  monthly_metrics_df[station_id].loc['RMSE'] = round(rmse,2)
  monthly_metrics_df[station_id].loc['MAE'] = round(mae,2)
  monthly_metrics_df[station_id].loc['Bias'] = round(bias,2)
  monthly_metrics_df[station_id].loc['PearsonR'] = round(pearsonr[0],2)
  monthly_metrics_df[station_id].loc['SpearmanR'] = round(spearmanr[0],2)
  monthly_metrics_df[station_id].loc['R2'] = round(rsq,2)
  monthly_metrics_df[station_id].loc['POD'] = round(pod,2)
  monthly_metrics_df[station_id].loc['POFD'] = round(pofd,2)
  monthly_metrics_df[station_id].loc['FAR'] = round(far,2)
  monthly_metrics_df[station_id].loc['FB'] = round(freq_bias,2)
                                  
  print(station_id)
  print("Number of Observation: ", n_of_sample)
  print("RMSE: ", str(round(rmse,1)))
  print("MAE: ", str(round(mae,1)))
  print("Bias: ", str(round(bias,1)))
  print("Rsquare: ", str(round(rsq,1)))
  print("Probability of Detection: ", pod)
  print("Probability of False Detection: ", pofd)
  print("False Alarm Rate: ", far)
  print("Frequency Bias: ", freq_bias)


  # # print(obs_monthly)
  # # print(sat_monthly)

  # # print(obs_monthly_bool)
  # # print(sat_monthly_bool)
  print(" ")

  # obs_monthly = df_obs_monthly[station_id]
  # sat_monthly = df_sat_monthly[station_id]

  # obs_monthly = obs_monthly.to_numpy()
  # sat_monthly = sat_monthly.to_numpy()

  # print(station, station_id)

monthly_metrics_df = monthly_metrics_df.T
monthly_metrics_df.to_csv('/content/gdrive/MyDrive/rainfall-forecast/verification_validation/metrics/metrics_cmorph_monthly.csv')
# Out:
# 0
# TA00073
# Number of Observation:  58
# RMSE:  184.6
# MAE:  121.9
# Bias:  110.4
# Rsquare:  -6.8
# Probability of Detection:  0.9555555555555556
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.17307692307692307
# Frequency Bias:  1.1555555555555554
#
# 1
# TA00024
# Number of Observation:  58
# RMSE:  147.3
# MAE:  85.1
# Bias:  63.2
# Rsquare:  -1.5
# Probability of Detection:  0.8863636363636364
# Probability of False Detection:  0.35714285714285715
# False Alarm Rate:  0.11363636363636363
# Frequency Bias:  1.0
#
# 2
# TA00026
# Number of Observation:  58
# RMSE:  185.0
# MAE:  130.9
# Bias:  85.0
# Rsquare:  -1.8
# Probability of Detection:  0.9411764705882353
# Probability of False Detection:  0.75
# False Alarm Rate:  0.1111111111111111
# Frequency Bias:  1.0588235294117647
#
# 3
# TA00070
# Number of Observation:  58
# RMSE:  212.4
# MAE:  116.4
# Bias:  80.4
# Rsquare:  -1.6
# Probability of Detection:  0.8108108108108109
# Probability of False Detection:  0.3684210526315789
# False Alarm Rate:  0.23076923076923078
# Frequency Bias:  1.054054054054054
#
# 4
# TA00071
# Number of Observation:  58
# RMSE:  234.4
# MAE:  141.2
# Bias:  86.2
# Rsquare:  -1.7
# Probability of Detection:  0.6666666666666666
# Probability of False Detection:  0.6
# False Alarm Rate:  0.3684210526315789
# Frequency Bias:  1.0555555555555556
#
# 5
# 638940-99999
# Number of Observation:  58
# RMSE:  236.1
# MAE:  130.7
# Bias:  83.9
# Rsquare:  -1.9
# Probability of Detection:  0.7954545454545454
# Probability of False Detection:  0.6428571428571429
# False Alarm Rate:  0.20454545454545456
# Frequency Bias:  1.0
#
# 6
# 637290-99999
# Number of Observation:  58
# RMSE:  285.3
# MAE:  212.1
# Bias:  197.8
# Rsquare:  -3.3
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.05263157894736842
# Frequency Bias:  1.0555555555555556
#
# 7
# 638700-99999
# Number of Observation:  58
# RMSE:  261.4
# MAE:  193.5
# Bias:  168.6
# Rsquare:  -1.1
# Probability of Detection:  1.0
# Probability of False Detection:  nan
# False Alarm Rate:  0.1206896551724138
# Frequency Bias:  1.1372549019607843
#
# 8
# 639710-99999
# Number of Observation:  58
# RMSE:  219.8
# MAE:  111.2
# Bias:  82.6
# Rsquare:  -2.2
# Probability of Detection:  0.8205128205128205
# Probability of False Detection:  0.5
# False Alarm Rate:  0.2727272727272727
# Frequency Bias:  1.1282051282051282
#
# 9
# 638620-99999
# Number of Observation:  58
# RMSE:  101.7
# MAE:  53.3
# Bias:  46.1
# Rsquare:  0.0
# Probability of Detection:  0.96
# Probability of False Detection:  0.03571428571428571
# False Alarm Rate:  0.2
# Frequency Bias:  1.2
#
# 10
# 638870-99999
# Number of Observation:  58
# RMSE:  127.3
# MAE:  62.8
# Bias:  55.5
# Rsquare:  -1.2
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.15151515151515152
# Frequency Bias:  1.1785714285714286
#
# 11
# 637560-99999
# Number of Observation:  58
# RMSE:  112.3
# MAE:  74.8
# Bias:  38.0
# Rsquare:  -0.5
# Probability of Detection:  0.8571428571428571
# Probability of False Detection:  0.5
# False Alarm Rate:  0.045454545454545456
# Frequency Bias:  0.8979591836734694
#
# 12
# 637910-99999
# Number of Observation:  58
# RMSE:  75.9
# MAE:  44.5
# Bias:  11.2
# Rsquare:  -0.0
# Probability of Detection:  0.75
# Probability of False Detection:  0.2962962962962963
# False Alarm Rate:  0.22580645161290322
# Frequency Bias:  0.96875
#
# 13
# 638810-99999
# Number of Observation:  58
# RMSE:  115.2
# MAE:  72.0
# Bias:  48.0
# Rsquare:  -0.4
# Probability of Detection:  0.9117647058823529
# Probability of False Detection:  0.1875
# False Alarm Rate:  0.2619047619047619
# Frequency Bias:  1.2352941176470589
#
# 14
# 638010-99999
# Number of Observation:  58
# RMSE:  192.4
# MAE:  117.6
# Bias:  103.7
# Rsquare:  -4.4
# Probability of Detection:  0.9512195121951219
# Probability of False Detection:  0.10526315789473684
# False Alarm Rate:  0.0
# Frequency Bias:  0.9512195121951219
#
# 15
# 639620-99999
# Number of Observation:  58
# RMSE:  157.6
# MAE:  83.3
# Bias:  68.8
# Rsquare:  -0.6
# Probability of Detection:  0.8484848484848485
# Probability of False Detection:  0.1724137931034483
# False Alarm Rate:  0.034482758620689655
# Frequency Bias:  0.8787878787878788
#
# 16
# 638660-99999
# Number of Observation:  58
# RMSE:  193.4
# MAE:  114.5
# Bias:  99.0
# Rsquare:  -3.0
# Probability of Detection:  0.9069767441860465
# Probability of False Detection:  0.26666666666666666
# False Alarm Rate:  0.09302325581395349
# Frequency Bias:  1.0
#
# 17
# 638320-99999
# Number of Observation:  58
# RMSE:  175.0
# MAE:  102.8
# Bias:  -37.3
# Rsquare:  0.3
# Probability of Detection:  0.8205128205128205
# Probability of False Detection:  0.2692307692307692
# False Alarm Rate:  0.0
# Frequency Bias:  0.8205128205128205
#
# 18
# 637330-99999
# Number of Observation:  58
# RMSE:  166.8
# MAE:  108.7
# Bias:  95.7
# Rsquare:  -4.8
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.038461538461538464
# Frequency Bias:  1.04
#
# 19
# TA00057
# Number of Observation:  56
# RMSE:  175.1
# MAE:  109.1
# Bias:  90.5
# Rsquare:  -5.0
# Probability of Detection:  0.9705882352941176
# Probability of False Detection:  0.16666666666666666
# False Alarm Rate:  0.34
# Frequency Bias:  1.4705882352941178
#
# 20
# TA00020
# Number of Observation:  57
# RMSE:  121.5
# MAE:  60.6
# Bias:  55.1
# Rsquare:  -3.0
# Probability of Detection:  0.96
# Probability of False Detection:  0.047619047619047616
# False Alarm Rate:  0.3333333333333333
# Frequency Bias:  1.44
#
# 21
# 638200-99999
# Number of Observation:  58
# RMSE:  205.6
# MAE:  111.9
# Bias:  82.6
# Rsquare:  -1.8
# Probability of Detection:  0.7555555555555555
# Probability of False Detection:  0.5789473684210527
# False Alarm Rate:  0.1282051282051282
# Frequency Bias:  0.8666666666666667
#
# 22
# 637170-99999
# Number of Observation:  58
# RMSE:  165.2
# MAE:  88.8
# Bias:  49.4
# Rsquare:  -1.9
# Probability of Detection:  0.8113207547169812
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.0
# Frequency Bias:  0.8113207547169812
#
# 23
# TA00019
# Number of Observation:  56
# RMSE:  241.2
# MAE:  180.7
# Bias:  179.4
# Rsquare:  -29.1
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.07272727272727272
# Frequency Bias:  1.0784313725490196
#
# 24
# 637930-99999
# Number of Observation:  58
# RMSE:  95.0
# MAE:  56.2
# Bias:  37.3
# Rsquare:  -1.0
# Probability of Detection:  0.8484848484848485
# Probability of False Detection:  0.20833333333333334
# False Alarm Rate:  0.17647058823529413
# Frequency Bias:  1.0303030303030303
#
# 25
# TA00076
# Number of Observation:  55
# RMSE:  264.4
# MAE:  216.8
# Bias:  216.8
# Rsquare:  -13.1
# Probability of Detection:  1.0
# Probability of False Detection:  nan
# False Alarm Rate:  0.3090909090909091
# Frequency Bias:  1.4473684210526316
#
# 26
# TA00069
# Number of Observation:  57
# RMSE:  162.6
# MAE:  98.7
# Bias:  61.8
# Rsquare:  -0.7
# Probability of Detection:  0.7368421052631579
# Probability of False Detection:  0.5263157894736842
# False Alarm Rate:  0.2631578947368421
# Frequency Bias:  1.0
#
# 27
# TA00074
# Number of Observation:  57
# RMSE:  207.7
# MAE:  112.3
# Bias:  47.6
# Rsquare:  -1.0
# Probability of Detection:  0.7674418604651163
# Probability of False Detection:  0.625
# False Alarm Rate:  0.1951219512195122
# Frequency Bias:  0.9534883720930233
#
# 28
# 636610-99999
# Number of Observation:  58
# RMSE:  141.0
# MAE:  104.8
# Bias:  97.3
# Rsquare:  -2.0
# Probability of Detection:  0.9615384615384616
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.038461538461538464
# Frequency Bias:  1.0
#
# 29
# 637200-99999
# Number of Observation:  58
# RMSE:  163.2
# MAE:  89.1
# Bias:  58.9
# Rsquare:  -0.7
# Probability of Detection:  0.6938775510204082
# Probability of False Detection:  0.6818181818181818
# False Alarm Rate:  0.05555555555555555
# Frequency Bias:  0.7346938775510204
#
# 30
# 643870-99999
# Number of Observation:  58
# RMSE:  127.8
# MAE:  68.0
# Bias:  12.0
# Rsquare:  -0.7
# Probability of Detection:  0.9
# Probability of False Detection:  0.45454545454545453
# False Alarm Rate:  0.0425531914893617
# Frequency Bias:  0.94
#
# 31
# 636950-99999
# Number of Observation:  58
# RMSE:  142.8
# MAE:  72.6
# Bias:  27.1
# Rsquare:  -0.0
# Probability of Detection:  0.8837209302325582
# Probability of False Detection:  0.3125
# False Alarm Rate:  0.09523809523809523
# Frequency Bias:  0.9767441860465116
#
# 32
# 637400-99999
# Number of Observation:  58
# RMSE:  105.0
# MAE:  67.7
# Bias:  55.4
# Rsquare:  -1.4
# Probability of Detection:  0.9047619047619048
# Probability of False Detection:  0.4444444444444444
# False Alarm Rate:  0.22448979591836735
# Frequency Bias:  1.1666666666666667
#
# 33
# TA00056
# Number of Observation:  54
# RMSE:  161.3
# MAE:  90.4
# Bias:  64.8
# Rsquare:  -0.5
# Probability of Detection:  0.7209302325581395
# Probability of False Detection:  0.5714285714285714
# False Alarm Rate:  0.06060606060606061
# Frequency Bias:  0.7674418604651163
#
# 34
# 637140-99999
# Number of Observation:  58
# RMSE:  158.6
# MAE:  108.2
# Bias:  103.7
# Rsquare:  -4.5
# Probability of Detection:  0.96
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.12727272727272726
# Frequency Bias:  1.1
#
# 35
# TA00025
# Number of Observation:  51
# RMSE:  130.4
# MAE:  79.9
# Bias:  48.4
# Rsquare:  -1.1
# Probability of Detection:  0.8461538461538461
# Probability of False Detection:  0.75
# False Alarm Rate:  0.23255813953488372
# Frequency Bias:  1.1025641025641026
#
# 36
# 643800-99999
# Number of Observation:  57
# RMSE:  122.6
# MAE:  87.6
# Bias:  78.1
# Rsquare:  -2.8
# Probability of Detection:  0.9411764705882353
# Probability of False Detection:  0.5
# False Alarm Rate:  0.058823529411764705
# Frequency Bias:  1.0
#
# 37
# 643810-99999
# Number of Observation:  57
# RMSE:  117.8
# MAE:  77.9
# Bias:  40.3
# Rsquare:  -1.1
# Probability of Detection:  0.9615384615384616
# Probability of False Detection:  0.4
# False Alarm Rate:  0.038461538461538464
# Frequency Bias:  1.0
#
# 38
# TA00033
# Number of Observation:  49
# RMSE:  222.8
# MAE:  143.4
# Bias:  136.9
# Rsquare:  -5.8
# Probability of Detection:  0.9523809523809523
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.13043478260869565
# Frequency Bias:  1.0952380952380953
#
# 39
# TA00072
# Number of Observation:  54
# RMSE:  273.0
# MAE:  137.7
# Bias:  112.4
# Rsquare:  -5.0
# Probability of Detection:  0.78125
# Probability of False Detection:  0.35
# False Alarm Rate:  0.2647058823529412
# Frequency Bias:  1.0625
#
# 40
# 636120-99999
# Number of Observation:  58
# RMSE:  66.7
# MAE:  36.4
# Bias:  28.1
# Rsquare:  -3.3
# Probability of Detection:  0.8
# Probability of False Detection:  0.16129032258064516
# False Alarm Rate:  0.25925925925925924
# Frequency Bias:  1.08
#
# 41
# TA00066
# Number of Observation:  51
# RMSE:  113.4
# MAE:  62.0
# Bias:  39.3
# Rsquare:  -0.4
# Probability of Detection:  0.8421052631578947
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.23809523809523808
# Frequency Bias:  1.105263157894737
#
# 42
# 637990-99999
# Number of Observation:  58
# RMSE:  207.8
# MAE:  80.2
# Bias:  78.2
# Rsquare:  -9.3
# Probability of Detection:  0.9473684210526315
# Probability of False Detection:  0.03333333333333333
# False Alarm Rate:  0.35714285714285715
# Frequency Bias:  1.4736842105263157
#
# 43
# 637420-99999
# Number of Observation:  58
# RMSE:  85.9
# MAE:  53.6
# Bias:  45.8
# Rsquare:  0.0
# Probability of Detection:  0.9473684210526315
# Probability of False Detection:  0.05263157894736842
# False Alarm Rate:  0.5384615384615384
# Frequency Bias:  2.0526315789473686
#
# 44
# TA00023
# Number of Observation:  47
# RMSE:  134.5
# MAE:  67.8
# Bias:  55.8
# Rsquare:  -3.3
# Probability of Detection:  0.7727272727272727
# Probability of False Detection:  0.17857142857142858
# False Alarm Rate:  0.10526315789473684
# Frequency Bias:  0.8636363636363636
#
# 45
# TA00075
# Number of Observation:  48
# RMSE:  124.8
# MAE:  81.4
# Bias:  70.2
# Rsquare:  -5.0
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.19047619047619047
# Frequency Bias:  1.2352941176470589
#
# 46
# TA00031
# Number of Observation:  49
# RMSE:  256.5
# MAE:  193.6
# Bias:  193.6
# Rsquare:  -12.4
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.08333333333333333
# Frequency Bias:  1.0909090909090908
#
# 47
# TA00021
# Number of Observation:  50
# RMSE:  243.4
# MAE:  149.7
# Bias:  144.4
# Rsquare:  -8.8
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.18181818181818182
# Frequency Bias:  1.2222222222222223
#
# 48
# TA00108
# Number of Observation:  45
# RMSE:  297.7
# MAE:  131.5
# Bias:  115.7
# Rsquare:  -32.3
# Probability of Detection:  0.8636363636363636
# Probability of False Detection:  0.14285714285714285
# False Alarm Rate:  0.20833333333333334
# Frequency Bias:  1.0909090909090908
#
# 49
# TA00029
# Number of Observation:  44
# RMSE:  170.1
# MAE:  122.3
# Bias:  107.3
# Rsquare:  -7.1
# Probability of Detection:  0.92
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.43902439024390244
# Frequency Bias:  1.64
#
# 50
# TA00130
# Number of Observation:  44
# RMSE:  152.4
# MAE:  83.1
# Bias:  62.7
# Rsquare:  -4.8
# Probability of Detection:  0.7272727272727273
# Probability of False Detection:  0.5625
# False Alarm Rate:  0.14285714285714285
# Frequency Bias:  0.8484848484848485
#
# 51
# 636860-99999
# Number of Observation:  47
# RMSE:  205.3
# MAE:  146.0
# Bias:  142.9
# Rsquare:  -4.8
# Probability of Detection:  0.9772727272727273
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.022727272727272728
# Frequency Bias:  1.0
#
# 52
# TA00133
# Number of Observation:  44
# RMSE:  107.6
# MAE:  63.1
# Bias:  26.1
# Rsquare:  -0.5
# Probability of Detection:  0.75
# Probability of False Detection:  0.6428571428571429
# False Alarm Rate:  0.1
# Frequency Bias:  0.8333333333333334
#
# 53
# TA00155
# Number of Observation:  43
# RMSE:  82.6
# MAE:  45.3
# Bias:  28.1
# Rsquare:  -0.0
# Probability of Detection:  0.8076923076923077
# Probability of False Detection:  0.2631578947368421
# False Alarm Rate:  0.125
# Frequency Bias:  0.9230769230769231
#
# 54
# TA00157
# Number of Observation:  43
# RMSE:  87.3
# MAE:  48.9
# Bias:  41.1
# Rsquare:  -0.0
# Probability of Detection:  0.9565217391304348
# Probability of False Detection:  0.05263157894736842
# False Alarm Rate:  0.08333333333333333
# Frequency Bias:  1.0434782608695652
#
# 55
# TA00140
# Number of Observation:  44
# RMSE:  150.7
# MAE:  106.6
# Bias:  93.8
# Rsquare:  -1.2
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.06976744186046512
# Frequency Bias:  1.075
#
# 56
# 643830-99999
# Number of Observation:  57
# RMSE:  81.4
# MAE:  56.7
# Bias:  31.7
# Rsquare:  -0.5
# Probability of Detection:  0.88
# Probability of False Detection:  0.5454545454545454
# False Alarm Rate:  0.043478260869565216
# Frequency Bias:  0.92
#
# 57
# TA00054
# Number of Observation:  45
# RMSE:  167.9
# MAE:  115.9
# Bias:  101.6
# Rsquare:  -3.8
# Probability of Detection:  0.9318181818181818
# Probability of False Detection:  1.0
# False Alarm Rate:  0.023809523809523808
# Frequency Bias:  0.9545454545454546
#
# 58
# 637050-99999
# Number of Observation:  58
# RMSE:  110.2
# MAE:  67.8
# Bias:  45.9
# Rsquare:  -1.4
# Probability of Detection:  0.8723404255319149
# Probability of False Detection:  0.5454545454545454
# False Alarm Rate:  0.1276595744680851
# Frequency Bias:  1.0
#
# 59
# 643900-99999
# Number of Observation:  58
# RMSE:  108.6
# MAE:  78.9
# Bias:  55.7
# Rsquare:  -0.7
# Probability of Detection:  0.9230769230769231
# Probability of False Detection:  0.375
# False Alarm Rate:  0.28
# Frequency Bias:  1.2820512820512822
#
# 60
# TA00134
# Number of Observation:  44
# RMSE:  142.4
# MAE:  82.6
# Bias:  71.7
# Rsquare:  -4.2
# Probability of Detection:  0.8484848484848485
# Probability of False Detection:  0.8333333333333334
# False Alarm Rate:  0.2631578947368421
# Frequency Bias:  1.1515151515151516
#
# 61
# TA00131
# Number of Observation:  43
# RMSE:  163.9
# MAE:  96.1
# Bias:  50.6
# Rsquare:  -0.8
# Probability of Detection:  0.7692307692307693
# Probability of False Detection:  0.6923076923076923
# False Alarm Rate:  0.0
# Frequency Bias:  0.7692307692307693
#
# 62
# TA00129
# Number of Observation:  43
# RMSE:  125.2
# MAE:  69.0
# Bias:  30.4
# Rsquare:  -1.4
# Probability of Detection:  0.8709677419354839
# Probability of False Detection:  0.3076923076923077
# False Alarm Rate:  0.1
# Frequency Bias:  0.967741935483871
#
# 63
# can-git-gr1.umva
# Number of Observation:  21
# RMSE:  119.6
# MAE:  84.5
# Bias:  66.7
# Rsquare:  -1.1
# Probability of Detection:  0.9
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.0
# Frequency Bias:  0.9
#
# 64
# cub-nta-gr1.umva
# Number of Observation:  22
# RMSE:  101.9
# MAE:  67.8
# Bias:  61.4
# Rsquare:  -1.4
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.05263157894736842
# Frequency Bias:  1.0555555555555556
#
# 65
# gas-mbu-gr3.umva
# Number of Observation:  22
# RMSE:  105.5
# MAE:  75.0
# Bias:  61.5
# Rsquare:  -1.4
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.10526315789473684
# Frequency Bias:  1.1176470588235294
#
# 66
# gat-gat-gr3.umva
# Number of Observation:  22
# RMSE:  83.2
# MAE:  57.8
# Bias:  47.8
# Rsquare:  -0.3
# Probability of Detection:  0.9444444444444444
# Probability of False Detection:  0.25
# False Alarm Rate:  0.05555555555555555
# Frequency Bias:  1.0
#
# 67
# git-git-gr1.umva
# Number of Observation:  21
# RMSE:  113.3
# MAE:  80.7
# Bias:  68.6
# Rsquare:  -1.5
# Probability of Detection:  0.9
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.0
# Frequency Bias:  0.9
#
# 68
# git-kuw-gr1.umva
# Number of Observation:  22
# RMSE:  85.4
# MAE:  58.8
# Bias:  25.1
# Rsquare:  0.1
# Probability of Detection:  0.9523809523809523
# Probability of False Detection:  0.5
# False Alarm Rate:  0.0
# Frequency Bias:  0.9523809523809523
#
# 69
# git-muh-gr1.umva
# Number of Observation:  22
# RMSE:  86.1
# MAE:  59.9
# Bias:  25.0
# Rsquare:  0.1
# Probability of Detection:  0.9047619047619048
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.0
# Frequency Bias:  0.9047619047619048
#
# 70
# kaj-kaj-gr1.umva
# Number of Observation:  22
# RMSE:  102.4
# MAE:  68.6
# Bias:  61.4
# Rsquare:  -1.1
# Probability of Detection:  0.9411764705882353
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.15789473684210525
# Frequency Bias:  1.1176470588235294
#
# 71
# kan-mak-gr1.umva
# Number of Observation:  22
# RMSE:  118.4
# MAE:  81.1
# Bias:  73.7
# Rsquare:  -1.6
# Probability of Detection:  0.9047619047619048
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.0
# Frequency Bias:  0.9047619047619048
#
# 72
# kar-karu-gr2.umva
# Number of Observation:  22
# RMSE:  104.4
# MAE:  68.5
# Bias:  52.4
# Rsquare:  -0.5
# Probability of Detection:  0.8888888888888888
# Probability of False Detection:  0.5
# False Alarm Rate:  0.1111111111111111
# Frequency Bias:  1.0
#
# 73
# kav-kir-gr2.umva
# Number of Observation:  21
# RMSE:  119.4
# MAE:  83.0
# Bias:  68.5
# Rsquare:  -1.2
# Probability of Detection:  0.9473684210526315
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.0
# Frequency Bias:  0.9473684210526315
#
# 74
# kav-mun-gr1.umva
# Number of Observation:  22
# RMSE:  118.5
# MAE:  80.6
# Bias:  64.1
# Rsquare:  -1.0
# Probability of Detection:  0.95
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.0
# Frequency Bias:  0.95
#
# 75
# kiv-nam-gr1.umva
# Number of Observation:  22
# RMSE:  113.2
# MAE:  84.2
# Bias:  60.3
# Rsquare:  -1.1
# Probability of Detection:  0.9
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.05263157894736842
# Frequency Bias:  0.95
#
# 76
# maga-mag-gr1.umva
# Number of Observation:  22
# RMSE:  122.2
# MAE:  75.3
# Bias:  58.0
# Rsquare:  -0.8
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.10526315789473684
# Frequency Bias:  1.1176470588235294
#
# 77
# mas-nya-gr1.umva
# Number of Observation:  22
# RMSE:  72.4
# MAE:  46.5
# Bias:  34.9
# Rsquare:  0.5
# Probability of Detection:  0.9473684210526315
# Probability of False Detection:  0.25
# False Alarm Rate:  0.0
# Frequency Bias:  0.9473684210526315
#
# 78
# may-may-gr2.umva
# Number of Observation:  22
# RMSE:  106.6
# MAE:  69.2
# Bias:  60.0
# Rsquare:  -1.1
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.05263157894736842
# Frequency Bias:  1.0555555555555556
#
# 79
# mug-mugo-gr2.umva
# Number of Observation:  21
# RMSE:  90.8
# MAE:  62.9
# Bias:  48.3
# Rsquare:  -0.6
# Probability of Detection:  0.9411764705882353
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.1111111111111111
# Frequency Bias:  1.0588235294117647
#
# 80
# mug-nta-gr3.umva
# Number of Observation:  22
# RMSE:  92.7
# MAE:  67.0
# Bias:  52.0
# Rsquare:  -0.4
# Probability of Detection:  0.9411764705882353
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.15789473684210525
# Frequency Bias:  1.1176470588235294
#
# 81
# mug-rus-gr2.umva
# Number of Observation:  21
# RMSE:  98.3
# MAE:  70.8
# Bias:  56.1
# Rsquare:  -0.5
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.1111111111111111
# Frequency Bias:  1.125
#
# 82
# muhw-muh-gr1.umva
# Number of Observation:  22
# RMSE:  77.4
# MAE:  53.1
# Bias:  35.8
# Rsquare:  0.3
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.05263157894736842
# Frequency Bias:  1.0555555555555556
#
# 83
# mun-mun-gr2.umva
# Number of Observation:  22
# RMSE:  110.7
# MAE:  80.7
# Bias:  68.4
# Rsquare:  -1.8
# Probability of Detection:  0.9
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.05263157894736842
# Frequency Bias:  0.95
#
# 84
# mut-mak-gr2.umva
# Number of Observation:  21
# RMSE:  89.6
# MAE:  60.5
# Bias:  35.2
# Rsquare:  0.2
# Probability of Detection:  0.9473684210526315
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.0
# Frequency Bias:  0.9473684210526315
#
# 85
# ngu-nya-gr3.umva
# Number of Observation:  22
# RMSE:  79.8
# MAE:  56.5
# Bias:  31.9
# Rsquare:  0.3
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.1111111111111111
# Frequency Bias:  1.125
#
# 86
# nyabi-ny-gr1.umva
# Number of Observation:  22
# RMSE:  107.0
# MAE:  77.0
# Bias:  66.4
# Rsquare:  -1.3
# Probability of Detection:  0.9
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.05263157894736842
# Frequency Bias:  0.95
#
# 87
# nya-mun-gr1.umva
# Number of Observation:  22
# RMSE:  104.3
# MAE:  75.1
# Bias:  64.3
# Rsquare:  -1.1
# Probability of Detection:  0.9
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.05263157894736842
# Frequency Bias:  0.95
#
# 88
# nye-nzo-gr1.umva
# Number of Observation:  22
# RMSE:  61.5
# MAE:  45.3
# Bias:  33.9
# Rsquare:  0.6
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.05555555555555555
# Frequency Bias:  1.0588235294117647
#
# 89
# ny-nyagi-gr1.umva
# Number of Observation:  22
# RMSE:  84.9
# MAE:  56.0
# Bias:  31.1
# Rsquare:  0.3
# Probability of Detection:  0.95
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.0
# Frequency Bias:  0.95
#
# 90
# nzi-mas-gr1.umva
# Number of Observation:  22
# RMSE:  122.0
# MAE:  79.9
# Bias:  63.4
# Rsquare:  -0.5
# Probability of Detection:  0.9444444444444444
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.10526315789473684
# Frequency Bias:  1.0555555555555556
#
# 91
# rem-muy-gr1.umva
# Number of Observation:  22
# RMSE:  111.8
# MAE:  76.0
# Bias:  45.4
# Rsquare:  -0.4
# Probability of Detection:  0.9047619047619048
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.0
# Frequency Bias:  0.9047619047619048
#
# 92
# rug-kiv-gr1.umva
# Number of Observation:  22
# RMSE:  104.0
# MAE:  68.4
# Bias:  54.8
# Rsquare:  -1.3
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.10526315789473684
# Frequency Bias:  1.1176470588235294
#
# 93
# rug-rug-gr2.umva
# Number of Observation:  22
# RMSE:  91.4
# MAE:  62.6
# Bias:  50.3
# Rsquare:  -0.6
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.0
# Frequency Bias:  1.0
#
# 94
# ruh-ruh-gr1.umva
# Number of Observation:  22
# RMSE:  122.6
# MAE:  87.9
# Bias:  72.5
# Rsquare:  -1.5
# Probability of Detection:  0.95
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.0
# Frequency Bias:  0.95
#
# 95
# rwa-bug-gr1.umva
# Number of Observation:  21
# RMSE:  110.4
# MAE:  78.8
# Bias:  58.1
# Rsquare:  -0.8
# Probability of Detection:  0.9444444444444444
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.05555555555555555
# Frequency Bias:  1.0
#
# 96
# rwa-tab-gr3.umva
# Number of Observation:  22
# RMSE:  83.7
# MAE:  59.9
# Bias:  38.5
# Rsquare:  0.1
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.0
# Frequency Bias:  1.0
#
# 97
# sha-sha-gr1.umva
# Number of Observation:  22
# RMSE:  100.8
# MAE:  60.8
# Bias:  56.9
# Rsquare:  -0.3
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.0
# Frequency Bias:  1.0
#
# 98
# shi-rur-gr1.umva
# Number of Observation:  22
# RMSE:  107.8
# MAE:  80.0
# Bias:  64.5
# Rsquare:  -0.6
# Probability of Detection:  0.9047619047619048
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.0
# Frequency Bias:  0.9047619047619048
#
# 99
# tab-tab-gr3.umva
# Number of Observation:  22
# RMSE:  79.3
# MAE:  55.9
# Bias:  40.3
# Rsquare:  0.2
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.0
# Frequency Bias:  1.0
#
# 100
# tem-rus-gr5.umva
# Number of Observation:  22
# RMSE:  113.5
# MAE:  75.9
# Bias:  61.8
# Rsquare:  -2.0
# Probability of Detection:  0.8947368421052632
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.10526315789473684
# Frequency Bias:  1.0
#
# 101
# yanz-kig-gr3.umva
# Number of Observation:  22
# RMSE:  90.0
# MAE:  64.2
# Bias:  34.3
# Rsquare:  0.1
# Probability of Detection:  0.9444444444444444
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.10526315789473684
# Frequency Bias:  1.0555555555555556
#
# 102
# muh-gah-gr1.umva
# Number of Observation:  22
# RMSE:  221.3
# MAE:  139.6
# Bias:  59.5
# Rsquare:  -8.1
# Probability of Detection:  0.6
# Probability of False Detection:  0.8
# False Alarm Rate:  0.0
# Frequency Bias:  0.6
