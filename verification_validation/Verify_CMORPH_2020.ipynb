# %%
import pandas as pd
import numpy as np

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy import stats

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
drop_columns = 'TA00075'


df_obs_daily = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_station_data_daily_v2_cmorph.csv")
df_obs_daily = df_obs_daily.set_index('Unnamed: 0')
df_obs_daily = df_obs_daily.loc['2020-01-04':'2020-12-31']
df_obs_daily = df_obs_daily.drop(columns=drop_columns)


df_sat_daily = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_cmorph_data_daily_v2.csv")
df_sat_daily = df_sat_daily.set_index('Unnamed: 0')
df_sat_daily = df_sat_daily.loc['2020-01-04':'2020-12-31']
df_sat_daily = df_sat_daily.drop(columns=drop_columns)

df_obs_metadata = pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/station_data/Final results_csv/station_list_final_v2.csv')
df_obs_metadata = df_obs_metadata.set_index('STNID')

# %%
index = pd.Index(['Lat', 'Lon', 'ObsNumber', 'RMSE', 'MAE', 'Bias', 'PearsonR', 'SpearmanR', 'R2', 'POD', 'POFD', 'FAR', 'FB'], name="rows")
column = df_obs_daily.columns

daily_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)
monthly_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)

for station, station_id in enumerate(df_obs_daily.columns):
  print(station)
  # if station == 102:
  #   continue
  
  obs_daily = df_obs_daily[station_id]  
  sat_daily = df_sat_daily[station_id]

  obs_daily = obs_daily.to_numpy(copy=True)
  sat_daily = sat_daily.to_numpy(copy=True)

  obs_daily = obs_daily[~np.isnan(obs_daily)]
  sat_daily = sat_daily[~np.isnan(sat_daily)]

  n_of_sample = len(obs_daily)

  rmse = mean_squared_error(obs_daily, sat_daily, squared=False)
  mae = mean_absolute_error(obs_daily, sat_daily)
  pearsonr = stats.pearsonr(obs_daily, sat_daily)
  spearmanr = stats.spearmanr(obs_daily, sat_daily)
  rsq = r2_score(obs_daily, sat_daily)

  # correlation_matrix = np.corrcoef(obs_daily, sat_daily)
  # correlation_xy = correlation_matrix[0,1]
  # rsq = correlation_xy**2

  bias = sat_daily - obs_daily
  bias = bias.mean()

  obs_daily_bool = obs_daily.copy()
  sat_daily_bool = sat_daily.copy()

  obs_daily_bool[obs_daily_bool < 1] = 0
  obs_daily_bool[obs_daily_bool >= 1] = 1

  sat_daily_bool[sat_daily_bool < 1] = 0
  sat_daily_bool[sat_daily_bool >= 1] = 1

  category = np.empty([n_of_sample])

  for i in range(n_of_sample):
    if obs_daily_bool[i] == 1 and sat_daily_bool[i] == 1:
      category[i] = 1
    elif obs_daily_bool[i] == 1 and sat_daily_bool[i] == 0:
      category[i] = 2
    elif obs_daily_bool[i] == 0 and sat_daily_bool[i] == 1:
      category[i] = 3
    elif obs_daily_bool[i] == 0 and sat_daily_bool[i] == 0:
      category[i] = 4

  hit = np.count_nonzero(category == 1)
  miss = np.count_nonzero(category == 2)
  false_alarm = np.count_nonzero(category == 3)
  correct_negative = np.count_nonzero(category == 4)

  pod = hit/(hit + miss)
  pofd = miss/(miss+correct_negative)
  far = false_alarm/(hit + false_alarm)
  freq_bias = (hit+false_alarm)/(hit+miss)

  daily_metrics_df[station_id].loc['Lat'] = df_obs_metadata['LATITUDE'].loc[station_id]
  daily_metrics_df[station_id].loc['Lon'] = df_obs_metadata['LONGITUDE'].loc[station_id]
  daily_metrics_df[station_id].loc['RMSE'] = round(rmse,2)
  daily_metrics_df[station_id].loc['MAE'] = round(mae,2)
  daily_metrics_df[station_id].loc['Bias'] = round(bias,2)
  daily_metrics_df[station_id].loc['PearsonR'] = round(pearsonr[0],2)
  daily_metrics_df[station_id].loc['SpearmanR'] = round(spearmanr[0],2)
  daily_metrics_df[station_id].loc['R2'] = round(rsq,2)
  daily_metrics_df[station_id].loc['Probability of Detection'] = round(pod,2)
  daily_metrics_df[station_id].loc['Probability of False Detection'] = round(pofd,2)
  daily_metrics_df[station_id].loc['False Alarm Rate'] = round(far,2)
  daily_metrics_df[station_id].loc['Frequency Bias'] = round(freq_bias,2)
                                  
  print(station_id)
  print("Number of Observation: ", n_of_sample)
  print("RMSE: ", str(round(rmse,1)))
  print("MAE: ", str(round(mae,1)))
  print("Bias: ", str(round(bias,1)))
  print("Rsquare: ", str(round(rsq,1)))
  print("Probability of Detection: ", pod)
  print("Probability of False Detection: ", pofd)
  print("False Alarm Rate: ", far)
  print("Frequency Bias: ", freq_bias)


  # # print(obs_daily)
  # # print(sat_daily)

  # # print(obs_daily_bool)
  # # print(sat_daily_bool)
  print(" ")

  # obs_monthly = df_obs_monthly[station_id]
  # sat_monthly = df_sat_monthly[station_id]

  # obs_monthly = obs_monthly.to_numpy()
  # sat_monthly = sat_monthly.to_numpy()

  # print(station, station_id)

daily_metrics_df = daily_metrics_df.T
daily_metrics_df.to_csv('/content/gdrive/MyDrive/rainfall-forecast/verification_validation/metrics/metrics_cmorph_daily_2020.csv')
# Out:
# 0
# TA00073
# Number of Observation:  302
# RMSE:  16.7
# MAE:  5.2
# Bias:  3.8
# Rsquare:  -11.9
# Probability of Detection:  0.6219512195121951
# Probability of False Detection:  0.14220183486238533
# False Alarm Rate:  0.39285714285714285
# Frequency Bias:  1.024390243902439
#
# 1
# TA00024
# Number of Observation:  302
# RMSE:  20.2
# MAE:  5.7
# Bias:  4.1
# Rsquare:  -10.5
# Probability of Detection:  0.4888888888888889
# Probability of False Detection:  0.19008264462809918
# False Alarm Rate:  0.26666666666666666
# Frequency Bias:  0.6666666666666666
#
# 2
# TA00026
# Number of Observation:  302
# RMSE:  18.4
# MAE:  7.2
# Bias:  5.3
# Rsquare:  -7.7
# Probability of Detection:  0.5747126436781609
# Probability of False Detection:  0.19473684210526315
# False Alarm Rate:  0.5535714285714286
# Frequency Bias:  1.2873563218390804
#
# 3
# TA00070
# Number of Observation:  301
# RMSE:  24.7
# MAE:  7.9
# Bias:  4.8
# Rsquare:  -6.3
# Probability of Detection:  0.422680412371134
# Probability of False Detection:  0.24778761061946902
# False Alarm Rate:  0.4533333333333333
# Frequency Bias:  0.7731958762886598
#
# 4
# TA00071
# Number of Observation:  302
# RMSE:  24.6
# MAE:  7.7
# Bias:  7.2
# Rsquare:  -59.3
# Probability of Detection:  0.2857142857142857
# Probability of False Detection:  0.08695652173913043
# False Alarm Rate:  0.8888888888888888
# Frequency Bias:  2.5714285714285716
#
# 5
# 638940-99999
# Number of Observation:  293
# RMSE:  38.6
# MAE:  10.5
# Bias:  3.8
# Rsquare:  -4.6
# Probability of Detection:  0.5068493150684932
# Probability of False Detection:  0.16822429906542055
# False Alarm Rate:  0.5316455696202531
# Frequency Bias:  1.082191780821918
#
# 6
# 637290-99999
# Number of Observation:  302
# RMSE:  25.9
# MAE:  10.9
# Bias:  3.8
# Rsquare:  -1.0
# Probability of Detection:  0.7083333333333334
# Probability of False Detection:  0.19444444444444445
# False Alarm Rate:  0.30327868852459017
# Frequency Bias:  1.0166666666666666
#
# 7
# 638700-99999
# Number of Observation:  297
# RMSE:  30.5
# MAE:  12.9
# Bias:  8.5
# Rsquare:  -4.8
# Probability of Detection:  0.5432098765432098
# Probability of False Detection:  0.2740740740740741
# False Alarm Rate:  0.7283950617283951
# Frequency Bias:  2.0
#
# 8
# 639710-99999
# Number of Observation:  296
# RMSE:  14.6
# MAE:  5.5
# Bias:  1.3
# Rsquare:  -1.6
# Probability of Detection:  0.45614035087719296
# Probability of False Detection:  0.13596491228070176
# False Alarm Rate:  0.6176470588235294
# Frequency Bias:  1.1929824561403508
#
# 9
# 638620-99999
# Number of Observation:  293
# RMSE:  16.1
# MAE:  4.7
# Bias:  2.0
# Rsquare:  -0.6
# Probability of Detection:  0.7291666666666666
# Probability of False Detection:  0.05531914893617021
# False Alarm Rate:  0.39655172413793105
# Frequency Bias:  1.2083333333333333
#
# 10
# 638870-99999
# Number of Observation:  296
# RMSE:  17.3
# MAE:  6.3
# Bias:  4.1
# Rsquare:  -2.2
# Probability of Detection:  0.7183098591549296
# Probability of False Detection:  0.09009009009009009
# False Alarm Rate:  0.3108108108108108
# Frequency Bias:  1.0422535211267605
#
# 11
# 637560-99999
# Number of Observation:  296
# RMSE:  14.3
# MAE:  5.4
# Bias:  1.1
# Rsquare:  -2.7
# Probability of Detection:  0.5116279069767442
# Probability of False Detection:  0.18666666666666668
# False Alarm Rate:  0.38028169014084506
# Frequency Bias:  0.8255813953488372
#
# 12
# 637910-99999
# Number of Observation:  296
# RMSE:  13.1
# MAE:  3.8
# Bias:  1.1
# Rsquare:  -1.5
# Probability of Detection:  0.5245901639344263
# Probability of False Detection:  0.11934156378600823
# False Alarm Rate:  0.39622641509433965
# Frequency Bias:  0.8688524590163934
#
# 13
# 638810-99999
# Number of Observation:  295
# RMSE:  11.6
# MAE:  4.8
# Bias:  1.7
# Rsquare:  -1.9
# Probability of Detection:  0.5072463768115942
# Probability of False Detection:  0.15315315315315314
# False Alarm Rate:  0.5205479452054794
# Frequency Bias:  1.0579710144927537
#
# 14
# 638010-99999
# Number of Observation:  290
# RMSE:  17.8
# MAE:  6.6
# Bias:  2.1
# Rsquare:  -0.3
# Probability of Detection:  0.6612903225806451
# Probability of False Detection:  0.1076923076923077
# False Alarm Rate:  0.5684210526315789
# Frequency Bias:  1.532258064516129
#
# 15
# 639620-99999
# Number of Observation:  292
# RMSE:  18.4
# MAE:  5.9
# Bias:  0.6
# Rsquare:  -0.5
# Probability of Detection:  0.6557377049180327
# Probability of False Detection:  0.08898305084745763
# False Alarm Rate:  0.2857142857142857
# Frequency Bias:  0.9180327868852459
#
# 16
# 638660-99999
# Number of Observation:  290
# RMSE:  29.0
# MAE:  9.3
# Bias:  4.6
# Rsquare:  -6.1
# Probability of Detection:  0.5897435897435898
# Probability of False Detection:  0.14814814814814814
# False Alarm Rate:  0.3783783783783784
# Frequency Bias:  0.9487179487179487
#
# 17
# 638320-99999
# Number of Observation:  297
# RMSE:  19.5
# MAE:  6.7
# Bias:  -0.0
# Rsquare:  -0.6
# Probability of Detection:  0.6056338028169014
# Probability of False Detection:  0.11764705882352941
# False Alarm Rate:  0.2711864406779661
# Frequency Bias:  0.8309859154929577
#
# 18
# 637330-99999
# Number of Observation:  290
# RMSE:  17.7
# MAE:  7.9
# Bias:  3.9
# Rsquare:  -1.2
# Probability of Detection:  0.6666666666666666
# Probability of False Detection:  0.15819209039548024
# False Alarm Rate:  0.504424778761062
# Frequency Bias:  1.3452380952380953
#
# 19
# TA00057
# Number of Observation:  302
# RMSE:  21.8
# MAE:  7.1
# Bias:  6.3
# Rsquare:  -97.4
# Probability of Detection:  0.4807692307692308
# Probability of False Detection:  0.12558139534883722
# False Alarm Rate:  0.7126436781609196
# Frequency Bias:  1.6730769230769231
#
# 20
# TA00020
# Number of Observation:  225
# RMSE:  12.3
# MAE:  2.5
# Bias:  1.7
# Rsquare:  -12.3
# Probability of Detection:  0.7666666666666667
# Probability of False Detection:  0.036458333333333336
# False Alarm Rate:  0.30303030303030304
# Frequency Bias:  1.1
#
# 21
# 638200-99999
# Number of Observation:  283
# RMSE:  22.8
# MAE:  8.2
# Bias:  5.2
# Rsquare:  -7.3
# Probability of Detection:  0.4772727272727273
# Probability of False Detection:  0.22115384615384615
# False Alarm Rate:  0.44
# Frequency Bias:  0.8522727272727273
#
# 22
# 637170-99999
# Number of Observation:  295
# RMSE:  19.7
# MAE:  6.8
# Bias:  1.9
# Rsquare:  -2.2
# Probability of Detection:  0.4336283185840708
# Probability of False Detection:  0.2962962962962963
# False Alarm Rate:  0.379746835443038
# Frequency Bias:  0.6991150442477876
#
# 23
# TA00019
# Number of Observation:  301
# RMSE:  23.6
# MAE:  10.4
# Bias:  9.1
# Rsquare:  -13.8
# Probability of Detection:  0.8555555555555555
# Probability of False Detection:  0.09923664122137404
# False Alarm Rate:  0.5470588235294118
# Frequency Bias:  1.8888888888888888
#
# 24
# 637930-99999
# Number of Observation:  293
# RMSE:  11.5
# MAE:  3.7
# Bias:  1.9
# Rsquare:  -2.1
# Probability of Detection:  0.6097560975609756
# Probability of False Detection:  0.06956521739130435
# False Alarm Rate:  0.6031746031746031
# Frequency Bias:  1.5365853658536586
#
# 25
# TA00076
# Number of Observation:  204
# RMSE:  22.6
# MAE:  11.5
# Bias:  7.9
# Rsquare:  -4.1
# Probability of Detection:  0.7916666666666666
# Probability of False Detection:  0.32786885245901637
# False Alarm Rate:  0.46853146853146854
# Frequency Bias:  1.4895833333333333
#
# 26
# TA00069
# Number of Observation:  241
# RMSE:  19.8
# MAE:  5.7
# Bias:  2.6
# Rsquare:  -7.9
# Probability of Detection:  0.2542372881355932
# Probability of False Detection:  0.2222222222222222
# False Alarm Rate:  0.6511627906976745
# Frequency Bias:  0.7288135593220338
#
# 27
# TA00074
# Number of Observation:  302
# RMSE:  19.6
# MAE:  7.2
# Bias:  3.4
# Rsquare:  -1.2
# Probability of Detection:  0.5568181818181818
# Probability of False Detection:  0.17410714285714285
# False Alarm Rate:  0.3717948717948718
# Frequency Bias:  0.8863636363636364
#
# 28
# 636610-99999
# Number of Observation:  295
# RMSE:  20.3
# MAE:  11.0
# Bias:  5.2
# Rsquare:  -2.6
# Probability of Detection:  0.6666666666666666
# Probability of False Detection:  0.38636363636363635
# False Alarm Rate:  0.37423312883435583
# Frequency Bias:  1.065359477124183
#
# 29
# 637200-99999
# Number of Observation:  284
# RMSE:  21.3
# MAE:  7.7
# Bias:  2.3
# Rsquare:  -2.0
# Probability of Detection:  0.46875
# Probability of False Detection:  0.2350230414746544
# False Alarm Rate:  0.3283582089552239
# Frequency Bias:  0.6979166666666666
#
# 30
# 643870-99999
# Number of Observation:  275
# RMSE:  24.6
# MAE:  7.9
# Bias:  0.5
# Rsquare:  -0.8
# Probability of Detection:  0.4418604651162791
# Probability of False Detection:  0.24742268041237114
# False Alarm Rate:  0.5308641975308642
# Frequency Bias:  0.9418604651162791
#
# 31
# 636950-99999
# Number of Observation:  287
# RMSE:  27.2
# MAE:  8.0
# Bias:  1.9
# Rsquare:  -4.1
# Probability of Detection:  0.3684210526315789
# Probability of False Detection:  0.2597402597402597
# False Alarm Rate:  0.375
# Frequency Bias:  0.5894736842105263
#
# 32
# 637400-99999
# Number of Observation:  278
# RMSE:  18.2
# MAE:  6.4
# Bias:  3.7
# Rsquare:  -4.7
# Probability of Detection:  0.5428571428571428
# Probability of False Detection:  0.16
# False Alarm Rate:  0.5128205128205128
# Frequency Bias:  1.1142857142857143
#
# 33
# TA00056
# Number of Observation:  286
# RMSE:  22.9
# MAE:  8.0
# Bias:  5.2
# Rsquare:  -3.7
# Probability of Detection:  0.5057471264367817
# Probability of False Detection:  0.21182266009852216
# False Alarm Rate:  0.46987951807228917
# Frequency Bias:  0.9540229885057471
#
# 34
# 637140-99999
# Number of Observation:  285
# RMSE:  23.4
# MAE:  9.5
# Bias:  5.8
# Rsquare:  -7.2
# Probability of Detection:  0.6428571428571429
# Probability of False Detection:  0.26627218934911245
# False Alarm Rate:  0.3017241379310345
# Frequency Bias:  0.9206349206349206
#
# 35
# TA00025
# Number of Observation:  302
# RMSE:  19.3
# MAE:  6.8
# Bias:  5.8
# Rsquare:  -8.0
# Probability of Detection:  0.5833333333333334
# Probability of False Detection:  0.07352941176470588
# False Alarm Rate:  0.7857142857142857
# Frequency Bias:  2.7222222222222223
#
# 36
# 643800-99999
# Number of Observation:  267
# RMSE:  16.1
# MAE:  7.6
# Bias:  4.1
# Rsquare:  -2.5
# Probability of Detection:  0.6631578947368421
# Probability of False Detection:  0.23529411764705882
# False Alarm Rate:  0.5190839694656488
# Frequency Bias:  1.3789473684210527
#
# 37
# 643810-99999
# Number of Observation:  272
# RMSE:  14.0
# MAE:  6.2
# Bias:  3.5
# Rsquare:  -8.6
# Probability of Detection:  0.5806451612903226
# Probability of False Detection:  0.2532467532467532
# False Alarm Rate:  0.5423728813559322
# Frequency Bias:  1.2688172043010753
#
# 38
# TA00033
# Number of Observation:  302
# RMSE:  21.3
# MAE:  8.1
# Bias:  5.8
# Rsquare:  -5.6
# Probability of Detection:  0.75
# Probability of False Detection:  0.14606741573033707
# False Alarm Rate:  0.3709677419354839
# Frequency Bias:  1.1923076923076923
#
# 39
# TA00072
# Number of Observation:  132
# RMSE:  30.9
# MAE:  13.1
# Bias:  11.0
# Rsquare:  -13.7
# Probability of Detection:  0.6388888888888888
# Probability of False Detection:  0.16049382716049382
# False Alarm Rate:  0.5490196078431373
# Frequency Bias:  1.4166666666666667
#
# 40
# 636120-99999
# Number of Observation:  297
# RMSE:  13.4
# MAE:  3.4
# Bias:  2.1
# Rsquare:  -4.1
# Probability of Detection:  0.36585365853658536
# Probability of False Detection:  0.10236220472440945
# False Alarm Rate:  0.6511627906976745
# Frequency Bias:  1.048780487804878
#
# 41
# TA00066
# Number of Observation:  147
# RMSE:  6.4
# MAE:  1.9
# Bias:  -0.3
# Rsquare:  -1.0
# Probability of Detection:  0.3333333333333333
# Probability of False Detection:  0.15267175572519084
# False Alarm Rate:  0.375
# Frequency Bias:  0.5333333333333333
#
# 42
# 637990-99999
# Number of Observation:  282
# RMSE:  19.8
# MAE:  6.9
# Bias:  4.6
# Rsquare:  -7.5
# Probability of Detection:  0.5280898876404494
# Probability of False Detection:  0.21
# False Alarm Rate:  0.4268292682926829
# Frequency Bias:  0.9213483146067416
#
# 43
# 637420-99999
# Number of Observation:  276
# RMSE:  19.8
# MAE:  7.4
# Bias:  4.1
# Rsquare:  -2.7
# Probability of Detection:  0.5
# Probability of False Detection:  0.18518518518518517
# False Alarm Rate:  0.5977011494252874
# Frequency Bias:  1.2428571428571429
#
# 44
# TA00023
# Number of Observation:  302
# RMSE:  14.8
# MAE:  3.5
# Bias:  3.2
# Rsquare:  -25.6
# Probability of Detection:  0.625
# Probability of False Detection:  0.034482758620689655
# False Alarm Rate:  0.6341463414634146
# Frequency Bias:  1.7083333333333333
#
# 45
# TA00031
# Number of Observation:  149
# RMSE:  24.4
# MAE:  12.5
# Bias:  11.0
# Rsquare:  -8.7
# Probability of Detection:  0.8852459016393442
# Probability of False Detection:  0.1590909090909091
# False Alarm Rate:  0.4857142857142857
# Frequency Bias:  1.721311475409836
#
# 46
# TA00021
# Number of Observation:  223
# RMSE:  29.6
# MAE:  14.3
# Bias:  13.4
# Rsquare:  -18.2
# Probability of Detection:  0.6923076923076923
# Probability of False Detection:  0.11538461538461539
# False Alarm Rate:  0.773109243697479
# Frequency Bias:  3.051282051282051
#
# 47
# TA00108
# Number of Observation:  282
# RMSE:  16.8
# MAE:  5.0
# Bias:  3.9
# Rsquare:  -3.7
# Probability of Detection:  0.4482758620689655
# Probability of False Detection:  0.06956521739130435
# False Alarm Rate:  0.75
# Frequency Bias:  1.793103448275862
#
# 48
# TA00029
# Number of Observation:  302
# RMSE:  17.9
# MAE:  7.2
# Bias:  4.9
# Rsquare:  -26.0
# Probability of Detection:  0.38571428571428573
# Probability of False Detection:  0.4075829383886256
# False Alarm Rate:  0.4065934065934066
# Frequency Bias:  0.65
#
# 49
# TA00130
# Number of Observation:  302
# RMSE:  15.2
# MAE:  4.2
# Bias:  2.5
# Rsquare:  -2.4
# Probability of Detection:  0.5384615384615384
# Probability of False Detection:  0.07627118644067797
# False Alarm Rate:  0.6818181818181818
# Frequency Bias:  1.6923076923076923
#
# 50
# 636860-99999
# Number of Observation:  278
# RMSE:  33.2
# MAE:  14.4
# Bias:  8.7
# Rsquare:  -8.8
# Probability of Detection:  0.6691176470588235
# Probability of False Detection:  0.3191489361702128
# False Alarm Rate:  0.3357664233576642
# Frequency Bias:  1.0073529411764706
#
# 51
# TA00133
# Number of Observation:  302
# RMSE:  18.4
# MAE:  5.9
# Bias:  2.0
# Rsquare:  -2.4
# Probability of Detection:  0.47959183673469385
# Probability of False Detection:  0.21888412017167383
# False Alarm Rate:  0.3188405797101449
# Frequency Bias:  0.7040816326530612
#
# 52
# TA00155
# Number of Observation:  302
# RMSE:  8.8
# MAE:  2.6
# Bias:  1.2
# Rsquare:  0.1
# Probability of Detection:  0.6595744680851063
# Probability of False Detection:  0.06639004149377593
# False Alarm Rate:  0.4918032786885246
# Frequency Bias:  1.297872340425532
#
# 53
# TA00157
# Number of Observation:  302
# RMSE:  12.6
# MAE:  3.1
# Bias:  1.9
# Rsquare:  -3.4
# Probability of Detection:  0.6756756756756757
# Probability of False Detection:  0.04819277108433735
# False Alarm Rate:  0.5283018867924528
# Frequency Bias:  1.4324324324324325
#
# 54
# TA00140
# Number of Observation:  277
# RMSE:  18.8
# MAE:  9.6
# Bias:  2.5
# Rsquare:  -1.2
# Probability of Detection:  0.6214285714285714
# Probability of False Detection:  0.3706293706293706
# False Alarm Rate:  0.35074626865671643
# Frequency Bias:  0.9571428571428572
#
# 55
# 643830-99999
# Number of Observation:  245
# RMSE:  15.3
# MAE:  7.1
# Bias:  1.2
# Rsquare:  -1.1
# Probability of Detection:  0.5102040816326531
# Probability of False Detection:  0.3221476510067114
# False Alarm Rate:  0.4791666666666667
# Frequency Bias:  0.9795918367346939
#
# 56
# TA00054
# Number of Observation:  135
# RMSE:  20.3
# MAE:  7.7
# Bias:  5.2
# Rsquare:  -3.9
# Probability of Detection:  0.8775510204081632
# Probability of False Detection:  0.08450704225352113
# False Alarm Rate:  0.328125
# Frequency Bias:  1.3061224489795917
#
# 57
# 637050-99999
# Number of Observation:  171
# RMSE:  10.9
# MAE:  3.8
# Bias:  2.2
# Rsquare:  -5.0
# Probability of Detection:  0.37037037037037035
# Probability of False Detection:  0.1297709923664122
# False Alarm Rate:  0.75
# Frequency Bias:  1.4814814814814814
#
# 58
# 643900-99999
# Number of Observation:  163
# RMSE:  13.3
# MAE:  3.9
# Bias:  3.5
# Rsquare:  -111.5
# Probability of Detection:  0.6111111111111112
# Probability of False Detection:  0.06930693069306931
# False Alarm Rate:  0.8225806451612904
# Frequency Bias:  3.4444444444444446
#
# 59
# TA00134
# Number of Observation:  191
# RMSE:  9.5
# MAE:  3.9
# Bias:  2.8
# Rsquare:  -4.8
# Probability of Detection:  0.5641025641025641
# Probability of False Detection:  0.1259259259259259
# False Alarm Rate:  0.6071428571428571
# Frequency Bias:  1.435897435897436
#
# 60
# TA00131
# Number of Observation:  302
# RMSE:  16.6
# MAE:  6.3
# Bias:  2.8
# Rsquare:  -1.4
# Probability of Detection:  0.5172413793103449
# Probability of False Detection:  0.18666666666666668
# False Alarm Rate:  0.4155844155844156
# Frequency Bias:  0.8850574712643678
#
# 61
# TA00129
# Number of Observation:  302
# RMSE:  10.7
# MAE:  3.2
# Bias:  2.3
# Rsquare:  -9.6
# Probability of Detection:  0.7142857142857143
# Probability of False Detection:  0.04310344827586207
# False Alarm Rate:  0.6428571428571429
# Frequency Bias:  2.0
#
# 62
# can-git-gr1.umva
# Number of Observation:  259
# RMSE:  17.4
# MAE:  7.7
# Bias:  3.5
# Rsquare:  -3.7
# Probability of Detection:  0.7027027027027027
# Probability of False Detection:  0.1456953642384106
# False Alarm Rate:  0.5185185185185185
# Frequency Bias:  1.4594594594594594
#
# 63
# cub-nta-gr1.umva
# Number of Observation:  270
# RMSE:  16.3
# MAE:  5.9
# Bias:  2.7
# Rsquare:  -5.7
# Probability of Detection:  0.65
# Probability of False Detection:  0.14893617021276595
# False Alarm Rate:  0.36585365853658536
# Frequency Bias:  1.025
#
# 64
# gas-mbu-gr3.umva
# Number of Observation:  272
# RMSE:  16.7
# MAE:  6.1
# Bias:  2.7
# Rsquare:  -5.1
# Probability of Detection:  0.6538461538461539
# Probability of False Detection:  0.14136125654450263
# False Alarm Rate:  0.37037037037037035
# Frequency Bias:  1.0384615384615385
#
# 65
# gat-gat-gr3.umva
# Number of Observation:  282
# RMSE:  13.6
# MAE:  5.1
# Bias:  1.7
# Rsquare:  -3.0
# Probability of Detection:  0.5833333333333334
# Probability of False Detection:  0.17412935323383086
# False Alarm Rate:  0.3950617283950617
# Frequency Bias:  0.9642857142857143
#
# 66
# git-git-gr1.umva
# Number of Observation:  255
# RMSE:  19.0
# MAE:  7.7
# Bias:  3.7
# Rsquare:  -4.6
# Probability of Detection:  0.6619718309859155
# Probability of False Detection:  0.1610738255033557
# False Alarm Rate:  0.5566037735849056
# Frequency Bias:  1.4929577464788732
#
# 67
# git-kuw-gr1.umva
# Number of Observation:  256
# RMSE:  18.9
# MAE:  8.4
# Bias:  1.8
# Rsquare:  -2.7
# Probability of Detection:  0.6233766233766234
# Probability of False Detection:  0.18354430379746836
# False Alarm Rate:  0.5102040816326531
# Frequency Bias:  1.2727272727272727
#
# 68
# git-muh-gr1.umva
# Number of Observation:  254
# RMSE:  18.5
# MAE:  8.3
# Bias:  1.7
# Rsquare:  -2.6
# Probability of Detection:  0.6025641025641025
# Probability of False Detection:  0.1962025316455696
# False Alarm Rate:  0.5104166666666666
# Frequency Bias:  1.2307692307692308
#
# 69
# kaj-kaj-gr1.umva
# Number of Observation:  271
# RMSE:  15.2
# MAE:  6.1
# Bias:  1.8
# Rsquare:  -2.8
# Probability of Detection:  0.5421686746987951
# Probability of False Detection:  0.19487179487179487
# False Alarm Rate:  0.40789473684210525
# Frequency Bias:  0.9156626506024096
#
# 70
# kan-mak-gr1.umva
# Number of Observation:  261
# RMSE:  20.2
# MAE:  8.3
# Bias:  3.3
# Rsquare:  -5.7
# Probability of Detection:  0.5833333333333334
# Probability of False Detection:  0.21875
# False Alarm Rate:  0.5148514851485149
# Frequency Bias:  1.2023809523809523
#
# 71
# kar-karu-gr2.umva
# Number of Observation:  268
# RMSE:  15.6
# MAE:  6.3
# Bias:  1.2
# Rsquare:  -1.7
# Probability of Detection:  0.6086956521739131
# Probability of False Detection:  0.140625
# False Alarm Rate:  0.4473684210526316
# Frequency Bias:  1.1014492753623188
#
# 72
# kav-kir-gr2.umva
# Number of Observation:  260
# RMSE:  17.1
# MAE:  7.5
# Bias:  3.7
# Rsquare:  -3.9
# Probability of Detection:  0.7323943661971831
# Probability of False Detection:  0.12582781456953643
# False Alarm Rate:  0.5229357798165137
# Frequency Bias:  1.5352112676056338
#
# 73
# kav-mun-gr1.umva
# Number of Observation:  285
# RMSE:  16.8
# MAE:  7.8
# Bias:  3.4
# Rsquare:  -4.0
# Probability of Detection:  0.7017543859649122
# Probability of False Detection:  0.2125
# False Alarm Rate:  0.36
# Frequency Bias:  1.0964912280701755
#
# 74
# kiv-nam-gr1.umva
# Number of Observation:  261
# RMSE:  19.6
# MAE:  8.3
# Bias:  3.7
# Rsquare:  -4.8
# Probability of Detection:  0.7011494252873564
# Probability of False Detection:  0.17218543046357615
# False Alarm Rate:  0.44545454545454544
# Frequency Bias:  1.264367816091954
#
# 75
# maga-mag-gr1.umva
# Number of Observation:  276
# RMSE:  16.7
# MAE:  6.8
# Bias:  2.1
# Rsquare:  -3.1
# Probability of Detection:  0.6363636363636364
# Probability of False Detection:  0.1702127659574468
# False Alarm Rate:  0.36363636363636365
# Frequency Bias:  1.0
#
# 76
# mas-nya-gr1.umva
# Number of Observation:  275
# RMSE:  16.4
# MAE:  6.5
# Bias:  0.9
# Rsquare:  -2.0
# Probability of Detection:  0.6129032258064516
# Probability of False Detection:  0.18652849740932642
# False Alarm Rate:  0.3048780487804878
# Frequency Bias:  0.8817204301075269
#
# 77
# may-may-gr2.umva
# Number of Observation:  263
# RMSE:  15.8
# MAE:  6.0
# Bias:  2.9
# Rsquare:  -4.8
# Probability of Detection:  0.6493506493506493
# Probability of False Detection:  0.15168539325842698
# False Alarm Rate:  0.4117647058823529
# Frequency Bias:  1.103896103896104
#
# 78
# mug-mugo-gr2.umva
# Number of Observation:  243
# RMSE:  18.8
# MAE:  6.6
# Bias:  2.5
# Rsquare:  -4.2
# Probability of Detection:  0.6363636363636364
# Probability of False Detection:  0.13953488372093023
# False Alarm Rate:  0.4084507042253521
# Frequency Bias:  1.0757575757575757
#
# 79
# mug-nta-gr3.umva
# Number of Observation:  275
# RMSE:  18.7
# MAE:  7.2
# Bias:  2.2
# Rsquare:  -3.6
# Probability of Detection:  0.5975609756097561
# Probability of False Detection:  0.17098445595854922
# False Alarm Rate:  0.4024390243902439
# Frequency Bias:  1.0
#
# 80
# mug-rus-gr2.umva
# Number of Observation:  244
# RMSE:  19.7
# MAE:  7.2
# Bias:  2.4
# Rsquare:  -3.3
# Probability of Detection:  0.6716417910447762
# Probability of False Detection:  0.1286549707602339
# False Alarm Rate:  0.3835616438356164
# Frequency Bias:  1.0895522388059702
#
# 81
# muhw-muh-gr1.umva
# Number of Observation:  270
# RMSE:  16.0
# MAE:  6.6
# Bias:  0.8
# Rsquare:  -1.4
# Probability of Detection:  0.6233766233766234
# Probability of False Detection:  0.15104166666666666
# False Alarm Rate:  0.38461538461538464
# Frequency Bias:  1.0129870129870129
#
# 82
# mun-mun-gr2.umva
# Number of Observation:  264
# RMSE:  18.8
# MAE:  7.9
# Bias:  3.7
# Rsquare:  -5.8
# Probability of Detection:  0.6781609195402298
# Probability of False Detection:  0.18064516129032257
# False Alarm Rate:  0.45871559633027525
# Frequency Bias:  1.2528735632183907
#
# 83
# mut-mak-gr2.umva
# Number of Observation:  264
# RMSE:  17.2
# MAE:  8.1
# Bias:  2.0
# Rsquare:  -2.5
# Probability of Detection:  0.6559139784946236
# Probability of False Detection:  0.20512820512820512
# False Alarm Rate:  0.4351851851851852
# Frequency Bias:  1.1612903225806452
#
# 84
# ngu-nya-gr3.umva
# Number of Observation:  276
# RMSE:  15.7
# MAE:  5.9
# Bias:  1.3
# Rsquare:  -3.2
# Probability of Detection:  0.5617977528089888
# Probability of False Detection:  0.20207253886010362
# False Alarm Rate:  0.39759036144578314
# Frequency Bias:  0.9325842696629213
#
# 85
# nyabi-ny-gr1.umva
# Number of Observation:  258
# RMSE:  18.9
# MAE:  7.9
# Bias:  3.2
# Rsquare:  -4.8
# Probability of Detection:  0.6712328767123288
# Probability of False Detection:  0.1568627450980392
# False Alarm Rate:  0.5333333333333333
# Frequency Bias:  1.4383561643835616
#
# 86
# nya-mun-gr1.umva
# Number of Observation:  261
# RMSE:  18.9
# MAE:  7.9
# Bias:  3.1
# Rsquare:  -4.9
# Probability of Detection:  0.6666666666666666
# Probability of False Detection:  0.16025641025641027
# False Alarm Rate:  0.5238095238095238
# Frequency Bias:  1.4
#
# 87
# nye-nzo-gr1.umva
# Number of Observation:  279
# RMSE:  14.3
# MAE:  5.8
# Bias:  0.7
# Rsquare:  -1.5
# Probability of Detection:  0.6
# Probability of False Detection:  0.1708542713567839
# False Alarm Rate:  0.3625
# Frequency Bias:  0.9411764705882353
#
# 88
# ny-nyagi-gr1.umva
# Number of Observation:  266
# RMSE:  16.2
# MAE:  7.8
# Bias:  1.9
# Rsquare:  -2.2
# Probability of Detection:  0.68
# Probability of False Detection:  0.2077922077922078
# False Alarm Rate:  0.39285714285714285
# Frequency Bias:  1.12
#
# 89
# nzi-mas-gr1.umva
# Number of Observation:  278
# RMSE:  17.9
# MAE:  7.3
# Bias:  1.9
# Rsquare:  -2.8
# Probability of Detection:  0.7032967032967034
# Probability of False Detection:  0.14673913043478262
# False Alarm Rate:  0.3191489361702128
# Frequency Bias:  1.032967032967033
#
# 90
# rem-muy-gr1.umva
# Number of Observation:  260
# RMSE:  17.9
# MAE:  8.3
# Bias:  2.7
# Rsquare:  -2.8
# Probability of Detection:  0.6952380952380952
# Probability of False Detection:  0.2191780821917808
# False Alarm Rate:  0.35964912280701755
# Frequency Bias:  1.0857142857142856
#
# 91
# rug-kiv-gr1.umva
# Number of Observation:  274
# RMSE:  15.3
# MAE:  6.2
# Bias:  1.9
# Rsquare:  -2.7
# Probability of Detection:  0.5974025974025974
# Probability of False Detection:  0.15979381443298968
# False Alarm Rate:  0.425
# Frequency Bias:  1.0389610389610389
#
# 92
# rug-rug-gr2.umva
# Number of Observation:  275
# RMSE:  19.3
# MAE:  7.1
# Bias:  2.2
# Rsquare:  -3.1
# Probability of Detection:  0.6172839506172839
# Probability of False Detection:  0.16489361702127658
# False Alarm Rate:  0.42528735632183906
# Frequency Bias:  1.0740740740740742
#
# 93
# ruh-ruh-gr1.umva
# Number of Observation:  253
# RMSE:  19.2
# MAE:  7.8
# Bias:  3.9
# Rsquare:  -6.2
# Probability of Detection:  0.6533333333333333
# Probability of False Detection:  0.17567567567567569
# False Alarm Rate:  0.5333333333333333
# Frequency Bias:  1.4
#
# 94
# rwa-bug-gr1.umva
# Number of Observation:  264
# RMSE:  16.6
# MAE:  7.9
# Bias:  2.8
# Rsquare:  -3.3
# Probability of Detection:  0.7
# Probability of False Detection:  0.17763157894736842
# False Alarm Rate:  0.4375
# Frequency Bias:  1.2444444444444445
#
# 95
# rwa-tab-gr3.umva
# Number of Observation:  276
# RMSE:  16.5
# MAE:  6.2
# Bias:  1.8
# Rsquare:  -2.6
# Probability of Detection:  0.5529411764705883
# Probability of False Detection:  0.19689119170984457
# False Alarm Rate:  0.43373493975903615
# Frequency Bias:  0.9764705882352941
#
# 96
# sha-sha-gr1.umva
# Number of Observation:  278
# RMSE:  16.2
# MAE:  6.4
# Bias:  1.9
# Rsquare:  -2.1
# Probability of Detection:  0.6710526315789473
# Probability of False Detection:  0.13089005235602094
# False Alarm Rate:  0.41379310344827586
# Frequency Bias:  1.144736842105263
#
# 97
# shi-rur-gr1.umva
# Number of Observation:  259
# RMSE:  18.5
# MAE:  7.7
# Bias:  2.9
# Rsquare:  -3.1
# Probability of Detection:  0.6933333333333334
# Probability of False Detection:  0.14838709677419354
# False Alarm Rate:  0.5
# Frequency Bias:  1.3866666666666667
#
# 98
# tab-tab-gr3.umva
# Number of Observation:  277
# RMSE:  14.5
# MAE:  5.8
# Bias:  1.4
# Rsquare:  -2.7
# Probability of Detection:  0.5802469135802469
# Probability of False Detection:  0.17258883248730963
# False Alarm Rate:  0.4125
# Frequency Bias:  0.9876543209876543
#
# 99
# tem-rus-gr5.umva
# Number of Observation:  276
# RMSE:  18.8
# MAE:  7.0
# Bias:  2.4
# Rsquare:  -4.8
# Probability of Detection:  0.6133333333333333
# Probability of False Detection:  0.15508021390374332
# False Alarm Rate:  0.48314606741573035
# Frequency Bias:  1.1866666666666668
#
# 100
# yanz-kig-gr3.umva
# Number of Observation:  267
# RMSE:  16.9
# MAE:  8.1
# Bias:  2.4
# Rsquare:  -2.4
# Probability of Detection:  0.7032967032967034
# Probability of False Detection:  0.17419354838709677
# False Alarm Rate:  0.42857142857142855
# Frequency Bias:  1.2307692307692308
#
# 101
# muh-gah-gr1.umva
# Number of Observation:  259
# RMSE:  21.3
# MAE:  8.6
# Bias:  3.4
# Rsquare:  -5.0
# Probability of Detection:  0.33707865168539325
# Probability of False Detection:  0.29064039408866993
# False Alarm Rate:  0.4642857142857143
# Frequency Bias:  0.6292134831460674
