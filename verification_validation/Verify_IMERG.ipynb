# %%
import pandas as pd
import numpy as np

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy import stats

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df_obs_daily = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_station_data_daily_v2_imerg.csv")
df_obs_daily = df_obs_daily.set_index('Unnamed: 0')

df_obs_monthly = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_station_data_monthly_v2_imerg.csv")
df_obs_monthly = df_obs_monthly.set_index('Unnamed: 0')

df_sat_daily = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_imerg_daily_v2.csv")
df_sat_daily = df_sat_daily.set_index('Unnamed: 0')

df_sat_monthly = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_imerg_monthly_v2.csv")
df_sat_monthly = df_sat_monthly.set_index('Unnamed: 0')

df_obs_metadata = pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/station_data/Final results_csv/station_list_final_v2.csv')
df_obs_metadata = df_obs_metadata.set_index('STNID')

# %%
index = pd.Index(['Lat', 'Lon', 'RMSE', 'MAE', 'Bias', 'PearsonR', 'SpearmanR', 'R2', 'Probability of Detection', 'Probability of False Detection', 'False Alarm Rate', 'Frequency Bias'], name="rows")
column = df_obs_daily.columns

daily_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)
monthly_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)

for station, station_id in enumerate(df_obs_daily.columns):
  print(station)
  if station == 102:
    continue
  
  obs_daily = df_obs_daily[station_id]  
  sat_daily = df_sat_daily[station_id]

  obs_daily = obs_daily.to_numpy(copy=True)
  sat_daily = sat_daily.to_numpy(copy=True)

  obs_daily = obs_daily[~np.isnan(obs_daily)]
  sat_daily = sat_daily[~np.isnan(sat_daily)]

  n_of_sample = len(obs_daily)

  rmse = mean_squared_error(obs_daily, sat_daily, squared=False)
  mae = mean_absolute_error(obs_daily, sat_daily)
  pearsonr = stats.pearsonr(obs_daily, sat_daily)
  spearmanr = stats.spearmanr(obs_daily, sat_daily)
  rsq = r2_score(obs_daily, sat_daily)

  # correlation_matrix = np.corrcoef(obs_daily, sat_daily)
  # correlation_xy = correlation_matrix[0,1]
  # rsq = correlation_xy**2

  bias = sat_daily - obs_daily
  bias = bias.mean()

  obs_daily_bool = obs_daily.copy()
  sat_daily_bool = sat_daily.copy()

  obs_daily_bool[obs_daily_bool < 1] = 0
  obs_daily_bool[obs_daily_bool >= 1] = 1

  sat_daily_bool[sat_daily_bool < 1] = 0
  sat_daily_bool[sat_daily_bool >= 1] = 1

  category = np.empty([n_of_sample])

  for i in range(n_of_sample):
    if obs_daily_bool[i] == 1 and sat_daily_bool[i] == 1:
      category[i] = 1
    elif obs_daily_bool[i] == 1 and sat_daily_bool[i] == 0:
      category[i] = 2
    elif obs_daily_bool[i] == 0 and sat_daily_bool[i] == 1:
      category[i] = 3
    elif obs_daily_bool[i] == 0 and sat_daily_bool[i] == 0:
      category[i] = 4

  hit = np.count_nonzero(category == 1)
  miss = np.count_nonzero(category == 2)
  false_alarm = np.count_nonzero(category == 3)
  correct_negative = np.count_nonzero(category == 4)

  pod = hit/(hit + miss)
  pofd = miss/(miss+correct_negative)
  far = false_alarm/(hit + false_alarm)
  freq_bias = (hit+false_alarm)/(hit+miss)

  daily_metrics_df[station_id].loc['Lat'] = df_obs_metadata['LATITUDE'].loc[station_id]
  daily_metrics_df[station_id].loc['Lon'] = df_obs_metadata['LONGITUDE'].loc[station_id]
  daily_metrics_df[station_id].loc['RMSE'] = round(rmse,2)
  daily_metrics_df[station_id].loc['MAE'] = round(mae,2)
  daily_metrics_df[station_id].loc['Bias'] = round(bias,2)
  daily_metrics_df[station_id].loc['PearsonR'] = round(pearsonr[0],2)
  daily_metrics_df[station_id].loc['SpearmanR'] = round(spearmanr[0],2)
  daily_metrics_df[station_id].loc['R2'] = round(rsq,2)
  daily_metrics_df[station_id].loc['Probability of Detection'] = round(pod,2)
  daily_metrics_df[station_id].loc['Probability of False Detection'] = round(pofd,2)
  daily_metrics_df[station_id].loc['False Alarm Rate'] = round(far,2)
  daily_metrics_df[station_id].loc['Frequency Bias'] = round(freq_bias,2)
                                  
  print(station_id)
  print("Number of Observation: ", n_of_sample)
  print("RMSE: ", str(round(rmse,1)))
  print("MAE: ", str(round(mae,1)))
  print("Bias: ", str(round(bias,1)))
  print("Rsquare: ", str(round(rsq,1)))
  print("Probability of Detection: ", pod)
  print("Probability of False Detection: ", pofd)
  print("False Alarm Rate: ", far)
  print("Frequency Bias: ", freq_bias)


  # # print(obs_daily)
  # # print(sat_daily)

  # # print(obs_daily_bool)
  # # print(sat_daily_bool)
  print(" ")

  # obs_monthly = df_obs_monthly[station_id]
  # sat_monthly = df_sat_monthly[station_id]

  # obs_monthly = obs_monthly.to_numpy()
  # sat_monthly = sat_monthly.to_numpy()

  # print(station, station_id)

daily_metrics_df = daily_metrics_df.T
daily_metrics_df.to_csv('/content/gdrive/MyDrive/rainfall-forecast/verification_validation/metrics/metrics_imerg_daily.csv')

# %%
index = pd.Index(['Lat', 'Lon', 'ObsN', 'RMSE', 'MAE', 'Bias', 'PearsonR', 'SpearmanR', 'R2', 'POD', 'POFD', 'FAR', 'FB'], name="rows")
column = df_obs_monthly.columns

monthly_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)
monthly_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)

for station, station_id in enumerate(df_obs_monthly.columns):
  print(station)
  if station == 102:
    continue
  
  obs_monthly = df_obs_monthly[station_id]  
  sat_monthly = df_sat_monthly[station_id]

  obs_monthly = obs_monthly.to_numpy(copy=True)
  sat_monthly = sat_monthly.to_numpy(copy=True)

  obs_monthly = obs_monthly[~np.isnan(obs_monthly)]
  sat_monthly = sat_monthly[~np.isnan(sat_monthly)]

  n_of_sample = len(obs_monthly)

  rmse = mean_squared_error(obs_monthly, sat_monthly, squared=False)
  mae = mean_absolute_error(obs_monthly, sat_monthly)
  pearsonr = stats.pearsonr(obs_monthly, sat_monthly)
  spearmanr = stats.spearmanr(obs_monthly, sat_monthly)
  rsq = r2_score(obs_monthly, sat_monthly)

  # correlation_matrix = np.corrcoef(obs_monthly, sat_monthly)
  # correlation_xy = correlation_matrix[0,1]
  # rsq = correlation_xy**2

  bias = sat_monthly - obs_monthly
  bias = bias.mean()

  obs_monthly_bool = obs_monthly.copy()
  sat_monthly_bool = sat_monthly.copy()

  obs_monthly_bool[obs_monthly_bool < 10] = 0
  obs_monthly_bool[obs_monthly_bool >= 10] = 1

  sat_monthly_bool[sat_monthly_bool < 10] = 0
  sat_monthly_bool[sat_monthly_bool >= 10] = 1

  category = np.empty([n_of_sample])

  for i in range(n_of_sample):
    if obs_monthly_bool[i] == 1 and sat_monthly_bool[i] == 1:
      category[i] = 1
    elif obs_monthly_bool[i] == 1 and sat_monthly_bool[i] == 0:
      category[i] = 2
    elif obs_monthly_bool[i] == 0 and sat_monthly_bool[i] == 1:
      category[i] = 3
    elif obs_monthly_bool[i] == 0 and sat_monthly_bool[i] == 0:
      category[i] = 4

  hit = np.count_nonzero(category == 1)
  miss = np.count_nonzero(category == 2)
  false_alarm = np.count_nonzero(category == 3)
  correct_negative = np.count_nonzero(category == 4)

  if hit + miss == 0:
    pod = np.nan
  else:
    pod = hit/(hit + miss)

  if miss + correct_negative == 0:
    pofd = np.nan
  else:
    pofd = miss/(miss + correct_negative)

  if hit + false_alarm == 0:
    far = np.nan
  else:
    far = false_alarm/(hit + false_alarm)

  if hit + miss == 0:
    freq_bias = np.nan
  else:
    freq_bias = (hit+false_alarm)/(hit+miss)

  monthly_metrics_df[station_id].loc['Lat'] = df_obs_metadata['LATITUDE'].loc[station_id]
  monthly_metrics_df[station_id].loc['Lon'] = df_obs_metadata['LONGITUDE'].loc[station_id]
  monthly_metrics_df[station_id].loc['ObsN'] = n_of_sample
  monthly_metrics_df[station_id].loc['RMSE'] = round(rmse,2)
  monthly_metrics_df[station_id].loc['MAE'] = round(mae,2)
  monthly_metrics_df[station_id].loc['Bias'] = round(bias,2)
  monthly_metrics_df[station_id].loc['PearsonR'] = round(pearsonr[0],2)
  monthly_metrics_df[station_id].loc['SpearmanR'] = round(spearmanr[0],2)
  monthly_metrics_df[station_id].loc['R2'] = round(rsq,2)
  monthly_metrics_df[station_id].loc['POD'] = round(pod,2)
  monthly_metrics_df[station_id].loc['POFD'] = round(pofd,2)
  monthly_metrics_df[station_id].loc['FAR'] = round(far,2)
  monthly_metrics_df[station_id].loc['FB'] = round(freq_bias,2)
                                  
  print(station_id)
  print("Number of Observation: ", n_of_sample)
  print("RMSE: ", str(round(rmse,1)))
  print("MAE: ", str(round(mae,1)))
  print("Bias: ", str(round(bias,1)))
  print("Rsquare: ", str(round(rsq,1)))
  print("Probability of Detection: ", pod)
  print("Probability of False Detection: ", pofd)
  print("False Alarm Rate: ", far)
  print("Frequency Bias: ", freq_bias)


  # # print(obs_monthly)
  # # print(sat_monthly)

  # # print(obs_monthly_bool)
  # # print(sat_monthly_bool)
  print(" ")

  # obs_monthly = df_obs_monthly[station_id]
  # sat_monthly = df_sat_monthly[station_id]

  # obs_monthly = obs_monthly.to_numpy()
  # sat_monthly = sat_monthly.to_numpy()

  # print(station, station_id)

monthly_metrics_df = monthly_metrics_df.T
monthly_metrics_df.to_csv('/content/gdrive/MyDrive/rainfall-forecast/verification_validation/metrics/metrics_imerg_monthly.csv')
# Out:
# 0
# TA00073
# Number of Observation:  60
# RMSE:  55.6
# MAE:  31.6
# Bias:  6.1
# Rsquare:  0.3
# Probability of Detection:  0.9787234042553191
# Probability of False Detection:  0.25
# False Alarm Rate:  0.17857142857142858
# Frequency Bias:  1.1914893617021276
#
# 1
# TA00024
# Number of Observation:  60
# RMSE:  63.1
# MAE:  37.2
# Bias:  -1.1
# Rsquare:  0.5
# Probability of Detection:  0.8913043478260869
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.08888888888888889
# Frequency Bias:  0.9782608695652174
#
# 2
# TA00026
# Number of Observation:  60
# RMSE:  106.1
# MAE:  66.4
# Bias:  -8.0
# Rsquare:  0.1
# Probability of Detection:  0.9811320754716981
# Probability of False Detection:  0.5
# False Alarm Rate:  0.10344827586206896
# Frequency Bias:  1.0943396226415094
#
# 3
# TA00070
# Number of Observation:  60
# RMSE:  121.7
# MAE:  75.1
# Bias:  -20.5
# Rsquare:  0.1
# Probability of Detection:  0.7948717948717948
# Probability of False Detection:  0.5
# False Alarm Rate:  0.29545454545454547
# Frequency Bias:  1.1282051282051282
#
# 4
# TA00071
# Number of Observation:  60
# RMSE:  109.2
# MAE:  72.4
# Bias:  -14.8
# Rsquare:  0.4
# Probability of Detection:  0.8157894736842105
# Probability of False Detection:  0.4666666666666667
# False Alarm Rate:  0.3111111111111111
# Frequency Bias:  1.1842105263157894
#
# 5
# 638940-99999
# Number of Observation:  60
# RMSE:  90.7
# MAE:  51.7
# Bias:  -1.8
# Rsquare:  0.6
# Probability of Detection:  0.9782608695652174
# Probability of False Detection:  0.16666666666666666
# False Alarm Rate:  0.16666666666666666
# Frequency Bias:  1.173913043478261
#
# 6
# 637290-99999
# Number of Observation:  60
# RMSE:  108.2
# MAE:  83.2
# Bias:  20.0
# Rsquare:  0.4
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.05084745762711865
# Frequency Bias:  1.0535714285714286
#
# 7
# 638700-99999
# Number of Observation:  60
# RMSE:  71.3
# MAE:  47.6
# Bias:  -10.4
# Rsquare:  0.8
# Probability of Detection:  0.9811320754716981
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.08771929824561403
# Frequency Bias:  1.0754716981132075
#
# 8
# 639710-99999
# Number of Observation:  60
# RMSE:  65.8
# MAE:  35.9
# Bias:  -5.8
# Rsquare:  0.7
# Probability of Detection:  0.9024390243902439
# Probability of False Detection:  0.17391304347826086
# False Alarm Rate:  0.0
# Frequency Bias:  0.9024390243902439
#
# 9
# 638620-99999
# Number of Observation:  60
# RMSE:  56.2
# MAE:  33.0
# Bias:  9.4
# Rsquare:  0.7
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.2894736842105263
# Frequency Bias:  1.4074074074074074
#
# 10
# 638870-99999
# Number of Observation:  60
# RMSE:  49.2
# MAE:  35.7
# Bias:  25.3
# Rsquare:  0.7
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.375
# Frequency Bias:  1.6
#
# 11
# 637560-99999
# Number of Observation:  60
# RMSE:  91.8
# MAE:  62.6
# Bias:  31.1
# Rsquare:  -0.0
# Probability of Detection:  0.9607843137254902
# Probability of False Detection:  0.25
# False Alarm Rate:  0.057692307692307696
# Frequency Bias:  1.0196078431372548
#
# 12
# 637910-99999
# Number of Observation:  60
# RMSE:  59.2
# MAE:  34.8
# Bias:  -13.7
# Rsquare:  0.4
# Probability of Detection:  0.7575757575757576
# Probability of False Detection:  0.2857142857142857
# False Alarm Rate:  0.21875
# Frequency Bias:  0.9696969696969697
#
# 13
# 638810-99999
# Number of Observation:  60
# RMSE:  60.2
# MAE:  38.3
# Bias:  7.3
# Rsquare:  0.6
# Probability of Detection:  0.9444444444444444
# Probability of False Detection:  0.1
# False Alarm Rate:  0.15
# Frequency Bias:  1.1111111111111112
#
# 14
# 638010-99999
# Number of Observation:  60
# RMSE:  84.1
# MAE:  63.2
# Bias:  48.6
# Rsquare:  -0.0
# Probability of Detection:  0.9534883720930233
# Probability of False Detection:  0.18181818181818182
# False Alarm Rate:  0.16326530612244897
# Frequency Bias:  1.1395348837209303
#
# 15
# 639620-99999
# Number of Observation:  60
# RMSE:  65.1
# MAE:  33.2
# Bias:  -15.0
# Rsquare:  0.7
# Probability of Detection:  0.8857142857142857
# Probability of False Detection:  0.16
# False Alarm Rate:  0.11428571428571428
# Frequency Bias:  1.0
#
# 16
# 638660-99999
# Number of Observation:  60
# RMSE:  52.1
# MAE:  36.0
# Bias:  -1.1
# Rsquare:  0.7
# Probability of Detection:  0.9555555555555556
# Probability of False Detection:  0.2
# False Alarm Rate:  0.14
# Frequency Bias:  1.1111111111111112
#
# 17
# 638320-99999
# Number of Observation:  60
# RMSE:  179.2
# MAE:  99.2
# Bias:  -73.6
# Rsquare:  0.3
# Probability of Detection:  0.8780487804878049
# Probability of False Detection:  0.23809523809523808
# False Alarm Rate:  0.07692307692307693
# Frequency Bias:  0.9512195121951219
#
# 18
# 637330-99999
# Number of Observation:  60
# RMSE:  71.5
# MAE:  53.8
# Bias:  37.1
# Rsquare:  -0.1
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.10344827586206896
# Frequency Bias:  1.1153846153846154
#
# 19
# TA00057
# Number of Observation:  58
# RMSE:  108.4
# MAE:  75.1
# Bias:  60.3
# Rsquare:  -1.4
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.3684210526315789
# Frequency Bias:  1.5833333333333333
#
# 20
# TA00020
# Number of Observation:  59
# RMSE:  47.1
# MAE:  24.7
# Bias:  9.1
# Rsquare:  0.4
# Probability of Detection:  0.92
# Probability of False Detection:  0.08695652173913043
# False Alarm Rate:  0.3611111111111111
# Frequency Bias:  1.44
#
# 21
# 638200-99999
# Number of Observation:  60
# RMSE:  83.6
# MAE:  52.3
# Bias:  -35.6
# Rsquare:  0.5
# Probability of Detection:  0.7446808510638298
# Probability of False Detection:  0.6
# False Alarm Rate:  0.125
# Frequency Bias:  0.851063829787234
#
# 22
# 637170-99999
# Number of Observation:  60
# RMSE:  70.5
# MAE:  44.6
# Bias:  -21.3
# Rsquare:  0.5
# Probability of Detection:  0.9090909090909091
# Probability of False Detection:  0.5555555555555556
# False Alarm Rate:  0.0196078431372549
# Frequency Bias:  0.9272727272727272
#
# 23
# TA00019
# Number of Observation:  58
# RMSE:  120.0
# MAE:  84.9
# Bias:  82.2
# Rsquare:  -6.3
# Probability of Detection:  0.9811320754716981
# Probability of False Detection:  0.5
# False Alarm Rate:  0.07142857142857142
# Frequency Bias:  1.0566037735849056
#
# 24
# 637930-99999
# Number of Observation:  60
# RMSE:  41.7
# MAE:  26.2
# Bias:  -15.3
# Rsquare:  0.6
# Probability of Detection:  0.8857142857142857
# Probability of False Detection:  0.18181818181818182
# False Alarm Rate:  0.18421052631578946
# Frequency Bias:  1.0857142857142856
#
# 25
# TA00076
# Number of Observation:  57
# RMSE:  117.2
# MAE:  89.6
# Bias:  88.6
# Rsquare:  -1.8
# Probability of Detection:  1.0
# Probability of False Detection:  nan
# False Alarm Rate:  0.2982456140350877
# Frequency Bias:  1.425
#
# 26
# TA00069
# Number of Observation:  59
# RMSE:  72.5
# MAE:  49.2
# Bias:  -17.5
# Rsquare:  0.7
# Probability of Detection:  0.7
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.3170731707317073
# Frequency Bias:  1.025
#
# 27
# TA00074
# Number of Observation:  59
# RMSE:  115.2
# MAE:  68.9
# Bias:  -40.3
# Rsquare:  0.4
# Probability of Detection:  0.8372093023255814
# Probability of False Detection:  0.5
# False Alarm Rate:  0.2
# Frequency Bias:  1.0465116279069768
#
# 28
# 636610-99999
# Number of Observation:  60
# RMSE:  53.3
# MAE:  39.7
# Bias:  -2.8
# Rsquare:  0.6
# Probability of Detection:  0.9433962264150944
# Probability of False Detection:  0.6
# False Alarm Rate:  0.09090909090909091
# Frequency Bias:  1.0377358490566038
#
# 29
# 637200-99999
# Number of Observation:  60
# RMSE:  74.5
# MAE:  48.7
# Bias:  -40.2
# Rsquare:  0.6
# Probability of Detection:  0.6470588235294118
# Probability of False Detection:  0.6923076923076923
# False Alarm Rate:  0.029411764705882353
# Frequency Bias:  0.6666666666666666
#
# 30
# 643870-99999
# Number of Observation:  60
# RMSE:  97.2
# MAE:  73.9
# Bias:  24.7
# Rsquare:  0.1
# Probability of Detection:  1.0
# Probability of False Detection:  nan
# False Alarm Rate:  0.13333333333333333
# Frequency Bias:  1.1538461538461537
#
# 31
# 636950-99999
# Number of Observation:  60
# RMSE:  93.8
# MAE:  54.8
# Bias:  -36.6
# Rsquare:  0.6
# Probability of Detection:  0.9111111111111111
# Probability of False Detection:  0.2857142857142857
# False Alarm Rate:  0.10869565217391304
# Frequency Bias:  1.0222222222222221
#
# 32
# 637400-99999
# Number of Observation:  60
# RMSE:  61.4
# MAE:  49.1
# Bias:  41.9
# Rsquare:  0.2
# Probability of Detection:  1.0
# Probability of False Detection:  nan
# False Alarm Rate:  0.26666666666666666
# Frequency Bias:  1.3636363636363635
#
# 33
# TA00056
# Number of Observation:  56
# RMSE:  72.7
# MAE:  45.6
# Bias:  -29.7
# Rsquare:  0.7
# Probability of Detection:  0.6888888888888889
# Probability of False Detection:  0.5833333333333334
# False Alarm Rate:  0.03125
# Frequency Bias:  0.7111111111111111
#
# 34
# 637140-99999
# Number of Observation:  60
# RMSE:  42.8
# MAE:  30.1
# Bias:  -2.9
# Rsquare:  0.6
# Probability of Detection:  0.9803921568627451
# Probability of False Detection:  0.16666666666666666
# False Alarm Rate:  0.07407407407407407
# Frequency Bias:  1.0588235294117647
#
# 35
# TA00025
# Number of Observation:  53
# RMSE:  67.2
# MAE:  41.2
# Bias:  -4.9
# Rsquare:  0.4
# Probability of Detection:  0.926829268292683
# Probability of False Detection:  0.5
# False Alarm Rate:  0.19148936170212766
# Frequency Bias:  1.146341463414634
#
# 36
# 643800-99999
# Number of Observation:  59
# RMSE:  63.6
# MAE:  49.3
# Bias:  29.8
# Rsquare:  0.0
# Probability of Detection:  0.9433962264150944
# Probability of False Detection:  0.5
# False Alarm Rate:  0.05660377358490566
# Frequency Bias:  1.0
#
# 37
# 643810-99999
# Number of Observation:  59
# RMSE:  77.1
# MAE:  47.1
# Bias:  1.1
# Rsquare:  0.0
# Probability of Detection:  0.9444444444444444
# Probability of False Detection:  0.75
# False Alarm Rate:  0.07272727272727272
# Frequency Bias:  1.0185185185185186
#
# 38
# TA00033
# Number of Observation:  51
# RMSE:  102.2
# MAE:  72.0
# Bias:  62.1
# Rsquare:  -0.3
# Probability of Detection:  1.0
# Probability of False Detection:  nan
# False Alarm Rate:  0.13725490196078433
# Frequency Bias:  1.1590909090909092
#
# 39
# TA00072
# Number of Observation:  56
# RMSE:  74.1
# MAE:  47.4
# Bias:  -9.4
# Rsquare:  0.5
# Probability of Detection:  0.8235294117647058
# Probability of False Detection:  0.3157894736842105
# False Alarm Rate:  0.24324324324324326
# Frequency Bias:  1.088235294117647
#
# 40
# 636120-99999
# Number of Observation:  60
# RMSE:  31.1
# MAE:  18.0
# Bias:  4.6
# Rsquare:  0.3
# Probability of Detection:  0.8888888888888888
# Probability of False Detection:  0.1111111111111111
# False Alarm Rate:  0.2727272727272727
# Frequency Bias:  1.2222222222222223
#
# 41
# TA00066
# Number of Observation:  53
# RMSE:  63.8
# MAE:  43.5
# Bias:  -20.7
# Rsquare:  0.5
# Probability of Detection:  0.8
# Probability of False Detection:  0.5
# False Alarm Rate:  0.13513513513513514
# Frequency Bias:  0.925
#
# 42
# 637990-99999
# Number of Observation:  60
# RMSE:  48.9
# MAE:  28.5
# Bias:  15.6
# Rsquare:  0.4
# Probability of Detection:  0.8421052631578947
# Probability of False Detection:  0.11538461538461539
# False Alarm Rate:  0.5294117647058824
# Frequency Bias:  1.7894736842105263
#
# 43
# 637420-99999
# Number of Observation:  60
# RMSE:  60.0
# MAE:  31.4
# Bias:  13.5
# Rsquare:  0.5
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.6226415094339622
# Frequency Bias:  2.65
#
# 44
# TA00023
# Number of Observation:  49
# RMSE:  52.2
# MAE:  26.1
# Bias:  1.7
# Rsquare:  0.4
# Probability of Detection:  0.9583333333333334
# Probability of False Detection:  0.04
# False Alarm Rate:  0.041666666666666664
# Frequency Bias:  1.0
#
# 45
# TA00075
# Number of Observation:  48
# RMSE:  65.1
# MAE:  37.8
# Bias:  23.5
# Rsquare:  -0.6
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.20930232558139536
# Frequency Bias:  1.2647058823529411
#
# 46
# TA00031
# Number of Observation:  49
# RMSE:  84.6
# MAE:  62.1
# Bias:  55.8
# Rsquare:  -0.5
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.08333333333333333
# Frequency Bias:  1.0909090909090908
#
# 47
# TA00021
# Number of Observation:  52
# RMSE:  76.6
# MAE:  49.3
# Bias:  30.5
# Rsquare:  0.0
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.15555555555555556
# Frequency Bias:  1.1842105263157894
#
# 48
# TA00108
# Number of Observation:  47
# RMSE:  109.7
# MAE:  50.6
# Bias:  28.5
# Rsquare:  -3.2
# Probability of Detection:  0.9583333333333334
# Probability of False Detection:  0.0625
# False Alarm Rate:  0.25806451612903225
# Frequency Bias:  1.2916666666666667
#
# 49
# TA00029
# Number of Observation:  46
# RMSE:  71.7
# MAE:  49.6
# Bias:  15.0
# Rsquare:  -0.5
# Probability of Detection:  0.9629629629629629
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.3953488372093023
# Frequency Bias:  1.5925925925925926
#
# 50
# TA00130
# Number of Observation:  46
# RMSE:  55.3
# MAE:  36.1
# Bias:  -3.6
# Rsquare:  0.2
# Probability of Detection:  0.8285714285714286
# Probability of False Detection:  0.42857142857142855
# False Alarm Rate:  0.09375
# Frequency Bias:  0.9142857142857143
#
# 51
# 636860-99999
# Number of Observation:  49
# RMSE:  67.4
# MAE:  44.9
# Bias:  24.7
# Rsquare:  0.4
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.0625
# Frequency Bias:  1.0666666666666667
#
# 52
# TA00133
# Number of Observation:  46
# RMSE:  65.0
# MAE:  48.2
# Bias:  -31.6
# Rsquare:  0.5
# Probability of Detection:  0.8055555555555556
# Probability of False Detection:  0.6363636363636364
# False Alarm Rate:  0.17142857142857143
# Frequency Bias:  0.9722222222222222
#
# 53
# TA00155
# Number of Observation:  45
# RMSE:  49.8
# MAE:  29.0
# Bias:  -20.5
# Rsquare:  0.6
# Probability of Detection:  0.75
# Probability of False Detection:  0.30434782608695654
# False Alarm Rate:  0.045454545454545456
# Frequency Bias:  0.7857142857142857
#
# 54
# TA00157
# Number of Observation:  45
# RMSE:  51.2
# MAE:  28.6
# Bias:  -17.8
# Rsquare:  0.7
# Probability of Detection:  0.88
# Probability of False Detection:  0.15
# False Alarm Rate:  0.12
# Frequency Bias:  1.0
#
# 55
# TA00140
# Number of Observation:  46
# RMSE:  71.7
# MAE:  48.5
# Bias:  6.2
# Rsquare:  0.5
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.08888888888888889
# Frequency Bias:  1.0975609756097562
#
# 56
# 643830-99999
# Number of Observation:  59
# RMSE:  45.9
# MAE:  32.6
# Bias:  2.6
# Rsquare:  0.5
# Probability of Detection:  0.9615384615384616
# Probability of False Detection:  0.2857142857142857
# False Alarm Rate:  0.038461538461538464
# Frequency Bias:  1.0
#
# 57
# TA00054
# Number of Observation:  46
# RMSE:  52.6
# MAE:  35.4
# Bias:  10.4
# Rsquare:  0.5
# Probability of Detection:  0.9318181818181818
# Probability of False Detection:  0.75
# False Alarm Rate:  0.023809523809523808
# Frequency Bias:  0.9545454545454546
#
# 58
# 637050-99999
# Number of Observation:  60
# RMSE:  60.8
# MAE:  44.6
# Bias:  14.2
# Rsquare:  0.3
# Probability of Detection:  0.9591836734693877
# Probability of False Detection:  0.5
# False Alarm Rate:  0.16071428571428573
# Frequency Bias:  1.1428571428571428
#
# 59
# 643900-99999
# Number of Observation:  60
# RMSE:  77.6
# MAE:  50.7
# Bias:  18.7
# Rsquare:  0.1
# Probability of Detection:  0.8780487804878049
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.2
# Frequency Bias:  1.0975609756097562
#
# 60
# TA00134
# Number of Observation:  46
# RMSE:  95.9
# MAE:  54.2
# Bias:  45.1
# Rsquare:  -1.4
# Probability of Detection:  0.9714285714285714
# Probability of False Detection:  1.0
# False Alarm Rate:  0.24444444444444444
# Frequency Bias:  1.2857142857142858
#
# 61
# TA00131
# Number of Observation:  45
# RMSE:  80.7
# MAE:  55.0
# Bias:  -30.9
# Rsquare:  0.6
# Probability of Detection:  0.8048780487804879
# Probability of False Detection:  0.7272727272727273
# False Alarm Rate:  0.029411764705882353
# Frequency Bias:  0.8292682926829268
#
# 62
# TA00129
# Number of Observation:  45
# RMSE:  73.7
# MAE:  40.1
# Bias:  -15.8
# Rsquare:  0.1
# Probability of Detection:  0.7575757575757576
# Probability of False Detection:  0.4
# False Alarm Rate:  0.0
# Frequency Bias:  0.7575757575757576
#
# 63
# can-git-gr1.umva
# Number of Observation:  22
# RMSE:  43.6
# MAE:  34.4
# Bias:  14.5
# Rsquare:  0.8
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.0
# Frequency Bias:  1.0
#
# 64
# cub-nta-gr1.umva
# Number of Observation:  24
# RMSE:  58.4
# MAE:  42.7
# Bias:  28.8
# Rsquare:  0.3
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.13636363636363635
# Frequency Bias:  1.1578947368421053
#
# 65
# gas-mbu-gr3.umva
# Number of Observation:  24
# RMSE:  67.1
# MAE:  47.1
# Bias:  30.2
# Rsquare:  0.1
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.18181818181818182
# Frequency Bias:  1.2222222222222223
#
# 66
# gat-gat-gr3.umva
# Number of Observation:  24
# RMSE:  52.4
# MAE:  34.2
# Bias:  22.7
# Rsquare:  0.5
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.13636363636363635
# Frequency Bias:  1.1578947368421053
#
# 67
# git-git-gr1.umva
# Number of Observation:  22
# RMSE:  66.2
# MAE:  45.7
# Bias:  31.3
# Rsquare:  0.2
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.0
# Frequency Bias:  1.0
#
# 68
# git-kuw-gr1.umva
# Number of Observation:  23
# RMSE:  51.3
# MAE:  38.3
# Bias:  -6.1
# Rsquare:  0.7
# Probability of Detection:  0.9090909090909091
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.0
# Frequency Bias:  0.9090909090909091
#
# 69
# git-muh-gr1.umva
# Number of Observation:  23
# RMSE:  49.8
# MAE:  37.5
# Bias:  -0.2
# Rsquare:  0.7
# Probability of Detection:  0.9090909090909091
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.0
# Frequency Bias:  0.9090909090909091
#
# 70
# kaj-kaj-gr1.umva
# Number of Observation:  23
# RMSE:  51.0
# MAE:  41.8
# Bias:  24.5
# Rsquare:  0.5
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.18181818181818182
# Frequency Bias:  1.2222222222222223
#
# 71
# kan-mak-gr1.umva
# Number of Observation:  23
# RMSE:  52.0
# MAE:  35.2
# Bias:  10.0
# Rsquare:  0.5
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.0
# Frequency Bias:  1.0
#
# 72
# kar-karu-gr2.umva
# Number of Observation:  23
# RMSE:  65.0
# MAE:  48.2
# Bias:  16.5
# Rsquare:  0.4
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.13636363636363635
# Frequency Bias:  1.1578947368421053
#
# 73
# kav-kir-gr2.umva
# Number of Observation:  23
# RMSE:  39.7
# MAE:  31.3
# Bias:  17.1
# Rsquare:  0.8
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.047619047619047616
# Frequency Bias:  1.05
#
# 74
# kav-mun-gr1.umva
# Number of Observation:  24
# RMSE:  48.7
# MAE:  36.6
# Bias:  4.8
# Rsquare:  0.7
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.045454545454545456
# Frequency Bias:  1.0476190476190477
#
# 75
# kiv-nam-gr1.umva
# Number of Observation:  23
# RMSE:  59.5
# MAE:  43.6
# Bias:  17.0
# Rsquare:  0.4
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.045454545454545456
# Frequency Bias:  1.0476190476190477
#
# 76
# maga-mag-gr1.umva
# Number of Observation:  24
# RMSE:  42.5
# MAE:  33.7
# Bias:  14.9
# Rsquare:  0.8
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.18181818181818182
# Frequency Bias:  1.2222222222222223
#
# 77
# mas-nya-gr1.umva
# Number of Observation:  24
# RMSE:  79.8
# MAE:  43.2
# Bias:  9.6
# Rsquare:  0.3
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.09090909090909091
# Frequency Bias:  1.1
#
# 78
# may-may-gr2.umva
# Number of Observation:  24
# RMSE:  58.3
# MAE:  38.9
# Bias:  27.8
# Rsquare:  0.4
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.13636363636363635
# Frequency Bias:  1.1578947368421053
#
# 79
# mug-mugo-gr2.umva
# Number of Observation:  21
# RMSE:  49.9
# MAE:  35.9
# Bias:  11.4
# Rsquare:  0.5
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.10526315789473684
# Frequency Bias:  1.1176470588235294
#
# 80
# mug-nta-gr3.umva
# Number of Observation:  24
# RMSE:  54.5
# MAE:  39.4
# Bias:  15.6
# Rsquare:  0.6
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.14285714285714285
# Frequency Bias:  1.1666666666666667
#
# 81
# mug-rus-gr2.umva
# Number of Observation:  21
# RMSE:  55.3
# MAE:  40.8
# Bias:  15.5
# Rsquare:  0.5
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.15789473684210525
# Frequency Bias:  1.1875
#
# 82
# muhw-muh-gr1.umva
# Number of Observation:  23
# RMSE:  57.7
# MAE:  40.6
# Bias:  2.7
# Rsquare:  0.6
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.13636363636363635
# Frequency Bias:  1.1578947368421053
#
# 83
# mun-mun-gr2.umva
# Number of Observation:  23
# RMSE:  56.4
# MAE:  43.1
# Bias:  22.2
# Rsquare:  0.4
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.045454545454545456
# Frequency Bias:  1.0476190476190477
#
# 84
# mut-mak-gr2.umva
# Number of Observation:  23
# RMSE:  58.6
# MAE:  43.2
# Bias:  -7.7
# Rsquare:  0.7
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.047619047619047616
# Frequency Bias:  1.05
#
# 85
# ngu-nya-gr3.umva
# Number of Observation:  24
# RMSE:  70.5
# MAE:  47.1
# Bias:  5.9
# Rsquare:  0.4
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.22727272727272727
# Frequency Bias:  1.2941176470588236
#
# 86
# nyabi-ny-gr1.umva
# Number of Observation:  24
# RMSE:  51.8
# MAE:  38.1
# Bias:  25.2
# Rsquare:  0.5
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.045454545454545456
# Frequency Bias:  1.0476190476190477
#
# 87
# nya-mun-gr1.umva
# Number of Observation:  24
# RMSE:  50.2
# MAE:  37.8
# Bias:  23.0
# Rsquare:  0.6
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.045454545454545456
# Frequency Bias:  1.0476190476190477
#
# 88
# nye-nzo-gr1.umva
# Number of Observation:  24
# RMSE:  60.7
# MAE:  40.5
# Bias:  12.2
# Rsquare:  0.6
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.18181818181818182
# Frequency Bias:  1.2222222222222223
#
# 89
# ny-nyagi-gr1.umva
# Number of Observation:  24
# RMSE:  63.6
# MAE:  44.7
# Bias:  -13.0
# Rsquare:  0.6
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.045454545454545456
# Frequency Bias:  1.0476190476190477
#
# 90
# nzi-mas-gr1.umva
# Number of Observation:  24
# RMSE:  41.6
# MAE:  33.4
# Bias:  11.5
# Rsquare:  0.8
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.13636363636363635
# Frequency Bias:  1.1578947368421053
#
# 91
# rem-muy-gr1.umva
# Number of Observation:  24
# RMSE:  52.1
# MAE:  38.2
# Bias:  -9.7
# Rsquare:  0.7
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.0
# Frequency Bias:  1.0
#
# 92
# rug-kiv-gr1.umva
# Number of Observation:  24
# RMSE:  66.8
# MAE:  49.3
# Bias:  22.4
# Rsquare:  0.1
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.18181818181818182
# Frequency Bias:  1.2222222222222223
#
# 93
# rug-rug-gr2.umva
# Number of Observation:  24
# RMSE:  53.8
# MAE:  41.6
# Bias:  15.5
# Rsquare:  0.5
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.047619047619047616
# Frequency Bias:  1.05
#
# 94
# ruh-ruh-gr1.umva
# Number of Observation:  24
# RMSE:  68.7
# MAE:  46.2
# Bias:  26.5
# Rsquare:  0.2
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.045454545454545456
# Frequency Bias:  1.0476190476190477
#
# 95
# rwa-bug-gr1.umva
# Number of Observation:  23
# RMSE:  57.2
# MAE:  39.7
# Bias:  17.0
# Rsquare:  0.5
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.09523809523809523
# Frequency Bias:  1.105263157894737
#
# 96
# rwa-tab-gr3.umva
# Number of Observation:  24
# RMSE:  75.4
# MAE:  53.5
# Bias:  4.5
# Rsquare:  0.3
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.13636363636363635
# Frequency Bias:  1.1578947368421053
#
# 97
# sha-sha-gr1.umva
# Number of Observation:  24
# RMSE:  53.8
# MAE:  37.6
# Bias:  21.3
# Rsquare:  0.7
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.09090909090909091
# Frequency Bias:  1.1
#
# 98
# shi-rur-gr1.umva
# Number of Observation:  24
# RMSE:  34.7
# MAE:  23.8
# Bias:  10.3
# Rsquare:  0.9
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.0
# Frequency Bias:  1.0
#
# 99
# tab-tab-gr3.umva
# Number of Observation:  24
# RMSE:  71.5
# MAE:  50.8
# Bias:  18.6
# Rsquare:  0.3
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.13636363636363635
# Frequency Bias:  1.1578947368421053
#
# 100
# tem-rus-gr5.umva
# Number of Observation:  24
# RMSE:  33.2
# MAE:  23.7
# Bias:  8.0
# Rsquare:  0.8
# Probability of Detection:  0.95
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.09523809523809523
# Frequency Bias:  1.05
#
# 101
# yanz-kig-gr3.umva
# Number of Observation:  24
# RMSE:  61.5
# MAE:  46.9
# Bias:  -15.7
# Rsquare:  0.6
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.13636363636363635
# Frequency Bias:  1.1578947368421053
#
# 102
