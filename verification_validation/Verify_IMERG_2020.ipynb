# %%
import pandas as pd
import numpy as np

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy import stats

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
drop_columns = 'TA00075'


df_obs_daily = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_station_data_daily_v2_imerg.csv")
df_obs_daily = df_obs_daily.set_index('Unnamed: 0')
df_obs_daily = df_obs_daily.loc['2020-01-04':'2020-12-31']
df_obs_daily = df_obs_daily.drop(columns=drop_columns)


df_sat_daily = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_imerg_daily_v2.csv")
df_sat_daily = df_sat_daily.set_index('Unnamed: 0')
df_sat_daily = df_sat_daily.loc['2020-01-04':'2020-12-31']
df_sat_daily = df_sat_daily.drop(columns=drop_columns)


df_obs_metadata = pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/station_data/Final results_csv/station_list_final_v2.csv')
df_obs_metadata = df_obs_metadata.set_index('STNID')

# %%
index = pd.Index(['Lat', 'Lon', 'RMSE', 'MAE', 'Bias', 'PearsonR', 'SpearmanR', 'R2', 'Probability of Detection', 'Probability of False Detection', 'False Alarm Rate', 'Frequency Bias'], name="rows")
column = df_obs_daily.columns

daily_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)
monthly_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)

for station, station_id in enumerate(df_obs_daily.columns):
  print(station)
  if station == 101:
    continue
  
  obs_daily = df_obs_daily[station_id]  
  sat_daily = df_sat_daily[station_id]

  obs_daily = obs_daily.to_numpy(copy=True)
  sat_daily = sat_daily.to_numpy(copy=True)

  obs_daily = obs_daily[~np.isnan(obs_daily)]
  sat_daily = sat_daily[~np.isnan(sat_daily)]

  n_of_sample = len(obs_daily)

  rmse = mean_squared_error(obs_daily, sat_daily, squared=False)
  mae = mean_absolute_error(obs_daily, sat_daily)
  pearsonr = stats.pearsonr(obs_daily, sat_daily)
  spearmanr = stats.spearmanr(obs_daily, sat_daily)
  rsq = r2_score(obs_daily, sat_daily)

  # correlation_matrix = np.corrcoef(obs_daily, sat_daily)
  # correlation_xy = correlation_matrix[0,1]
  # rsq = correlation_xy**2

  bias = sat_daily - obs_daily
  bias = bias.mean()

  obs_daily_bool = obs_daily.copy()
  sat_daily_bool = sat_daily.copy()

  obs_daily_bool[obs_daily_bool < 1] = 0
  obs_daily_bool[obs_daily_bool >= 1] = 1

  sat_daily_bool[sat_daily_bool < 1] = 0
  sat_daily_bool[sat_daily_bool >= 1] = 1

  category = np.empty([n_of_sample])

  for i in range(n_of_sample):
    if obs_daily_bool[i] == 1 and sat_daily_bool[i] == 1:
      category[i] = 1
    elif obs_daily_bool[i] == 1 and sat_daily_bool[i] == 0:
      category[i] = 2
    elif obs_daily_bool[i] == 0 and sat_daily_bool[i] == 1:
      category[i] = 3
    elif obs_daily_bool[i] == 0 and sat_daily_bool[i] == 0:
      category[i] = 4

  hit = np.count_nonzero(category == 1)
  miss = np.count_nonzero(category == 2)
  false_alarm = np.count_nonzero(category == 3)
  correct_negative = np.count_nonzero(category == 4)

  pod = hit/(hit + miss)
  pofd = miss/(miss+correct_negative)
  far = false_alarm/(hit + false_alarm)
  freq_bias = (hit+false_alarm)/(hit+miss)

  daily_metrics_df[station_id].loc['Lat'] = df_obs_metadata['LATITUDE'].loc[station_id]
  daily_metrics_df[station_id].loc['Lon'] = df_obs_metadata['LONGITUDE'].loc[station_id]
  daily_metrics_df[station_id].loc['RMSE'] = round(rmse,2)
  daily_metrics_df[station_id].loc['MAE'] = round(mae,2)
  daily_metrics_df[station_id].loc['Bias'] = round(bias,2)
  daily_metrics_df[station_id].loc['PearsonR'] = round(pearsonr[0],2)
  daily_metrics_df[station_id].loc['SpearmanR'] = round(spearmanr[0],2)
  daily_metrics_df[station_id].loc['R2'] = round(rsq,2)
  daily_metrics_df[station_id].loc['Probability of Detection'] = round(pod,2)
  daily_metrics_df[station_id].loc['Probability of False Detection'] = round(pofd,2)
  daily_metrics_df[station_id].loc['False Alarm Rate'] = round(far,2)
  daily_metrics_df[station_id].loc['Frequency Bias'] = round(freq_bias,2)
                                  
  print(station_id)
  print("Number of Observation: ", n_of_sample)
  print("RMSE: ", str(round(rmse,1)))
  print("MAE: ", str(round(mae,1)))
  print("Bias: ", str(round(bias,1)))
  print("Rsquare: ", str(round(rsq,1)))
  print("Probability of Detection: ", pod)
  print("Probability of False Detection: ", pofd)
  print("False Alarm Rate: ", far)
  print("Frequency Bias: ", freq_bias)


  # # print(obs_daily)
  # # print(sat_daily)

  # # print(obs_daily_bool)
  # # print(sat_daily_bool)
  print(" ")

  # obs_monthly = df_obs_monthly[station_id]
  # sat_monthly = df_sat_monthly[station_id]

  # obs_monthly = obs_monthly.to_numpy()
  # sat_monthly = sat_monthly.to_numpy()

  # print(station, station_id)

daily_metrics_df = daily_metrics_df.T
daily_metrics_df.to_csv('/content/gdrive/MyDrive/rainfall-forecast/verification_validation/metrics/metrics_imerg_daily_2020.csv')
# Out:
# 0
# TA00073
# Number of Observation:  363
# RMSE:  5.0
# MAE:  2.0
# Bias:  -0.0
# Rsquare:  -0.2
# Probability of Detection:  0.6633663366336634
# Probability of False Detection:  0.1328125
# False Alarm Rate:  0.37383177570093457
# Frequency Bias:  1.0594059405940595
#
# 1
# TA00024
# Number of Observation:  363
# RMSE:  7.5
# MAE:  2.4
# Bias:  0.8
# Rsquare:  -0.6
# Probability of Detection:  0.5596330275229358
# Probability of False Detection:  0.1672473867595819
# False Alarm Rate:  0.19736842105263158
# Frequency Bias:  0.6972477064220184
#
# 2
# TA00026
# Number of Observation:  363
# RMSE:  6.9
# MAE:  3.6
# Bias:  1.4
# Rsquare:  -0.1
# Probability of Detection:  0.8653846153846154
# Probability of False Detection:  0.1044776119402985
# False Alarm Rate:  0.6069868995633187
# Frequency Bias:  2.201923076923077
#
# 3
# TA00070
# Number of Observation:  362
# RMSE:  7.7
# MAE:  3.2
# Bias:  -1.6
# Rsquare:  0.3
# Probability of Detection:  0.44537815126050423
# Probability of False Detection:  0.22837370242214533
# False Alarm Rate:  0.273972602739726
# Frequency Bias:  0.6134453781512605
#
# 4
# TA00071
# Number of Observation:  363
# RMSE:  6.9
# MAE:  2.5
# Bias:  1.1
# Rsquare:  -1.1
# Probability of Detection:  0.2653061224489796
# Probability of False Detection:  0.1258741258741259
# False Alarm Rate:  0.8311688311688312
# Frequency Bias:  1.5714285714285714
#
# 5
# 638940-99999
# Number of Observation:  353
# RMSE:  14.6
# MAE:  5.8
# Bias:  -0.6
# Rsquare:  0.1
# Probability of Detection:  0.65625
# Probability of False Detection:  0.1658291457286432
# False Alarm Rate:  0.5909090909090909
# Frequency Bias:  1.6041666666666667
#
# 6
# 637290-99999
# Number of Observation:  363
# RMSE:  20.6
# MAE:  8.8
# Bias:  -1.0
# Rsquare:  -0.2
# Probability of Detection:  0.68125
# Probability of False Detection:  0.2512315270935961
# False Alarm Rate:  0.31875
# Frequency Bias:  1.0
#
# 7
# 638700-99999
# Number of Observation:  358
# RMSE:  14.0
# MAE:  5.9
# Bias:  -0.0
# Rsquare:  -0.3
# Probability of Detection:  0.6936936936936937
# Probability of False Detection:  0.16267942583732056
# False Alarm Rate:  0.48322147651006714
# Frequency Bias:  1.3423423423423424
#
# 8
# 639710-99999
# Number of Observation:  357
# RMSE:  10.5
# MAE:  3.7
# Bias:  -0.7
# Rsquare:  0.1
# Probability of Detection:  0.6301369863013698
# Probability of False Detection:  0.09574468085106383
# False Alarm Rate:  0.38666666666666666
# Frequency Bias:  1.0273972602739727
#
# 9
# 638620-99999
# Number of Observation:  354
# RMSE:  11.2
# MAE:  3.6
# Bias:  -0.1
# Rsquare:  0.2
# Probability of Detection:  0.8235294117647058
# Probability of False Detection:  0.04897959183673469
# False Alarm Rate:  0.48623853211009177
# Frequency Bias:  1.6029411764705883
#
# 10
# 638870-99999
# Number of Observation:  357
# RMSE:  8.6
# MAE:  3.3
# Bias:  0.2
# Rsquare:  0.2
# Probability of Detection:  0.9425287356321839
# Probability of False Detection:  0.023696682464454975
# False Alarm Rate:  0.4383561643835616
# Frequency Bias:  1.6781609195402298
#
# 11
# 637560-99999
# Number of Observation:  353
# RMSE:  11.9
# MAE:  5.2
# Bias:  2.4
# Rsquare:  -1.3
# Probability of Detection:  0.7981651376146789
# Probability of False Detection:  0.10526315789473684
# False Alarm Rate:  0.3958333333333333
# Frequency Bias:  1.3211009174311927
#
# 12
# 637910-99999
# Number of Observation:  355
# RMSE:  7.7
# MAE:  2.3
# Bias:  -0.4
# Rsquare:  0.2
# Probability of Detection:  0.5970149253731343
# Probability of False Detection:  0.09310344827586207
# False Alarm Rate:  0.38461538461538464
# Frequency Bias:  0.9701492537313433
#
# 13
# 638810-99999
# Number of Observation:  355
# RMSE:  6.9
# MAE:  3.2
# Bias:  0.4
# Rsquare:  0.1
# Probability of Detection:  0.8316831683168316
# Probability of False Detection:  0.07692307692307693
# False Alarm Rate:  0.373134328358209
# Frequency Bias:  1.3267326732673268
#
# 14
# 638010-99999
# Number of Observation:  351
# RMSE:  15.4
# MAE:  6.0
# Bias:  1.5
# Rsquare:  -0.1
# Probability of Detection:  0.7127659574468085
# Probability of False Detection:  0.12980769230769232
# False Alarm Rate:  0.5314685314685315
# Frequency Bias:  1.5212765957446808
#
# 15
# 639620-99999
# Number of Observation:  349
# RMSE:  16.0
# MAE:  4.8
# Bias:  -2.1
# Rsquare:  0.0
# Probability of Detection:  0.7333333333333333
# Probability of False Detection:  0.0749063670411985
# False Alarm Rate:  0.32926829268292684
# Frequency Bias:  1.0933333333333333
#
# 16
# 638660-99999
# Number of Observation:  350
# RMSE:  11.6
# MAE:  4.1
# Bias:  -0.5
# Rsquare:  -0.1
# Probability of Detection:  0.6404494382022472
# Probability of False Detection:  0.14096916299559473
# False Alarm Rate:  0.5365853658536586
# Frequency Bias:  1.3820224719101124
#
# 17
# 638320-99999
# Number of Observation:  357
# RMSE:  18.2
# MAE:  6.9
# Bias:  -1.5
# Rsquare:  -0.1
# Probability of Detection:  0.7264150943396226
# Probability of False Detection:  0.12393162393162394
# False Alarm Rate:  0.37398373983739835
# Frequency Bias:  1.1603773584905661
#
# 18
# 637330-99999
# Number of Observation:  351
# RMSE:  11.8
# MAE:  5.1
# Bias:  0.6
# Rsquare:  -0.1
# Probability of Detection:  0.7614678899082569
# Probability of False Detection:  0.13612565445026178
# False Alarm Rate:  0.48125
# Frequency Bias:  1.4678899082568808
#
# 19
# TA00057
# Number of Observation:  363
# RMSE:  9.2
# MAE:  3.9
# Bias:  3.4
# Rsquare:  -19.1
# Probability of Detection:  0.7017543859649122
# Probability of False Detection:  0.1
# False Alarm Rate:  0.7927461139896373
# Frequency Bias:  3.3859649122807016
#
# 20
# TA00020
# Number of Observation:  286
# RMSE:  2.9
# MAE:  0.9
# Bias:  0.0
# Rsquare:  0.1
# Probability of Detection:  0.6176470588235294
# Probability of False Detection:  0.05371900826446281
# False Alarm Rate:  0.5227272727272727
# Frequency Bias:  1.2941176470588236
#
# 21
# 638200-99999
# Number of Observation:  336
# RMSE:  7.7
# MAE:  3.0
# Bias:  -0.8
# Rsquare:  0.1
# Probability of Detection:  0.37623762376237624
# Probability of False Detection:  0.23333333333333334
# False Alarm Rate:  0.42424242424242425
# Frequency Bias:  0.6534653465346535
#
# 22
# 637170-99999
# Number of Observation:  355
# RMSE:  10.3
# MAE:  4.1
# Bias:  -1.1
# Rsquare:  0.0
# Probability of Detection:  0.4552238805970149
# Probability of False Detection:  0.29918032786885246
# False Alarm Rate:  0.45045045045045046
# Frequency Bias:  0.8283582089552238
#
# 23
# TA00019
# Number of Observation:  362
# RMSE:  10.4
# MAE:  5.1
# Bias:  3.6
# Rsquare:  -1.6
# Probability of Detection:  0.8828828828828829
# Probability of False Detection:  0.08333333333333333
# False Alarm Rate:  0.5242718446601942
# Frequency Bias:  1.8558558558558558
#
# 24
# 637930-99999
# Number of Observation:  352
# RMSE:  11.3
# MAE:  2.8
# Bias:  -0.5
# Rsquare:  0.0
# Probability of Detection:  0.6607142857142857
# Probability of False Detection:  0.07116104868913857
# False Alarm Rate:  0.5647058823529412
# Frequency Bias:  1.5178571428571428
#
# 25
# TA00076
# Number of Observation:  265
# RMSE:  9.1
# MAE:  5.1
# Bias:  1.4
# Rsquare:  0.1
# Probability of Detection:  0.9316239316239316
# Probability of False Detection:  0.0898876404494382
# False Alarm Rate:  0.3806818181818182
# Frequency Bias:  1.5042735042735043
#
# 26
# TA00069
# Number of Observation:  274
# RMSE:  6.8
# MAE:  2.8
# Bias:  -0.8
# Rsquare:  -0.1
# Probability of Detection:  0.25333333333333335
# Probability of False Detection:  0.2413793103448276
# False Alarm Rate:  0.5476190476190477
# Frequency Bias:  0.56
#
# 27
# TA00074
# Number of Observation:  363
# RMSE:  8.7
# MAE:  3.4
# Bias:  -0.9
# Rsquare:  0.5
# Probability of Detection:  0.5730337078651685
# Probability of False Detection:  0.14232209737827714
# False Alarm Rate:  0.46875
# Frequency Bias:  1.0786516853932584
#
# 28
# 636610-99999
# Number of Observation:  355
# RMSE:  11.7
# MAE:  6.4
# Bias:  0.2
# Rsquare:  -0.3
# Probability of Detection:  0.7530120481927711
# Probability of False Detection:  0.2611464968152866
# False Alarm Rate:  0.3686868686868687
# Frequency Bias:  1.1927710843373494
#
# 29
# 637200-99999
# Number of Observation:  344
# RMSE:  12.7
# MAE:  4.8
# Bias:  -2.3
# Rsquare:  -0.1
# Probability of Detection:  0.49572649572649574
# Probability of False Detection:  0.21851851851851853
# False Alarm Rate:  0.21621621621621623
# Frequency Bias:  0.6324786324786325
#
# 30
# 643870-99999
# Number of Observation:  333
# RMSE:  20.2
# MAE:  7.9
# Bias:  -0.4
# Rsquare:  -0.2
# Probability of Detection:  0.7064220183486238
# Probability of False Detection:  0.25196850393700787
# False Alarm Rate:  0.6262135922330098
# Frequency Bias:  1.889908256880734
#
# 31
# 636950-99999
# Number of Observation:  347
# RMSE:  13.4
# MAE:  5.2
# Bias:  -1.6
# Rsquare:  0.1
# Probability of Detection:  0.6190476190476191
# Probability of False Detection:  0.21428571428571427
# False Alarm Rate:  0.36585365853658536
# Frequency Bias:  0.9761904761904762
#
# 32
# 637400-99999
# Number of Observation:  325
# RMSE:  7.7
# MAE:  3.8
# Bias:  1.3
# Rsquare:  -0.1
# Probability of Detection:  0.6951219512195121
# Probability of False Detection:  0.16129032258064516
# False Alarm Rate:  0.6647058823529411
# Frequency Bias:  2.073170731707317
#
# 33
# TA00056
# Number of Observation:  347
# RMSE:  6.7
# MAE:  2.4
# Bias:  -0.9
# Rsquare:  0.5
# Probability of Detection:  0.55
# Probability of False Detection:  0.1624548736462094
# False Alarm Rate:  0.21428571428571427
# Frequency Bias:  0.7
#
# 34
# 637140-99999
# Number of Observation:  343
# RMSE:  7.3
# MAE:  3.7
# Bias:  -0.1
# Rsquare:  0.1
# Probability of Detection:  0.7163120567375887
# Probability of False Detection:  0.21390374331550802
# False Alarm Rate:  0.3525641025641026
# Frequency Bias:  1.1063829787234043
#
# 35
# TA00025
# Number of Observation:  363
# RMSE:  7.9
# MAE:  2.7
# Bias:  1.5
# Rsquare:  -0.6
# Probability of Detection:  0.6521739130434783
# Probability of False Detection:  0.06557377049180328
# False Alarm Rate:  0.7478991596638656
# Frequency Bias:  2.5869565217391304
#
# 36
# 643800-99999
# Number of Observation:  318
# RMSE:  11.1
# MAE:  5.8
# Bias:  1.4
# Rsquare:  -0.6
# Probability of Detection:  0.7265625
# Probability of False Detection:  0.2413793103448276
# False Alarm Rate:  0.4624277456647399
# Frequency Bias:  1.3515625
#
# 37
# 643810-99999
# Number of Observation:  328
# RMSE:  6.6
# MAE:  3.6
# Bias:  0.7
# Rsquare:  -0.6
# Probability of Detection:  0.6173913043478261
# Probability of False Detection:  0.25287356321839083
# False Alarm Rate:  0.538961038961039
# Frequency Bias:  1.3391304347826087
#
# 38
# TA00033
# Number of Observation:  363
# RMSE:  12.5
# MAE:  6.0
# Bias:  3.1
# Rsquare:  -0.6
# Probability of Detection:  0.8120300751879699
# Probability of False Detection:  0.12953367875647667
# False Alarm Rate:  0.36470588235294116
# Frequency Bias:  1.2781954887218046
#
# 39
# TA00072
# Number of Observation:  193
# RMSE:  7.5
# MAE:  3.1
# Bias:  0.8
# Rsquare:  -0.1
# Probability of Detection:  0.66
# Probability of False Detection:  0.12056737588652482
# False Alarm Rate:  0.36538461538461536
# Frequency Bias:  1.04
#
# 40
# 636120-99999
# Number of Observation:  358
# RMSE:  8.5
# MAE:  1.8
# Bias:  0.0
# Rsquare:  0.4
# Probability of Detection:  0.7209302325581395
# Probability of False Detection:  0.04081632653061224
# False Alarm Rate:  0.515625
# Frequency Bias:  1.4883720930232558
#
# 41
# TA00066
# Number of Observation:  208
# RMSE:  5.3
# MAE:  2.1
# Bias:  -1.0
# Rsquare:  -0.2
# Probability of Detection:  0.5
# Probability of False Detection:  0.13872832369942195
# False Alarm Rate:  0.3142857142857143
# Frequency Bias:  0.7291666666666666
#
# 42
# 637990-99999
# Number of Observation:  336
# RMSE:  6.6
# MAE:  2.6
# Bias:  0.2
# Rsquare:  -0.1
# Probability of Detection:  0.43820224719101125
# Probability of False Detection:  0.1937984496124031
# False Alarm Rate:  0.5
# Frequency Bias:  0.8764044943820225
#
# 43
# 637420-99999
# Number of Observation:  320
# RMSE:  9.6
# MAE:  3.6
# Bias:  0.4
# Rsquare:  -0.0
# Probability of Detection:  0.6266666666666667
# Probability of False Detection:  0.15135135135135136
# False Alarm Rate:  0.6518518518518519
# Frequency Bias:  1.8
#
# 44
# TA00023
# Number of Observation:  363
# RMSE:  4.6
# MAE:  1.3
# Bias:  0.7
# Rsquare:  -0.2
# Probability of Detection:  0.6428571428571429
# Probability of False Detection:  0.05136986301369863
# False Alarm Rate:  0.6197183098591549
# Frequency Bias:  1.6904761904761905
#
# 45
# TA00031
# Number of Observation:  149
# RMSE:  13.5
# MAE:  7.1
# Bias:  4.9
# Rsquare:  -2.0
# Probability of Detection:  0.9180327868852459
# Probability of False Detection:  0.11627906976744186
# False Alarm Rate:  0.4716981132075472
# Frequency Bias:  1.7377049180327868
#
# 46
# TA00021
# Number of Observation:  284
# RMSE:  9.6
# MAE:  4.9
# Bias:  3.2
# Rsquare:  -0.4
# Probability of Detection:  0.7254901960784313
# Probability of False Detection:  0.09929078014184398
# False Alarm Rate:  0.7412587412587412
# Frequency Bias:  2.803921568627451
#
# 47
# TA00108
# Number of Observation:  343
# RMSE:  9.7
# MAE:  2.7
# Bias:  1.1
# Rsquare:  -0.5
# Probability of Detection:  0.6304347826086957
# Probability of False Detection:  0.06159420289855073
# False Alarm Rate:  0.5671641791044776
# Frequency Bias:  1.4565217391304348
#
# 48
# TA00029
# Number of Observation:  363
# RMSE:  5.3
# MAE:  2.8
# Bias:  0.7
# Rsquare:  -1.4
# Probability of Detection:  0.5128205128205128
# Probability of False Detection:  0.3377777777777778
# False Alarm Rate:  0.42028985507246375
# Frequency Bias:  0.8846153846153846
#
# 49
# TA00130
# Number of Observation:  363
# RMSE:  8.8
# MAE:  2.2
# Bias:  0.6
# Rsquare:  -0.4
# Probability of Detection:  0.4791666666666667
# Probability of False Detection:  0.08741258741258741
# False Alarm Rate:  0.7012987012987013
# Frequency Bias:  1.6041666666666667
#
# 50
# 636860-99999
# Number of Observation:  338
# RMSE:  15.1
# MAE:  6.8
# Bias:  2.2
# Rsquare:  -1.3
# Probability of Detection:  0.8111888111888111
# Probability of False Detection:  0.19285714285714287
# False Alarm Rate:  0.41414141414141414
# Frequency Bias:  1.3846153846153846
#
# 51
# TA00133
# Number of Observation:  363
# RMSE:  8.3
# MAE:  3.0
# Bias:  -0.7
# Rsquare:  0.2
# Probability of Detection:  0.49504950495049505
# Probability of False Detection:  0.1827956989247312
# False Alarm Rate:  0.40476190476190477
# Frequency Bias:  0.8316831683168316
#
# 52
# TA00155
# Number of Observation:  363
# RMSE:  6.9
# MAE:  1.5
# Bias:  -0.6
# Rsquare:  0.4
# Probability of Detection:  0.6290322580645161
# Probability of False Detection:  0.07590759075907591
# False Alarm Rate:  0.35
# Frequency Bias:  0.967741935483871
#
# 53
# TA00157
# Number of Observation:  363
# RMSE:  6.0
# MAE:  1.7
# Bias:  -0.7
# Rsquare:  0.5
# Probability of Detection:  0.6666666666666666
# Probability of False Detection:  0.06375838926174497
# False Alarm Rate:  0.4153846153846154
# Frequency Bias:  1.1403508771929824
#
# 54
# TA00140
# Number of Observation:  338
# RMSE:  11.5
# MAE:  5.5
# Bias:  -0.7
# Rsquare:  0.1
# Probability of Detection:  0.7847222222222222
# Probability of False Detection:  0.20261437908496732
# False Alarm Rate:  0.3891891891891892
# Frequency Bias:  1.2847222222222223
#
# 55
# 643830-99999
# Number of Observation:  294
# RMSE:  13.3
# MAE:  6.0
# Bias:  -0.7
# Rsquare:  -0.4
# Probability of Detection:  0.6115702479338843
# Probability of False Detection:  0.28484848484848485
# False Alarm Rate:  0.4263565891472868
# Frequency Bias:  1.0661157024793388
#
# 56
# TA00054
# Number of Observation:  136
# RMSE:  6.1
# MAE:  3.3
# Bias:  0.2
# Rsquare:  0.6
# Probability of Detection:  0.84
# Probability of False Detection:  0.11764705882352941
# False Alarm Rate:  0.38235294117647056
# Frequency Bias:  1.36
#
# 57
# 637050-99999
# Number of Observation:  216
# RMSE:  9.8
# MAE:  3.8
# Bias:  1.7
# Rsquare:  -1.1
# Probability of Detection:  0.5121951219512195
# Probability of False Detection:  0.13333333333333333
# False Alarm Rate:  0.6818181818181818
# Frequency Bias:  1.6097560975609757
#
# 58
# 643900-99999
# Number of Observation:  205
# RMSE:  8.5
# MAE:  3.1
# Bias:  2.5
# Rsquare:  -19.8
# Probability of Detection:  0.5714285714285714
# Probability of False Detection:  0.06870229007633588
# False Alarm Rate:  0.8378378378378378
# Frequency Bias:  3.5238095238095237
#
# 59
# TA00134
# Number of Observation:  252
# RMSE:  5.5
# MAE:  2.7
# Bias:  1.4
# Rsquare:  -0.7
# Probability of Detection:  0.6551724137931034
# Probability of False Detection:  0.15267175572519084
# False Alarm Rate:  0.6859504132231405
# Frequency Bias:  2.086206896551724
#
# 60
# TA00131
# Number of Observation:  361
# RMSE:  8.0
# MAE:  3.1
# Bias:  -1.0
# Rsquare:  0.4
# Probability of Detection:  0.41836734693877553
# Probability of False Detection:  0.1986062717770035
# False Alarm Rate:  0.44594594594594594
# Frequency Bias:  0.7551020408163265
#
# 61
# TA00129
# Number of Observation:  363
# RMSE:  4.1
# MAE:  1.4
# Bias:  0.2
# Rsquare:  -0.3
# Probability of Detection:  0.64
# Probability of False Detection:  0.059800664451827246
# False Alarm Rate:  0.4838709677419355
# Frequency Bias:  1.24
#
# 62
# can-git-gr1.umva
# Number of Observation:  288
# RMSE:  11.4
# MAE:  5.8
# Bias:  0.7
# Rsquare:  -0.9
# Probability of Detection:  0.7553191489361702
# Probability of False Detection:  0.14743589743589744
# False Alarm Rate:  0.4621212121212121
# Frequency Bias:  1.4042553191489362
#
# 63
# cub-nta-gr1.umva
# Number of Observation:  299
# RMSE:  11.0
# MAE:  5.1
# Bias:  1.5
# Rsquare:  -1.5
# Probability of Detection:  0.7676767676767676
# Probability of False Detection:  0.1329479768786127
# False Alarm Rate:  0.3968253968253968
# Frequency Bias:  1.2727272727272727
#
# 64
# gas-mbu-gr3.umva
# Number of Observation:  301
# RMSE:  11.3
# MAE:  5.2
# Bias:  1.6
# Rsquare:  -1.6
# Probability of Detection:  0.7604166666666666
# Probability of False Detection:  0.13068181818181818
# False Alarm Rate:  0.416
# Frequency Bias:  1.3020833333333333
#
# 65
# gat-gat-gr3.umva
# Number of Observation:  310
# RMSE:  9.5
# MAE:  4.5
# Bias:  0.8
# Rsquare:  -0.8
# Probability of Detection:  0.7238095238095238
# Probability of False Detection:  0.15508021390374332
# False Alarm Rate:  0.3821138211382114
# Frequency Bias:  1.1714285714285715
#
# 66
# git-git-gr1.umva
# Number of Observation:  283
# RMSE:  13.4
# MAE:  6.3
# Bias:  1.6
# Rsquare:  -1.8
# Probability of Detection:  0.7078651685393258
# Probability of False Detection:  0.17105263157894737
# False Alarm Rate:  0.5190839694656488
# Frequency Bias:  1.4719101123595506
#
# 67
# git-kuw-gr1.umva
# Number of Observation:  282
# RMSE:  13.1
# MAE:  6.6
# Bias:  -0.4
# Rsquare:  -0.5
# Probability of Detection:  0.7368421052631579
# Probability of False Detection:  0.1497005988023952
# False Alarm Rate:  0.391304347826087
# Frequency Bias:  1.2105263157894737
#
# 68
# git-muh-gr1.umva
# Number of Observation:  279
# RMSE:  13.0
# MAE:  6.6
# Bias:  -0.2
# Rsquare:  -0.6
# Probability of Detection:  0.7204301075268817
# Probability of False Detection:  0.1566265060240964
# False Alarm Rate:  0.40707964601769914
# Frequency Bias:  1.2150537634408602
#
# 69
# kaj-kaj-gr1.umva
# Number of Observation:  299
# RMSE:  11.9
# MAE:  5.5
# Bias:  0.8
# Rsquare:  -1.0
# Probability of Detection:  0.696969696969697
# Probability of False Detection:  0.16666666666666666
# False Alarm Rate:  0.42016806722689076
# Frequency Bias:  1.202020202020202
#
# 70
# kan-mak-gr1.umva
# Number of Observation:  289
# RMSE:  11.3
# MAE:  5.6
# Bias:  0.2
# Rsquare:  -1.0
# Probability of Detection:  0.6923076923076923
# Probability of False Detection:  0.19161676646706588
# False Alarm Rate:  0.4098360655737705
# Frequency Bias:  1.1730769230769231
#
# 71
# kar-karu-gr2.umva
# Number of Observation:  297
# RMSE:  12.3
# MAE:  5.6
# Bias:  0.4
# Rsquare:  -0.7
# Probability of Detection:  0.7619047619047619
# Probability of False Detection:  0.11235955056179775
# False Alarm Rate:  0.46218487394957986
# Frequency Bias:  1.4166666666666667
#
# 72
# kav-kir-gr2.umva
# Number of Observation:  290
# RMSE:  11.0
# MAE:  5.5
# Bias:  1.0
# Rsquare:  -0.9
# Probability of Detection:  0.7555555555555555
# Probability of False Detection:  0.14012738853503184
# False Alarm Rate:  0.48872180451127817
# Frequency Bias:  1.4777777777777779
#
# 73
# kav-mun-gr1.umva
# Number of Observation:  314
# RMSE:  11.5
# MAE:  5.4
# Bias:  0.4
# Rsquare:  -1.3
# Probability of Detection:  0.717391304347826
# Probability of False Detection:  0.24375
# False Alarm Rate:  0.35714285714285715
# Frequency Bias:  1.1159420289855073
#
# 74
# kiv-nam-gr1.umva
# Number of Observation:  289
# RMSE:  13.8
# MAE:  6.5
# Bias:  1.5
# Rsquare:  -1.8
# Probability of Detection:  0.7115384615384616
# Probability of False Detection:  0.19480519480519481
# False Alarm Rate:  0.45185185185185184
# Frequency Bias:  1.2980769230769231
#
# 75
# maga-mag-gr1.umva
# Number of Observation:  302
# RMSE:  10.6
# MAE:  5.1
# Bias:  0.9
# Rsquare:  -0.7
# Probability of Detection:  0.7428571428571429
# Probability of False Detection:  0.15517241379310345
# False Alarm Rate:  0.390625
# Frequency Bias:  1.2190476190476192
#
# 76
# mas-nya-gr1.umva
# Number of Observation:  306
# RMSE:  11.9
# MAE:  5.7
# Bias:  -0.1
# Rsquare:  -0.7
# Probability of Detection:  0.6991150442477876
# Probability of False Detection:  0.1837837837837838
# False Alarm Rate:  0.34710743801652894
# Frequency Bias:  1.0707964601769913
#
# 77
# may-may-gr2.umva
# Number of Observation:  293
# RMSE:  10.6
# MAE:  5.0
# Bias:  1.7
# Rsquare:  -1.6
# Probability of Detection:  0.7708333333333334
# Probability of False Detection:  0.13496932515337423
# False Alarm Rate:  0.4307692307692308
# Frequency Bias:  1.3541666666666667
#
# 78
# mug-mugo-gr2.umva
# Number of Observation:  243
# RMSE:  11.7
# MAE:  4.9
# Bias:  0.9
# Rsquare:  -1.0
# Probability of Detection:  0.7272727272727273
# Probability of False Detection:  0.11538461538461539
# False Alarm Rate:  0.4482758620689655
# Frequency Bias:  1.3181818181818181
#
# 79
# mug-nta-gr3.umva
# Number of Observation:  304
# RMSE:  14.6
# MAE:  6.1
# Bias:  0.7
# Rsquare:  -1.5
# Probability of Detection:  0.68
# Probability of False Detection:  0.17391304347826086
# False Alarm Rate:  0.43333333333333335
# Frequency Bias:  1.2
#
# 80
# mug-rus-gr2.umva
# Number of Observation:  244
# RMSE:  12.5
# MAE:  5.3
# Bias:  0.5
# Rsquare:  -0.7
# Probability of Detection:  0.746268656716418
# Probability of False Detection:  0.11038961038961038
# False Alarm Rate:  0.4444444444444444
# Frequency Bias:  1.3432835820895523
#
# 81
# muhw-muh-gr1.umva
# Number of Observation:  297
# RMSE:  12.9
# MAE:  6.1
# Bias:  -0.0
# Rsquare:  -0.6
# Probability of Detection:  0.7472527472527473
# Probability of False Detection:  0.12921348314606743
# False Alarm Rate:  0.42857142857142855
# Frequency Bias:  1.3076923076923077
#
# 82
# mun-mun-gr2.umva
# Number of Observation:  292
# RMSE:  13.2
# MAE:  6.2
# Bias:  1.2
# Rsquare:  -1.9
# Probability of Detection:  0.7314814814814815
# Probability of False Detection:  0.18354430379746836
# False Alarm Rate:  0.41044776119402987
# Frequency Bias:  1.2407407407407407
#
# 83
# mut-mak-gr2.umva
# Number of Observation:  291
# RMSE:  12.9
# MAE:  6.3
# Bias:  -0.8
# Rsquare:  -0.9
# Probability of Detection:  0.7142857142857143
# Probability of False Detection:  0.20253164556962025
# False Alarm Rate:  0.39849624060150374
# Frequency Bias:  1.1875
#
# 84
# ngu-nya-gr3.umva
# Number of Observation:  307
# RMSE:  10.4
# MAE:  5.1
# Bias:  0.3
# Rsquare:  -0.9
# Probability of Detection:  0.6880733944954128
# Probability of False Detection:  0.18681318681318682
# False Alarm Rate:  0.4
# Frequency Bias:  1.146788990825688
#
# 85
# nyabi-ny-gr1.umva
# Number of Observation:  288
# RMSE:  13.2
# MAE:  6.4
# Bias:  1.2
# Rsquare:  -1.7
# Probability of Detection:  0.7078651685393258
# Probability of False Detection:  0.16560509554140126
# False Alarm Rate:  0.5190839694656488
# Frequency Bias:  1.4719101123595506
#
# 86
# nya-mun-gr1.umva
# Number of Observation:  291
# RMSE:  13.1
# MAE:  6.4
# Bias:  1.2
# Rsquare:  -1.7
# Probability of Detection:  0.7096774193548387
# Probability of False Detection:  0.16875
# False Alarm Rate:  0.4961832061068702
# Frequency Bias:  1.4086021505376345
#
# 87
# nye-nzo-gr1.umva
# Number of Observation:  306
# RMSE:  11.1
# MAE:  5.4
# Bias:  -0.1
# Rsquare:  -0.5
# Probability of Detection:  0.69
# Probability of False Detection:  0.1657754010695187
# False Alarm Rate:  0.42016806722689076
# Frequency Bias:  1.19
#
# 88
# ny-nyagi-gr1.umva
# Number of Observation:  295
# RMSE:  12.8
# MAE:  6.0
# Bias:  -0.4
# Rsquare:  -1.0
# Probability of Detection:  0.6910569105691057
# Probability of False Detection:  0.24358974358974358
# False Alarm Rate:  0.38848920863309355
# Frequency Bias:  1.1300813008130082
#
# 89
# nzi-mas-gr1.umva
# Number of Observation:  306
# RMSE:  10.9
# MAE:  5.3
# Bias:  0.2
# Rsquare:  -0.5
# Probability of Detection:  0.7657657657657657
# Probability of False Detection:  0.14689265536723164
# False Alarm Rate:  0.34108527131782945
# Frequency Bias:  1.162162162162162
#
# 90
# rem-muy-gr1.umva
# Number of Observation:  290
# RMSE:  13.2
# MAE:  6.5
# Bias:  -0.2
# Rsquare:  -1.1
# Probability of Detection:  0.71875
# Probability of False Detection:  0.25
# False Alarm Rate:  0.3698630136986301
# Frequency Bias:  1.140625
#
# 91
# rug-kiv-gr1.umva
# Number of Observation:  305
# RMSE:  11.4
# MAE:  5.1
# Bias:  1.1
# Rsquare:  -1.1
# Probability of Detection:  0.7419354838709677
# Probability of False Detection:  0.13333333333333333
# False Alarm Rate:  0.448
# Frequency Bias:  1.3440860215053763
#
# 92
# rug-rug-gr2.umva
# Number of Observation:  303
# RMSE:  13.2
# MAE:  5.9
# Bias:  0.5
# Rsquare:  -0.7
# Probability of Detection:  0.7403846153846154
# Probability of False Detection:  0.15168539325842698
# False Alarm Rate:  0.384
# Frequency Bias:  1.2019230769230769
#
# 93
# ruh-ruh-gr1.umva
# Number of Observation:  282
# RMSE:  13.1
# MAE:  6.3
# Bias:  1.8
# Rsquare:  -2.2
# Probability of Detection:  0.7096774193548387
# Probability of False Detection:  0.17880794701986755
# False Alarm Rate:  0.4961832061068702
# Frequency Bias:  1.4086021505376345
#
# 94
# rwa-bug-gr1.umva
# Number of Observation:  292
# RMSE:  11.4
# MAE:  5.9
# Bias:  0.8
# Rsquare:  -1.1
# Probability of Detection:  0.7339449541284404
# Probability of False Detection:  0.19594594594594594
# False Alarm Rate:  0.4444444444444444
# Frequency Bias:  1.3211009174311927
#
# 95
# rwa-tab-gr3.umva
# Number of Observation:  302
# RMSE:  11.3
# MAE:  5.3
# Bias:  0.3
# Rsquare:  -0.6
# Probability of Detection:  0.7058823529411765
# Probability of False Detection:  0.16483516483516483
# False Alarm Rate:  0.4
# Frequency Bias:  1.1764705882352942
#
# 96
# sha-sha-gr1.umva
# Number of Observation:  309
# RMSE:  12.0
# MAE:  5.8
# Bias:  0.5
# Rsquare:  -0.7
# Probability of Detection:  0.7916666666666666
# Probability of False Detection:  0.11363636363636363
# False Alarm Rate:  0.42857142857142855
# Frequency Bias:  1.3854166666666667
#
# 97
# shi-rur-gr1.umva
# Number of Observation:  287
# RMSE:  12.2
# MAE:  6.1
# Bias:  0.3
# Rsquare:  -0.7
# Probability of Detection:  0.7717391304347826
# Probability of False Detection:  0.1346153846153846
# False Alarm Rate:  0.4580152671755725
# Frequency Bias:  1.423913043478261
#
# 98
# tab-tab-gr3.umva
# Number of Observation:  300
# RMSE:  10.5
# MAE:  5.0
# Bias:  0.6
# Rsquare:  -1.0
# Probability of Detection:  0.7127659574468085
# Probability of False Detection:  0.14917127071823205
# False Alarm Rate:  0.4369747899159664
# Frequency Bias:  1.2659574468085106
#
# 99
# tem-rus-gr5.umva
# Number of Observation:  305
# RMSE:  10.3
# MAE:  5.1
# Bias:  0.1
# Rsquare:  -0.6
# Probability of Detection:  0.7553191489361702
# Probability of False Detection:  0.12849162011173185
# False Alarm Rate:  0.4365079365079365
# Frequency Bias:  1.3404255319148937
#
# 100
# yanz-kig-gr3.umva
# Number of Observation:  296
# RMSE:  12.9
# MAE:  6.1
# Bias:  -0.4
# Rsquare:  -0.9
# Probability of Detection:  0.6936936936936937
# Probability of False Detection:  0.2138364779874214
# False Alarm Rate:  0.43795620437956206
# Frequency Bias:  1.2342342342342343
#
# 101
