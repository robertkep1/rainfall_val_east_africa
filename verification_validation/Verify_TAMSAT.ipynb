# %%
import pandas as pd
import numpy as np

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy import stats

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df_obs_daily = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_station_data_daily_v2_tamsat.csv")
df_obs_daily = df_obs_daily.set_index('Unnamed: 0')

df_obs_monthly = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_station_data_monthly_v2_tamsat.csv")
df_obs_monthly = df_obs_monthly.set_index('Unnamed: 0')

df_sat_daily = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_tamsat_data_daily_v2.csv")
df_sat_daily = df_sat_daily.set_index('Unnamed: 0')

df_sat_monthly = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_tamsat_data_monthly_v2.csv")
df_sat_monthly = df_sat_monthly.set_index('Unnamed: 0')

df_obs_metadata = pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/station_data/Final results_csv/station_list_final_v2.csv')
df_obs_metadata = df_obs_metadata.set_index('STNID')

# %%
index = pd.Index(['Lat', 'Lon', 'RMSE', 'MAE', 'Bias', 'PearsonR', 'SpearmanR', 'R2', 'Probability of Detection', 'Probability of False Detection', 'False Alarm Rate', 'Frequency Bias'], name="rows")
column = df_obs_daily.columns

daily_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)
monthly_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)

for station, station_id in enumerate(df_obs_daily.columns):
  print(station)
  # if station == 102:
  #   continue
  
  obs_daily = df_obs_daily[station_id]  
  sat_daily = df_sat_daily[station_id]

  obs_daily = obs_daily.to_numpy(copy=True)
  sat_daily = sat_daily.to_numpy(copy=True)

  obs_daily = obs_daily[~np.isnan(obs_daily)]
  sat_daily = sat_daily[~np.isnan(sat_daily)]

  n_of_sample = len(obs_daily)

  rmse = mean_squared_error(obs_daily, sat_daily, squared=False)
  mae = mean_absolute_error(obs_daily, sat_daily)
  pearsonr = stats.pearsonr(obs_daily, sat_daily)
  spearmanr = stats.spearmanr(obs_daily, sat_daily)
  rsq = r2_score(obs_daily, sat_daily)

  # correlation_matrix = np.corrcoef(obs_daily, sat_daily)
  # correlation_xy = correlation_matrix[0,1]
  # rsq = correlation_xy**2

  bias = sat_daily - obs_daily
  bias = bias.mean()

  obs_daily_bool = obs_daily.copy()
  sat_daily_bool = sat_daily.copy()

  obs_daily_bool[obs_daily_bool < 1] = 0
  obs_daily_bool[obs_daily_bool >= 1] = 1

  sat_daily_bool[sat_daily_bool < 1] = 0
  sat_daily_bool[sat_daily_bool >= 1] = 1

  category = np.empty([n_of_sample])

  for i in range(n_of_sample):
    if obs_daily_bool[i] == 1 and sat_daily_bool[i] == 1:
      category[i] = 1
    elif obs_daily_bool[i] == 1 and sat_daily_bool[i] == 0:
      category[i] = 2
    elif obs_daily_bool[i] == 0 and sat_daily_bool[i] == 1:
      category[i] = 3
    elif obs_daily_bool[i] == 0 and sat_daily_bool[i] == 0:
      category[i] = 4

  hit = np.count_nonzero(category == 1)
  miss = np.count_nonzero(category == 2)
  false_alarm = np.count_nonzero(category == 3)
  correct_negative = np.count_nonzero(category == 4)

  pod = hit/(hit + miss)
  pofd = miss/(miss+correct_negative)
  far = false_alarm/(hit + false_alarm)
  freq_bias = (hit+false_alarm)/(hit+miss)

  daily_metrics_df[station_id].loc['Lat'] = df_obs_metadata['LATITUDE'].loc[station_id]
  daily_metrics_df[station_id].loc['Lon'] = df_obs_metadata['LONGITUDE'].loc[station_id]
  daily_metrics_df[station_id].loc['RMSE'] = round(rmse,2)
  daily_metrics_df[station_id].loc['MAE'] = round(mae,2)
  daily_metrics_df[station_id].loc['Bias'] = round(bias,2)
  daily_metrics_df[station_id].loc['PearsonR'] = round(pearsonr[0],2)
  daily_metrics_df[station_id].loc['SpearmanR'] = round(spearmanr[0],2)
  daily_metrics_df[station_id].loc['R2'] = round(rsq,2)
  daily_metrics_df[station_id].loc['Probability of Detection'] = round(pod,2)
  daily_metrics_df[station_id].loc['Probability of False Detection'] = round(pofd,2)
  daily_metrics_df[station_id].loc['False Alarm Rate'] = round(far,2)
  daily_metrics_df[station_id].loc['Frequency Bias'] = round(freq_bias,2)
                                  
  print(station_id)
  print("Number of Observation: ", n_of_sample)
  print("RMSE: ", str(round(rmse,1)))
  print("MAE: ", str(round(mae,1)))
  print("Bias: ", str(round(bias,1)))
  print("Rsquare: ", str(round(rsq,1)))
  print("Probability of Detection: ", pod)
  print("Probability of False Detection: ", pofd)
  print("False Alarm Rate: ", far)
  print("Frequency Bias: ", freq_bias)


  # # print(obs_daily)
  # # print(sat_daily)

  # # print(obs_daily_bool)
  # # print(sat_daily_bool)
  print(" ")

  # obs_monthly = df_obs_monthly[station_id]
  # sat_monthly = df_sat_monthly[station_id]

  # obs_monthly = obs_monthly.to_numpy()
  # sat_monthly = sat_monthly.to_numpy()

  # print(station, station_id)

daily_metrics_df = daily_metrics_df.T
daily_metrics_df.to_csv('/content/gdrive/MyDrive/rainfall-forecast/verification_validation/metrics/metrics_tamsat_daily.csv')

# %%
index = pd.Index(['Lat', 'Lon', 'ObsN', 'RMSE', 'MAE', 'Bias', 'PearsonR', 'SpearmanR', 'R2', 'POD', 'POFD', 'FAR', 'FB'], name="rows")
column = df_obs_monthly.columns

monthly_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)
monthly_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)

for station, station_id in enumerate(df_obs_monthly.columns):
  print(station)
  # if station == 102:
  #   continue
  
  obs_monthly = df_obs_monthly[station_id]  
  sat_monthly = df_sat_monthly[station_id]

  obs_monthly = obs_monthly.to_numpy(copy=True)
  sat_monthly = sat_monthly.to_numpy(copy=True)

  obs_monthly = obs_monthly[~np.isnan(obs_monthly)]
  sat_monthly = sat_monthly[~np.isnan(sat_monthly)]

  n_of_sample = len(obs_monthly)

  rmse = mean_squared_error(obs_monthly, sat_monthly, squared=False)
  mae = mean_absolute_error(obs_monthly, sat_monthly)
  pearsonr = stats.pearsonr(obs_monthly, sat_monthly)
  spearmanr = stats.spearmanr(obs_monthly, sat_monthly)
  rsq = r2_score(obs_monthly, sat_monthly)

  # correlation_matrix = np.corrcoef(obs_monthly, sat_monthly)
  # correlation_xy = correlation_matrix[0,1]
  # rsq = correlation_xy**2

  bias = sat_monthly - obs_monthly
  bias = bias.mean()

  obs_monthly_bool = obs_monthly.copy()
  sat_monthly_bool = sat_monthly.copy()

  obs_monthly_bool[obs_monthly_bool < 10] = 0
  obs_monthly_bool[obs_monthly_bool >= 10] = 1

  sat_monthly_bool[sat_monthly_bool < 10] = 0
  sat_monthly_bool[sat_monthly_bool >= 10] = 1

  category = np.empty([n_of_sample])

  for i in range(n_of_sample):
    if obs_monthly_bool[i] == 1 and sat_monthly_bool[i] == 1:
      category[i] = 1
    elif obs_monthly_bool[i] == 1 and sat_monthly_bool[i] == 0:
      category[i] = 2
    elif obs_monthly_bool[i] == 0 and sat_monthly_bool[i] == 1:
      category[i] = 3
    elif obs_monthly_bool[i] == 0 and sat_monthly_bool[i] == 0:
      category[i] = 4

  hit = np.count_nonzero(category == 1)
  miss = np.count_nonzero(category == 2)
  false_alarm = np.count_nonzero(category == 3)
  correct_negative = np.count_nonzero(category == 4)

  if hit + miss == 0:
    pod = np.nan
  else:
    pod = hit/(hit + miss)

  if miss + correct_negative == 0:
    pofd = np.nan
  else:
    pofd = miss/(miss + correct_negative)

  if hit + false_alarm == 0:
    far = np.nan
  else:
    far = false_alarm/(hit + false_alarm)

  if hit + miss == 0:
    freq_bias = np.nan
  else:
    freq_bias = (hit+false_alarm)/(hit+miss)

  monthly_metrics_df[station_id].loc['Lat'] = df_obs_metadata['LATITUDE'].loc[station_id]
  monthly_metrics_df[station_id].loc['Lon'] = df_obs_metadata['LONGITUDE'].loc[station_id]
  monthly_metrics_df[station_id].loc['ObsN'] = n_of_sample
  monthly_metrics_df[station_id].loc['RMSE'] = round(rmse,2)
  monthly_metrics_df[station_id].loc['MAE'] = round(mae,2)
  monthly_metrics_df[station_id].loc['Bias'] = round(bias,2)
  monthly_metrics_df[station_id].loc['PearsonR'] = round(pearsonr[0],2)
  monthly_metrics_df[station_id].loc['SpearmanR'] = round(spearmanr[0],2)
  monthly_metrics_df[station_id].loc['R2'] = round(rsq,2)
  monthly_metrics_df[station_id].loc['POD'] = round(pod,2)
  monthly_metrics_df[station_id].loc['POFD'] = round(pofd,2)
  monthly_metrics_df[station_id].loc['FAR'] = round(far,2)
  monthly_metrics_df[station_id].loc['FB'] = round(freq_bias,2)
                                  
  print(station_id)
  print("Number of Observation: ", n_of_sample)
  print("RMSE: ", str(round(rmse,1)))
  print("MAE: ", str(round(mae,1)))
  print("Bias: ", str(round(bias,1)))
  print("Rsquare: ", str(round(rsq,1)))
  print("Probability of Detection: ", pod)
  print("Probability of False Detection: ", pofd)
  print("False Alarm Rate: ", far)
  print("Frequency Bias: ", freq_bias)


  # # print(obs_monthly)
  # # print(sat_monthly)

  # # print(obs_monthly_bool)
  # # print(sat_monthly_bool)
  print(" ")

  # obs_monthly = df_obs_monthly[station_id]
  # sat_monthly = df_sat_monthly[station_id]

  # obs_monthly = obs_monthly.to_numpy()
  # sat_monthly = sat_monthly.to_numpy()

  # print(station, station_id)

monthly_metrics_df = monthly_metrics_df.T
monthly_metrics_df.to_csv('/content/gdrive/MyDrive/rainfall-forecast/verification_validation/metrics/metrics_tamsat_monthly.csv')
# Out:
# 0
# TA00073
# Number of Observation:  60
# RMSE:  87.6
# MAE:  59.7
# Bias:  6.0
# Rsquare:  -0.8
# Probability of Detection:  0.8260869565217391
# Probability of False Detection:  1.0
# False Alarm Rate:  0.2692307692307692
# Frequency Bias:  1.1304347826086956
#
# 1
# TA00024
# Number of Observation:  60
# RMSE:  99.6
# MAE:  59.3
# Bias:  -14.0
# Rsquare:  -0.2
# Probability of Detection:  0.782608695652174
# Probability of False Detection:  0.5555555555555556
# False Alarm Rate:  0.14285714285714285
# Frequency Bias:  0.9130434782608695
#
# 2
# TA00026
# Number of Observation:  60
# RMSE:  123.9
# MAE:  78.1
# Bias:  -23.7
# Rsquare:  -0.3
# Probability of Detection:  0.9433962264150944
# Probability of False Detection:  0.75
# False Alarm Rate:  0.10714285714285714
# Frequency Bias:  1.0566037735849056
#
# 3
# TA00070
# Number of Observation:  60
# RMSE:  143.0
# MAE:  90.0
# Bias:  -27.0
# Rsquare:  -0.2
# Probability of Detection:  0.6842105263157895
# Probability of False Detection:  0.6
# False Alarm Rate:  0.35
# Frequency Bias:  1.0526315789473684
#
# 4
# TA00071
# Number of Observation:  60
# RMSE:  129.6
# MAE:  81.2
# Bias:  -29.6
# Rsquare:  0.1
# Probability of Detection:  0.6756756756756757
# Probability of False Detection:  0.5714285714285714
# False Alarm Rate:  0.358974358974359
# Frequency Bias:  1.054054054054054
#
# 5
# 638940-99999
# Number of Observation:  60
# RMSE:  131.9
# MAE:  84.8
# Bias:  -46.9
# Rsquare:  0.1
# Probability of Detection:  0.75
# Probability of False Detection:  0.4583333333333333
# False Alarm Rate:  0.08333333333333333
# Frequency Bias:  0.8181818181818182
#
# 6
# 637290-99999
# Number of Observation:  60
# RMSE:  112.9
# MAE:  86.1
# Bias:  -31.1
# Rsquare:  0.4
# Probability of Detection:  0.9821428571428571
# Probability of False Detection:  0.5
# False Alarm Rate:  0.05172413793103448
# Frequency Bias:  1.0357142857142858
#
# 7
# 638700-99999
# Number of Observation:  60
# RMSE:  186.8
# MAE:  111.0
# Bias:  -85.3
# Rsquare:  -0.1
# Probability of Detection:  0.6862745098039216
# Probability of False Detection:  0.6956521739130435
# False Alarm Rate:  0.05405405405405406
# Frequency Bias:  0.7254901960784313
#
# 8
# 639710-99999
# Number of Observation:  60
# RMSE:  106.5
# MAE:  61.7
# Bias:  -8.4
# Rsquare:  0.2
# Probability of Detection:  0.8048780487804879
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.08333333333333333
# Frequency Bias:  0.8780487804878049
#
# 9
# 638620-99999
# Number of Observation:  60
# RMSE:  89.3
# MAE:  44.9
# Bias:  -13.6
# Rsquare:  0.2
# Probability of Detection:  0.8888888888888888
# Probability of False Detection:  0.09090909090909091
# False Alarm Rate:  0.1111111111111111
# Frequency Bias:  1.0
#
# 10
# 638870-99999
# Number of Observation:  60
# RMSE:  63.3
# MAE:  35.1
# Bias:  -10.9
# Rsquare:  0.4
# Probability of Detection:  0.9333333333333333
# Probability of False Detection:  0.06451612903225806
# False Alarm Rate:  0.034482758620689655
# Frequency Bias:  0.9666666666666667
#
# 11
# 637560-99999
# Number of Observation:  60
# RMSE:  86.0
# MAE:  53.6
# Bias:  -16.7
# Rsquare:  0.1
# Probability of Detection:  0.9183673469387755
# Probability of False Detection:  0.3076923076923077
# False Alarm Rate:  0.0425531914893617
# Frequency Bias:  0.9591836734693877
#
# 12
# 637910-99999
# Number of Observation:  60
# RMSE:  78.9
# MAE:  49.1
# Bias:  -13.9
# Rsquare:  -0.1
# Probability of Detection:  0.6666666666666666
# Probability of False Detection:  0.4074074074074074
# False Alarm Rate:  0.3333333333333333
# Frequency Bias:  1.0
#
# 13
# 638810-99999
# Number of Observation:  60
# RMSE:  63.8
# MAE:  39.4
# Bias:  -1.7
# Rsquare:  0.5
# Probability of Detection:  0.8333333333333334
# Probability of False Detection:  0.21428571428571427
# False Alarm Rate:  0.0625
# Frequency Bias:  0.8888888888888888
#
# 14
# 638010-99999
# Number of Observation:  60
# RMSE:  65.3
# MAE:  44.9
# Bias:  -9.6
# Rsquare:  0.4
# Probability of Detection:  0.9069767441860465
# Probability of False Detection:  0.2
# False Alarm Rate:  0.025
# Frequency Bias:  0.9302325581395349
#
# 15
# 639620-99999
# Number of Observation:  60
# RMSE:  75.0
# MAE:  42.6
# Bias:  -10.2
# Rsquare:  0.6
# Probability of Detection:  0.8285714285714286
# Probability of False Detection:  0.20689655172413793
# False Alarm Rate:  0.06451612903225806
# Frequency Bias:  0.8857142857142857
#
# 16
# 638660-99999
# Number of Observation:  60
# RMSE:  88.5
# MAE:  60.9
# Bias:  -40.4
# Rsquare:  0.1
# Probability of Detection:  0.8
# Probability of False Detection:  0.4090909090909091
# False Alarm Rate:  0.05263157894736842
# Frequency Bias:  0.8444444444444444
#
# 17
# 638320-99999
# Number of Observation:  60
# RMSE:  221.7
# MAE:  136.2
# Bias:  -109.8
# Rsquare:  -0.1
# Probability of Detection:  0.8292682926829268
# Probability of False Detection:  0.2916666666666667
# False Alarm Rate:  0.05555555555555555
# Frequency Bias:  0.8780487804878049
#
# 18
# 637330-99999
# Number of Observation:  60
# RMSE:  68.6
# MAE:  51.1
# Bias:  2.7
# Rsquare:  0.0
# Probability of Detection:  0.9803921568627451
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.12280701754385964
# Frequency Bias:  1.1176470588235294
#
# 19
# TA00057
# Number of Observation:  58
# RMSE:  84.7
# MAE:  47.1
# Bias:  16.2
# Rsquare:  -0.5
# Probability of Detection:  0.8611111111111112
# Probability of False Detection:  0.38461538461538464
# False Alarm Rate:  0.3111111111111111
# Frequency Bias:  1.25
#
# 20
# TA00020
# Number of Observation:  59
# RMSE:  69.3
# MAE:  38.0
# Bias:  9.0
# Rsquare:  -0.3
# Probability of Detection:  0.96
# Probability of False Detection:  0.043478260869565216
# False Alarm Rate:  0.3333333333333333
# Frequency Bias:  1.44
#
# 21
# 638200-99999
# Number of Observation:  60
# RMSE:  125.6
# MAE:  81.9
# Bias:  -39.5
# Rsquare:  -0.1
# Probability of Detection:  0.6382978723404256
# Probability of False Detection:  0.7391304347826086
# False Alarm Rate:  0.1891891891891892
# Frequency Bias:  0.7872340425531915
#
# 22
# 637170-99999
# Number of Observation:  60
# RMSE:  115.3
# MAE:  81.4
# Bias:  -31.8
# Rsquare:  -0.5
# Probability of Detection:  0.7636363636363637
# Probability of False Detection:  0.9285714285714286
# False Alarm Rate:  0.08695652173913043
# Frequency Bias:  0.8363636363636363
#
# 23
# TA00019
# Number of Observation:  58
# RMSE:  72.1
# MAE:  54.4
# Bias:  34.6
# Rsquare:  -1.6
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.08771929824561403
# Frequency Bias:  1.0961538461538463
#
# 24
# 637930-99999
# Number of Observation:  60
# RMSE:  66.5
# MAE:  40.2
# Bias:  -11.6
# Rsquare:  0.1
# Probability of Detection:  0.7647058823529411
# Probability of False Detection:  0.32
# False Alarm Rate:  0.2571428571428571
# Frequency Bias:  1.0294117647058822
#
# 25
# TA00076
# Number of Observation:  57
# RMSE:  96.1
# MAE:  76.8
# Bias:  42.3
# Rsquare:  -0.9
# Probability of Detection:  1.0
# Probability of False Detection:  nan
# False Alarm Rate:  0.3157894736842105
# Frequency Bias:  1.4615384615384615
#
# 26
# TA00069
# Number of Observation:  59
# RMSE:  125.5
# MAE:  81.8
# Bias:  -27.0
# Rsquare:  -0.0
# Probability of Detection:  0.5897435897435898
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.34285714285714286
# Frequency Bias:  0.8974358974358975
#
# 27
# TA00074
# Number of Observation:  59
# RMSE:  140.9
# MAE:  79.0
# Bias:  -36.7
# Rsquare:  0.1
# Probability of Detection:  0.8333333333333334
# Probability of False Detection:  0.5384615384615384
# False Alarm Rate:  0.2391304347826087
# Frequency Bias:  1.0952380952380953
#
# 28
# 636610-99999
# Number of Observation:  60
# RMSE:  87.9
# MAE:  68.0
# Bias:  -42.5
# Rsquare:  -0.1
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.08620689655172414
# Frequency Bias:  1.0943396226415094
#
# 29
# 637200-99999
# Number of Observation:  60
# RMSE:  131.1
# MAE:  82.2
# Bias:  -38.6
# Rsquare:  -0.1
# Probability of Detection:  0.7142857142857143
# Probability of False Detection:  0.7368421052631579
# False Alarm Rate:  0.14634146341463414
# Frequency Bias:  0.8367346938775511
#
# 30
# 643870-99999
# Number of Observation:  60
# RMSE:  112.3
# MAE:  74.0
# Bias:  -53.9
# Rsquare:  -0.3
# Probability of Detection:  0.7843137254901961
# Probability of False Detection:  0.6470588235294118
# False Alarm Rate:  0.06976744186046512
# Frequency Bias:  0.8431372549019608
#
# 31
# 636950-99999
# Number of Observation:  60
# RMSE:  165.5
# MAE:  104.2
# Bias:  -41.4
# Rsquare:  -0.3
# Probability of Detection:  0.7777777777777778
# Probability of False Detection:  0.5263157894736842
# False Alarm Rate:  0.14634146341463414
# Frequency Bias:  0.9111111111111111
#
# 32
# 637400-99999
# Number of Observation:  60
# RMSE:  80.6
# MAE:  53.4
# Bias:  -16.6
# Rsquare:  -0.5
# Probability of Detection:  0.6818181818181818
# Probability of False Detection:  0.5833333333333334
# False Alarm Rate:  0.16666666666666666
# Frequency Bias:  0.8181818181818182
#
# 33
# TA00056
# Number of Observation:  56
# RMSE:  134.8
# MAE:  75.6
# Bias:  -28.0
# Rsquare:  -0.0
# Probability of Detection:  0.7727272727272727
# Probability of False Detection:  0.625
# False Alarm Rate:  0.15
# Frequency Bias:  0.9090909090909091
#
# 34
# 637140-99999
# Number of Observation:  60
# RMSE:  80.6
# MAE:  56.6
# Bias:  -12.3
# Rsquare:  -0.4
# Probability of Detection:  0.9607843137254902
# Probability of False Detection:  0.4
# False Alarm Rate:  0.10909090909090909
# Frequency Bias:  1.0784313725490196
#
# 35
# TA00025
# Number of Observation:  53
# RMSE:  91.7
# MAE:  55.3
# Bias:  -11.3
# Rsquare:  -0.1
# Probability of Detection:  0.85
# Probability of False Detection:  0.46153846153846156
# False Alarm Rate:  0.15
# Frequency Bias:  1.0
#
# 36
# 643800-99999
# Number of Observation:  59
# RMSE:  70.3
# MAE:  53.5
# Bias:  -5.5
# Rsquare:  -0.2
# Probability of Detection:  0.8679245283018868
# Probability of False Detection:  0.6363636363636364
# False Alarm Rate:  0.041666666666666664
# Frequency Bias:  0.9056603773584906
#
# 37
# 643810-99999
# Number of Observation:  59
# RMSE:  78.5
# MAE:  52.7
# Bias:  -10.7
# Rsquare:  0.0
# Probability of Detection:  0.8703703703703703
# Probability of False Detection:  0.7777777777777778
# False Alarm Rate:  0.06
# Frequency Bias:  0.9259259259259259
#
# 38
# TA00033
# Number of Observation:  51
# RMSE:  79.8
# MAE:  63.4
# Bias:  9.8
# Rsquare:  0.2
# Probability of Detection:  1.0
# Probability of False Detection:  nan
# False Alarm Rate:  0.1568627450980392
# Frequency Bias:  1.186046511627907
#
# 39
# TA00072
# Number of Observation:  56
# RMSE:  115.2
# MAE:  75.7
# Bias:  -19.7
# Rsquare:  -0.1
# Probability of Detection:  0.7272727272727273
# Probability of False Detection:  0.45
# False Alarm Rate:  0.3333333333333333
# Frequency Bias:  1.0909090909090908
#
# 40
# 636120-99999
# Number of Observation:  60
# RMSE:  41.2
# MAE:  24.6
# Bias:  -17.1
# Rsquare:  -0.2
# Probability of Detection:  0.2962962962962963
# Probability of False Detection:  0.4523809523809524
# False Alarm Rate:  0.5555555555555556
# Frequency Bias:  0.6666666666666666
#
# 41
# TA00066
# Number of Observation:  53
# RMSE:  100.0
# MAE:  61.5
# Bias:  -19.9
# Rsquare:  -0.2
# Probability of Detection:  0.8
# Probability of False Detection:  0.6153846153846154
# False Alarm Rate:  0.2
# Frequency Bias:  1.0
#
# 42
# 637990-99999
# Number of Observation:  60
# RMSE:  71.5
# MAE:  42.6
# Bias:  5.8
# Rsquare:  -0.2
# Probability of Detection:  0.631578947368421
# Probability of False Detection:  0.28
# False Alarm Rate:  0.6571428571428571
# Frequency Bias:  1.8421052631578947
#
# 43
# 637420-99999
# Number of Observation:  60
# RMSE:  97.1
# MAE:  50.1
# Bias:  0.0
# Rsquare:  -0.3
# Probability of Detection:  0.75
# Probability of False Detection:  0.29411764705882354
# False Alarm Rate:  0.6511627906976745
# Frequency Bias:  2.15
#
# 44
# TA00023
# Number of Observation:  49
# RMSE:  62.0
# MAE:  39.2
# Bias:  13.6
# Rsquare:  0.1
# Probability of Detection:  0.8333333333333334
# Probability of False Detection:  0.2222222222222222
# False Alarm Rate:  0.3548387096774194
# Frequency Bias:  1.2916666666666667
#
# 45
# TA00075
# Number of Observation:  48
# RMSE:  55.0
# MAE:  38.5
# Bias:  3.9
# Rsquare:  -0.2
# Probability of Detection:  0.8529411764705882
# Probability of False Detection:  0.38461538461538464
# False Alarm Rate:  0.17142857142857143
# Frequency Bias:  1.0294117647058822
#
# 46
# TA00031
# Number of Observation:  49
# RMSE:  77.9
# MAE:  62.9
# Bias:  25.9
# Rsquare:  -0.2
# Probability of Detection:  1.0
# Probability of False Detection:  0.0
# False Alarm Rate:  0.08333333333333333
# Frequency Bias:  1.0909090909090908
#
# 47
# TA00021
# Number of Observation:  52
# RMSE:  79.5
# MAE:  61.2
# Bias:  -17.1
# Rsquare:  -0.0
# Probability of Detection:  0.9473684210526315
# Probability of False Detection:  0.5
# False Alarm Rate:  0.25
# Frequency Bias:  1.263157894736842
#
# 48
# TA00108
# Number of Observation:  47
# RMSE:  84.2
# MAE:  49.2
# Bias:  14.8
# Rsquare:  -1.5
# Probability of Detection:  0.875
# Probability of False Detection:  0.17647058823529413
# False Alarm Rate:  0.3
# Frequency Bias:  1.25
#
# 49
# TA00029
# Number of Observation:  46
# RMSE:  130.4
# MAE:  79.1
# Bias:  50.8
# Rsquare:  -4.6
# Probability of Detection:  0.8518518518518519
# Probability of False Detection:  1.0
# False Alarm Rate:  0.4523809523809524
# Frequency Bias:  1.5555555555555556
#
# 50
# TA00130
# Number of Observation:  46
# RMSE:  64.3
# MAE:  45.1
# Bias:  -8.7
# Rsquare:  -0.1
# Probability of Detection:  0.6
# Probability of False Detection:  0.7368421052631579
# False Alarm Rate:  0.2222222222222222
# Frequency Bias:  0.7714285714285715
#
# 51
# 636860-99999
# Number of Observation:  49
# RMSE:  96.4
# MAE:  74.5
# Bias:  -48.9
# Rsquare:  -0.2
# Probability of Detection:  0.9772727272727273
# Probability of False Detection:  0.5
# False Alarm Rate:  0.0851063829787234
# Frequency Bias:  1.0681818181818181
#
# 52
# TA00133
# Number of Observation:  46
# RMSE:  93.4
# MAE:  70.3
# Bias:  -39.7
# Rsquare:  -0.1
# Probability of Detection:  0.5833333333333334
# Probability of False Detection:  0.8333333333333334
# False Alarm Rate:  0.25
# Frequency Bias:  0.7777777777777778
#
# 53
# TA00155
# Number of Observation:  45
# RMSE:  69.1
# MAE:  39.8
# Bias:  -27.3
# Rsquare:  0.3
# Probability of Detection:  0.7777777777777778
# Probability of False Detection:  0.2857142857142857
# False Alarm Rate:  0.125
# Frequency Bias:  0.8888888888888888
#
# 54
# TA00157
# Number of Observation:  45
# RMSE:  69.6
# MAE:  39.8
# Bias:  -24.9
# Rsquare:  0.4
# Probability of Detection:  0.8
# Probability of False Detection:  0.2777777777777778
# False Alarm Rate:  0.25925925925925924
# Frequency Bias:  1.08
#
# 55
# TA00140
# Number of Observation:  46
# RMSE:  107.0
# MAE:  74.7
# Bias:  -34.7
# Rsquare:  -0.1
# Probability of Detection:  0.975
# Probability of False Detection:  1.0
# False Alarm Rate:  0.13333333333333333
# Frequency Bias:  1.125
#
# 56
# 643830-99999
# Number of Observation:  59
# RMSE:  61.2
# MAE:  41.4
# Bias:  -9.2
# Rsquare:  0.2
# Probability of Detection:  0.9230769230769231
# Probability of False Detection:  0.4444444444444444
# False Alarm Rate:  0.04
# Frequency Bias:  0.9615384615384616
#
# 57
# TA00054
# Number of Observation:  46
# RMSE:  82.1
# MAE:  63.6
# Bias:  3.6
# Rsquare:  -0.1
# Probability of Detection:  0.9545454545454546
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.023255813953488372
# Frequency Bias:  0.9772727272727273
#
# 58
# 637050-99999
# Number of Observation:  60
# RMSE:  50.7
# MAE:  39.5
# Bias:  15.4
# Rsquare:  0.5
# Probability of Detection:  1.0
# Probability of False Detection:  nan
# False Alarm Rate:  0.2
# Frequency Bias:  1.25
#
# 59
# 643900-99999
# Number of Observation:  60
# RMSE:  81.8
# MAE:  43.6
# Bias:  6.1
# Rsquare:  -0.0
# Probability of Detection:  0.8048780487804879
# Probability of False Detection:  0.36363636363636365
# False Alarm Rate:  0.13157894736842105
# Frequency Bias:  0.926829268292683
#
# 60
# TA00134
# Number of Observation:  46
# RMSE:  89.4
# MAE:  57.3
# Bias:  -5.4
# Rsquare:  -1.1
# Probability of Detection:  0.7428571428571429
# Probability of False Detection:  0.6923076923076923
# False Alarm Rate:  0.21212121212121213
# Frequency Bias:  0.9428571428571428
#
# 61
# TA00131
# Number of Observation:  45
# RMSE:  125.3
# MAE:  83.7
# Bias:  -66.5
# Rsquare:  -0.1
# Probability of Detection:  0.675
# Probability of False Detection:  0.7647058823529411
# False Alarm Rate:  0.03571428571428571
# Frequency Bias:  0.7
#
# 62
# TA00129
# Number of Observation:  45
# RMSE:  79.7
# MAE:  47.1
# Bias:  -20.4
# Rsquare:  -0.0
# Probability of Detection:  0.6875
# Probability of False Detection:  0.45454545454545453
# False Alarm Rate:  0.043478260869565216
# Frequency Bias:  0.71875
#
# 63
# can-git-gr1.umva
# Number of Observation:  22
# RMSE:  90.6
# MAE:  69.4
# Bias:  -64.8
# Rsquare:  -0.1
# Probability of Detection:  0.5714285714285714
# Probability of False Detection:  0.9
# False Alarm Rate:  0.0
# Frequency Bias:  0.5714285714285714
#
# 64
# cub-nta-gr1.umva
# Number of Observation:  24
# RMSE:  70.9
# MAE:  48.8
# Bias:  -43.3
# Rsquare:  0.0
# Probability of Detection:  0.7368421052631579
# Probability of False Detection:  0.5
# False Alarm Rate:  0.0
# Frequency Bias:  0.7368421052631579
#
# 65
# gas-mbu-gr3.umva
# Number of Observation:  24
# RMSE:  72.1
# MAE:  50.5
# Bias:  -42.2
# Rsquare:  -0.0
# Probability of Detection:  0.7058823529411765
# Probability of False Detection:  0.45454545454545453
# False Alarm Rate:  0.07692307692307693
# Frequency Bias:  0.7647058823529411
#
# 66
# gat-gat-gr3.umva
# Number of Observation:  24
# RMSE:  71.7
# MAE:  46.7
# Bias:  -41.0
# Rsquare:  0.1
# Probability of Detection:  0.5789473684210527
# Probability of False Detection:  0.6153846153846154
# False Alarm Rate:  0.0
# Frequency Bias:  0.5789473684210527
#
# 67
# git-git-gr1.umva
# Number of Observation:  22
# RMSE:  78.1
# MAE:  58.7
# Bias:  -51.4
# Rsquare:  -0.1
# Probability of Detection:  0.6190476190476191
# Probability of False Detection:  0.8888888888888888
# False Alarm Rate:  0.0
# Frequency Bias:  0.6190476190476191
#
# 68
# git-kuw-gr1.umva
# Number of Observation:  23
# RMSE:  117.9
# MAE:  86.6
# Bias:  -82.9
# Rsquare:  -0.3
# Probability of Detection:  0.5454545454545454
# Probability of False Detection:  0.9090909090909091
# False Alarm Rate:  0.0
# Frequency Bias:  0.5454545454545454
#
# 69
# git-muh-gr1.umva
# Number of Observation:  23
# RMSE:  110.5
# MAE:  79.6
# Bias:  -77.8
# Rsquare:  -0.3
# Probability of Detection:  0.5454545454545454
# Probability of False Detection:  0.9090909090909091
# False Alarm Rate:  0.0
# Frequency Bias:  0.5454545454545454
#
# 70
# kaj-kaj-gr1.umva
# Number of Observation:  23
# RMSE:  76.4
# MAE:  47.0
# Bias:  -37.5
# Rsquare:  -0.0
# Probability of Detection:  0.7777777777777778
# Probability of False Detection:  0.4444444444444444
# False Alarm Rate:  0.0
# Frequency Bias:  0.7777777777777778
#
# 71
# kan-mak-gr1.umva
# Number of Observation:  23
# RMSE:  92.2
# MAE:  69.3
# Bias:  -61.2
# Rsquare:  -0.4
# Probability of Detection:  0.5238095238095238
# Probability of False Detection:  0.9090909090909091
# False Alarm Rate:  0.08333333333333333
# Frequency Bias:  0.5714285714285714
#
# 72
# kar-karu-gr2.umva
# Number of Observation:  23
# RMSE:  94.2
# MAE:  55.3
# Bias:  -45.5
# Rsquare:  -0.2
# Probability of Detection:  0.6842105263157895
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.07142857142857142
# Frequency Bias:  0.7368421052631579
#
# 73
# kav-kir-gr2.umva
# Number of Observation:  23
# RMSE:  84.8
# MAE:  62.6
# Bias:  -58.7
# Rsquare:  -0.0
# Probability of Detection:  0.6
# Probability of False Detection:  0.7272727272727273
# False Alarm Rate:  0.0
# Frequency Bias:  0.6
#
# 74
# kav-mun-gr1.umva
# Number of Observation:  24
# RMSE:  93.2
# MAE:  69.2
# Bias:  -63.0
# Rsquare:  -0.1
# Probability of Detection:  0.6190476190476191
# Probability of False Detection:  0.7272727272727273
# False Alarm Rate:  0.0
# Frequency Bias:  0.6190476190476191
#
# 75
# kiv-nam-gr1.umva
# Number of Observation:  23
# RMSE:  93.2
# MAE:  73.9
# Bias:  -68.1
# Rsquare:  -0.4
# Probability of Detection:  0.55
# Probability of False Detection:  0.8181818181818182
# False Alarm Rate:  0.08333333333333333
# Frequency Bias:  0.6
#
# 76
# maga-mag-gr1.umva
# Number of Observation:  24
# RMSE:  89.1
# MAE:  57.6
# Bias:  -55.1
# Rsquare:  0.0
# Probability of Detection:  0.7222222222222222
# Probability of False Detection:  0.45454545454545453
# False Alarm Rate:  0.0
# Frequency Bias:  0.7222222222222222
#
# 77
# mas-nya-gr1.umva
# Number of Observation:  24
# RMSE:  109.7
# MAE:  61.3
# Bias:  -56.0
# Rsquare:  -0.2
# Probability of Detection:  0.6
# Probability of False Detection:  0.6666666666666666
# False Alarm Rate:  0.0
# Frequency Bias:  0.6
#
# 78
# may-may-gr2.umva
# Number of Observation:  24
# RMSE:  71.0
# MAE:  49.0
# Bias:  -38.2
# Rsquare:  0.1
# Probability of Detection:  0.631578947368421
# Probability of False Detection:  0.5833333333333334
# False Alarm Rate:  0.0
# Frequency Bias:  0.631578947368421
#
# 79
# mug-mugo-gr2.umva
# Number of Observation:  21
# RMSE:  76.9
# MAE:  52.7
# Bias:  -52.1
# Rsquare:  -0.1
# Probability of Detection:  0.6470588235294118
# Probability of False Detection:  0.6
# False Alarm Rate:  0.0
# Frequency Bias:  0.6470588235294118
#
# 80
# mug-nta-gr3.umva
# Number of Observation:  24
# RMSE:  89.3
# MAE:  57.9
# Bias:  -55.6
# Rsquare:  -0.1
# Probability of Detection:  0.7777777777777778
# Probability of False Detection:  0.4
# False Alarm Rate:  0.0
# Frequency Bias:  0.7777777777777778
#
# 81
# mug-rus-gr2.umva
# Number of Observation:  21
# RMSE:  88.2
# MAE:  53.8
# Bias:  -50.5
# Rsquare:  -0.2
# Probability of Detection:  0.6875
# Probability of False Detection:  0.5
# False Alarm Rate:  0.0
# Frequency Bias:  0.6875
#
# 82
# muhw-muh-gr1.umva
# Number of Observation:  23
# RMSE:  100.7
# MAE:  64.2
# Bias:  -58.8
# Rsquare:  -0.2
# Probability of Detection:  0.7368421052631579
# Probability of False Detection:  0.5555555555555556
# False Alarm Rate:  0.0
# Frequency Bias:  0.7368421052631579
#
# 83
# mun-mun-gr2.umva
# Number of Observation:  23
# RMSE:  85.5
# MAE:  65.6
# Bias:  -59.2
# Rsquare:  -0.3
# Probability of Detection:  0.5
# Probability of False Detection:  0.8333333333333334
# False Alarm Rate:  0.09090909090909091
# Frequency Bias:  0.55
#
# 84
# mut-mak-gr2.umva
# Number of Observation:  23
# RMSE:  113.2
# MAE:  79.1
# Bias:  -70.2
# Rsquare:  -0.2
# Probability of Detection:  0.631578947368421
# Probability of False Detection:  0.7
# False Alarm Rate:  0.07692307692307693
# Frequency Bias:  0.6842105263157895
#
# 85
# ngu-nya-gr3.umva
# Number of Observation:  24
# RMSE:  92.0
# MAE:  55.5
# Bias:  -54.1
# Rsquare:  -0.1
# Probability of Detection:  0.6470588235294118
# Probability of False Detection:  0.46153846153846156
# False Alarm Rate:  0.0
# Frequency Bias:  0.6470588235294118
#
# 86
# nyabi-ny-gr1.umva
# Number of Observation:  24
# RMSE:  80.5
# MAE:  58.4
# Bias:  -51.7
# Rsquare:  -0.1
# Probability of Detection:  0.55
# Probability of False Detection:  0.75
# False Alarm Rate:  0.08333333333333333
# Frequency Bias:  0.6
#
# 87
# nya-mun-gr1.umva
# Number of Observation:  24
# RMSE:  84.1
# MAE:  61.1
# Bias:  -54.2
# Rsquare:  -0.2
# Probability of Detection:  0.55
# Probability of False Detection:  0.75
# False Alarm Rate:  0.08333333333333333
# Frequency Bias:  0.6
#
# 88
# nye-nzo-gr1.umva
# Number of Observation:  24
# RMSE:  99.7
# MAE:  57.4
# Bias:  -51.3
# Rsquare:  -0.1
# Probability of Detection:  0.5555555555555556
# Probability of False Detection:  0.6153846153846154
# False Alarm Rate:  0.09090909090909091
# Frequency Bias:  0.6111111111111112
#
# 89
# ny-nyagi-gr1.umva
# Number of Observation:  24
# RMSE:  110.3
# MAE:  85.6
# Bias:  -75.3
# Rsquare:  -0.2
# Probability of Detection:  0.65
# Probability of False Detection:  0.7
# False Alarm Rate:  0.07142857142857142
# Frequency Bias:  0.7
#
# 90
# nzi-mas-gr1.umva
# Number of Observation:  24
# RMSE:  99.1
# MAE:  62.7
# Bias:  -57.4
# Rsquare:  0.0
# Probability of Detection:  0.7368421052631579
# Probability of False Detection:  0.5
# False Alarm Rate:  0.0
# Frequency Bias:  0.7368421052631579
#
# 91
# rem-muy-gr1.umva
# Number of Observation:  24
# RMSE:  113.5
# MAE:  86.4
# Bias:  -78.6
# Rsquare:  -0.2
# Probability of Detection:  0.5714285714285714
# Probability of False Detection:  0.8181818181818182
# False Alarm Rate:  0.07692307692307693
# Frequency Bias:  0.6190476190476191
#
# 92
# rug-kiv-gr1.umva
# Number of Observation:  24
# RMSE:  73.9
# MAE:  45.5
# Bias:  -38.3
# Rsquare:  -0.1
# Probability of Detection:  0.7222222222222222
# Probability of False Detection:  0.45454545454545453
# False Alarm Rate:  0.0
# Frequency Bias:  0.7222222222222222
#
# 93
# rug-rug-gr2.umva
# Number of Observation:  24
# RMSE:  81.7
# MAE:  58.7
# Bias:  -54.1
# Rsquare:  -0.1
# Probability of Detection:  0.7368421052631579
# Probability of False Detection:  0.5555555555555556
# False Alarm Rate:  0.06666666666666667
# Frequency Bias:  0.7894736842105263
#
# 94
# ruh-ruh-gr1.umva
# Number of Observation:  24
# RMSE:  85.6
# MAE:  63.3
# Bias:  -53.7
# Rsquare:  -0.1
# Probability of Detection:  0.65
# Probability of False Detection:  0.7
# False Alarm Rate:  0.07142857142857142
# Frequency Bias:  0.7
#
# 95
# rwa-bug-gr1.umva
# Number of Observation:  23
# RMSE:  95.7
# MAE:  71.8
# Bias:  -66.9
# Rsquare:  -0.3
# Probability of Detection:  0.6842105263157895
# Probability of False Detection:  0.6
# False Alarm Rate:  0.0
# Frequency Bias:  0.6842105263157895
#
# 96
# rwa-tab-gr3.umva
# Number of Observation:  24
# RMSE:  94.0
# MAE:  56.3
# Bias:  -55.4
# Rsquare:  -0.2
# Probability of Detection:  0.5789473684210527
# Probability of False Detection:  0.6153846153846154
# False Alarm Rate:  0.0
# Frequency Bias:  0.5789473684210527
#
# 97
# sha-sha-gr1.umva
# Number of Observation:  24
# RMSE:  99.1
# MAE:  58.6
# Bias:  -48.7
# Rsquare:  -0.1
# Probability of Detection:  0.65
# Probability of False Detection:  0.6363636363636364
# False Alarm Rate:  0.0
# Frequency Bias:  0.65
#
# 98
# shi-rur-gr1.umva
# Number of Observation:  24
# RMSE:  94.1
# MAE:  68.2
# Bias:  -63.6
# Rsquare:  -0.1
# Probability of Detection:  0.5909090909090909
# Probability of False Detection:  0.8181818181818182
# False Alarm Rate:  0.0
# Frequency Bias:  0.5909090909090909
#
# 99
# tab-tab-gr3.umva
# Number of Observation:  24
# RMSE:  80.5
# MAE:  45.0
# Bias:  -40.6
# Rsquare:  -0.1
# Probability of Detection:  0.5789473684210527
# Probability of False Detection:  0.6153846153846154
# False Alarm Rate:  0.0
# Frequency Bias:  0.5789473684210527
#
# 100
# tem-rus-gr5.umva
# Number of Observation:  24
# RMSE:  76.5
# MAE:  55.3
# Bias:  -52.1
# Rsquare:  -0.1
# Probability of Detection:  0.7
# Probability of False Detection:  0.6
# False Alarm Rate:  0.0
# Frequency Bias:  0.7
#
# 101
# yanz-kig-gr3.umva
# Number of Observation:  24
# RMSE:  117.1
# MAE:  85.6
# Bias:  -81.5
# Rsquare:  -0.4
# Probability of Detection:  0.6842105263157895
# Probability of False Detection:  0.5454545454545454
# False Alarm Rate:  0.0
# Frequency Bias:  0.6842105263157895
#
# 102
# muh-gah-gr1.umva
# Number of Observation:  23
# RMSE:  83.8
# MAE:  66.8
# Bias:  -30.6
# Rsquare:  -0.3
# Probability of Detection:  0.6190476190476191
# Probability of False Detection:  0.8
# False Alarm Rate:  0.0
# Frequency Bias:  0.6190476190476191
