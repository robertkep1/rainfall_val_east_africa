# %%
import pandas as pd
import numpy as np

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy import stats

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
drop_columns = 'TA00075'


df_obs_daily = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_station_data_daily_v2_tamsat.csv")
df_obs_daily = df_obs_daily.set_index('Unnamed: 0')
df_obs_daily = df_obs_daily.loc['2020-01-04':'2020-12-31']
df_obs_daily = df_obs_daily.drop(columns=drop_columns)

df_sat_daily = pd.read_csv("/content/gdrive/MyDrive/rainfall-forecast/verification_validation/final_tamsat_data_daily_v2.csv")
df_sat_daily = df_sat_daily.set_index('Unnamed: 0')
df_sat_daily = df_sat_daily.loc['2020-01-04':'2020-12-31']
df_sat_daily = df_sat_daily.drop(columns=drop_columns)


df_obs_metadata = pd.read_csv('/content/gdrive/MyDrive/rainfall-forecast/station_data/Final results_csv/station_list_final_v2.csv')
df_obs_metadata = df_obs_metadata.set_index('STNID')

# %%
index = pd.Index(['Lat', 'Lon', 'RMSE', 'MAE', 'Bias', 'PearsonR', 'SpearmanR', 'R2', 'Probability of Detection', 'Probability of False Detection', 'False Alarm Rate', 'Frequency Bias'], name="rows")
column = df_obs_daily.columns

daily_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)
monthly_metrics_df = pd.DataFrame(data=np.nan, index=index, columns=column)

for station, station_id in enumerate(df_obs_daily.columns):
  print(station)
  # if station == 102:
  #   continue
  
  obs_daily = df_obs_daily[station_id]  
  sat_daily = df_sat_daily[station_id]

  obs_daily = obs_daily.to_numpy(copy=True)
  sat_daily = sat_daily.to_numpy(copy=True)

  obs_daily = obs_daily[~np.isnan(obs_daily)]
  sat_daily = sat_daily[~np.isnan(sat_daily)]

  n_of_sample = len(obs_daily)

  rmse = mean_squared_error(obs_daily, sat_daily, squared=False)
  mae = mean_absolute_error(obs_daily, sat_daily)
  pearsonr = stats.pearsonr(obs_daily, sat_daily)
  spearmanr = stats.spearmanr(obs_daily, sat_daily)
  rsq = r2_score(obs_daily, sat_daily)

  # correlation_matrix = np.corrcoef(obs_daily, sat_daily)
  # correlation_xy = correlation_matrix[0,1]
  # rsq = correlation_xy**2

  bias = sat_daily - obs_daily
  bias = bias.mean()

  obs_daily_bool = obs_daily.copy()
  sat_daily_bool = sat_daily.copy()

  obs_daily_bool[obs_daily_bool < 1] = 0
  obs_daily_bool[obs_daily_bool >= 1] = 1

  sat_daily_bool[sat_daily_bool < 1] = 0
  sat_daily_bool[sat_daily_bool >= 1] = 1

  category = np.empty([n_of_sample])

  for i in range(n_of_sample):
    if obs_daily_bool[i] == 1 and sat_daily_bool[i] == 1:
      category[i] = 1
    elif obs_daily_bool[i] == 1 and sat_daily_bool[i] == 0:
      category[i] = 2
    elif obs_daily_bool[i] == 0 and sat_daily_bool[i] == 1:
      category[i] = 3
    elif obs_daily_bool[i] == 0 and sat_daily_bool[i] == 0:
      category[i] = 4

  hit = np.count_nonzero(category == 1)
  miss = np.count_nonzero(category == 2)
  false_alarm = np.count_nonzero(category == 3)
  correct_negative = np.count_nonzero(category == 4)

  pod = hit/(hit + miss)
  pofd = miss/(miss+correct_negative)
  far = false_alarm/(hit + false_alarm)
  freq_bias = (hit+false_alarm)/(hit+miss)

  daily_metrics_df[station_id].loc['Lat'] = df_obs_metadata['LATITUDE'].loc[station_id]
  daily_metrics_df[station_id].loc['Lon'] = df_obs_metadata['LONGITUDE'].loc[station_id]
  daily_metrics_df[station_id].loc['RMSE'] = round(rmse,2)
  daily_metrics_df[station_id].loc['MAE'] = round(mae,2)
  daily_metrics_df[station_id].loc['Bias'] = round(bias,2)
  daily_metrics_df[station_id].loc['PearsonR'] = round(pearsonr[0],2)
  daily_metrics_df[station_id].loc['SpearmanR'] = round(spearmanr[0],2)
  daily_metrics_df[station_id].loc['R2'] = round(rsq,2)
  daily_metrics_df[station_id].loc['Probability of Detection'] = round(pod,2)
  daily_metrics_df[station_id].loc['Probability of False Detection'] = round(pofd,2)
  daily_metrics_df[station_id].loc['False Alarm Rate'] = round(far,2)
  daily_metrics_df[station_id].loc['Frequency Bias'] = round(freq_bias,2)
                                  
  print(station_id)
  print("Number of Observation: ", n_of_sample)
  print("RMSE: ", str(round(rmse,1)))
  print("MAE: ", str(round(mae,1)))
  print("Bias: ", str(round(bias,1)))
  print("Rsquare: ", str(round(rsq,1)))
  print("Probability of Detection: ", pod)
  print("Probability of False Detection: ", pofd)
  print("False Alarm Rate: ", far)
  print("Frequency Bias: ", freq_bias)


  # # print(obs_daily)
  # # print(sat_daily)

  # # print(obs_daily_bool)
  # # print(sat_daily_bool)
  print(" ")

  # obs_monthly = df_obs_monthly[station_id]
  # sat_monthly = df_sat_monthly[station_id]

  # obs_monthly = obs_monthly.to_numpy()
  # sat_monthly = sat_monthly.to_numpy()

  # print(station, station_id)

daily_metrics_df = daily_metrics_df.T
daily_metrics_df.to_csv('/content/gdrive/MyDrive/rainfall-forecast/verification_validation/metrics/metrics_tamsat_daily_2020.csv')
# Out:
# 0
# TA00073
# Number of Observation:  363
# RMSE:  5.2
# MAE:  2.5
# Bias:  -1.2
# Rsquare:  -0.3
# Probability of Detection:  0.12871287128712872
# Probability of False Detection:  0.27848101265822783
# False Alarm Rate:  0.723404255319149
# Frequency Bias:  0.46534653465346537
#
# 1
# TA00024
# Number of Observation:  363
# RMSE:  7.0
# MAE:  3.1
# Bias:  -1.4
# Rsquare:  -0.4
# Probability of Detection:  0.10091743119266056
# Probability of False Detection:  0.29607250755287007
# False Alarm Rate:  0.65625
# Frequency Bias:  0.29357798165137616
#
# 2
# TA00026
# Number of Observation:  363
# RMSE:  7.8
# MAE:  3.4
# Bias:  -1.0
# Rsquare:  -0.4
# Probability of Detection:  0.14423076923076922
# Probability of False Detection:  0.2908496732026144
# False Alarm Rate:  0.7368421052631579
# Frequency Bias:  0.5480769230769231
#
# 3
# TA00070
# Number of Observation:  362
# RMSE:  10.4
# MAE:  4.4
# Bias:  -2.6
# Rsquare:  -0.2
# Probability of Detection:  0.10084033613445378
# Probability of False Detection:  0.335423197492163
# False Alarm Rate:  0.7209302325581395
# Frequency Bias:  0.36134453781512604
#
# 4
# TA00071
# Number of Observation:  363
# RMSE:  6.9
# MAE:  2.3
# Bias:  0.1
# Rsquare:  -1.1
# Probability of Detection:  0.08163265306122448
# Probability of False Detection:  0.14018691588785046
# False Alarm Rate:  0.9047619047619048
# Frequency Bias:  0.8571428571428571
#
# 5
# 638940-99999
# Number of Observation:  353
# RMSE:  16.2
# MAE:  5.8
# Bias:  -3.1
# Rsquare:  -0.1
# Probability of Detection:  0.3020833333333333
# Probability of False Detection:  0.23674911660777384
# False Alarm Rate:  0.5857142857142857
# Frequency Bias:  0.7291666666666666
#
# 6
# 637290-99999
# Number of Observation:  363
# RMSE:  20.5
# MAE:  9.5
# Bias:  -2.5
# Rsquare:  -0.2
# Probability of Detection:  0.5125
# Probability of False Detection:  0.3611111111111111
# False Alarm Rate:  0.4421768707482993
# Frequency Bias:  0.91875
#
# 7
# 638700-99999
# Number of Observation:  358
# RMSE:  13.2
# MAE:  5.3
# Bias:  -3.6
# Rsquare:  -0.1
# Probability of Detection:  0.2882882882882883
# Probability of False Detection:  0.2696245733788396
# False Alarm Rate:  0.5076923076923077
# Frequency Bias:  0.5855855855855856
#
# 8
# 639710-99999
# Number of Observation:  357
# RMSE:  11.7
# MAE:  4.4
# Bias:  -0.2
# Rsquare:  -0.1
# Probability of Detection:  0.547945205479452
# Probability of False Detection:  0.12222222222222222
# False Alarm Rate:  0.5402298850574713
# Frequency Bias:  1.1917808219178083
#
# 9
# 638620-99999
# Number of Observation:  354
# RMSE:  12.5
# MAE:  3.7
# Bias:  -2.1
# Rsquare:  -0.0
# Probability of Detection:  0.39705882352941174
# Probability of False Detection:  0.1362126245847176
# False Alarm Rate:  0.49056603773584906
# Frequency Bias:  0.7794117647058824
#
# 10
# 638870-99999
# Number of Observation:  357
# RMSE:  9.8
# MAE:  3.2
# Bias:  -1.9
# Rsquare:  0.0
# Probability of Detection:  0.5287356321839081
# Probability of False Detection:  0.14285714285714285
# False Alarm Rate:  0.34285714285714286
# Frequency Bias:  0.8045977011494253
#
# 11
# 637560-99999
# Number of Observation:  353
# RMSE:  8.7
# MAE:  4.3
# Bias:  -1.0
# Rsquare:  -0.2
# Probability of Detection:  0.3577981651376147
# Probability of False Detection:  0.2641509433962264
# False Alarm Rate:  0.5568181818181818
# Frequency Bias:  0.8073394495412844
#
# 12
# 637910-99999
# Number of Observation:  355
# RMSE:  8.8
# MAE:  2.6
# Bias:  -1.4
# Rsquare:  -0.1
# Probability of Detection:  0.13432835820895522
# Probability of False Detection:  0.17901234567901234
# False Alarm Rate:  0.7096774193548387
# Frequency Bias:  0.4626865671641791
#
# 13
# 638810-99999
# Number of Observation:  355
# RMSE:  8.4
# MAE:  3.8
# Bias:  -1.1
# Rsquare:  -0.3
# Probability of Detection:  0.38613861386138615
# Probability of False Detection:  0.21830985915492956
# False Alarm Rate:  0.4507042253521127
# Frequency Bias:  0.7029702970297029
#
# 14
# 638010-99999
# Number of Observation:  351
# RMSE:  14.4
# MAE:  4.5
# Bias:  -1.3
# Rsquare:  -0.0
# Probability of Detection:  0.4148936170212766
# Probability of False Detection:  0.2099236641221374
# False Alarm Rate:  0.5617977528089888
# Frequency Bias:  0.9468085106382979
#
# 15
# 639620-99999
# Number of Observation:  349
# RMSE:  16.1
# MAE:  5.5
# Bias:  -1.9
# Rsquare:  0.0
# Probability of Detection:  0.6133333333333333
# Probability of False Detection:  0.11026615969581749
# False Alarm Rate:  0.46511627906976744
# Frequency Bias:  1.1466666666666667
#
# 16
# 638660-99999
# Number of Observation:  350
# RMSE:  11.7
# MAE:  3.9
# Bias:  -2.1
# Rsquare:  -0.1
# Probability of Detection:  0.3258426966292135
# Probability of False Detection:  0.2097902097902098
# False Alarm Rate:  0.546875
# Frequency Bias:  0.7191011235955056
#
# 17
# 638320-99999
# Number of Observation:  357
# RMSE:  18.5
# MAE:  6.6
# Bias:  -4.4
# Rsquare:  -0.1
# Probability of Detection:  0.27358490566037735
# Probability of False Detection:  0.25163398692810457
# False Alarm Rate:  0.43137254901960786
# Frequency Bias:  0.4811320754716981
#
# 18
# 637330-99999
# Number of Observation:  351
# RMSE:  12.1
# MAE:  4.9
# Bias:  -1.2
# Rsquare:  -0.1
# Probability of Detection:  0.45871559633027525
# Probability of False Detection:  0.23137254901960785
# False Alarm Rate:  0.4791666666666667
# Frequency Bias:  0.8807339449541285
#
# 19
# TA00057
# Number of Observation:  363
# RMSE:  4.1
# MAE:  1.6
# Bias:  0.3
# Rsquare:  -3.1
# Probability of Detection:  0.08771929824561403
# Probability of False Detection:  0.15709969788519637
# False Alarm Rate:  0.84375
# Frequency Bias:  0.5614035087719298
#
# 20
# TA00020
# Number of Observation:  286
# RMSE:  4.0
# MAE:  1.3
# Bias:  0.1
# Rsquare:  -0.7
# Probability of Detection:  0.20588235294117646
# Probability of False Detection:  0.10266159695817491
# False Alarm Rate:  0.6956521739130435
# Frequency Bias:  0.6764705882352942
#
# 21
# 638200-99999
# Number of Observation:  336
# RMSE:  9.4
# MAE:  3.7
# Bias:  -1.9
# Rsquare:  -0.3
# Probability of Detection:  0.09900990099009901
# Probability of False Detection:  0.30333333333333334
# False Alarm Rate:  0.7222222222222222
# Frequency Bias:  0.3564356435643564
#
# 22
# 637170-99999
# Number of Observation:  355
# RMSE:  11.2
# MAE:  4.2
# Bias:  -3.1
# Rsquare:  -0.2
# Probability of Detection:  0.1044776119402985
# Probability of False Detection:  0.37383177570093457
# False Alarm Rate:  0.5882352941176471
# Frequency Bias:  0.2537313432835821
#
# 23
# TA00019
# Number of Observation:  362
# RMSE:  7.7
# MAE:  4.3
# Bias:  -0.1
# Rsquare:  -0.4
# Probability of Detection:  0.4954954954954955
# Probability of False Detection:  0.24888888888888888
# False Alarm Rate:  0.5985401459854015
# Frequency Bias:  1.2342342342342343
#
# 24
# 637930-99999
# Number of Observation:  352
# RMSE:  11.9
# MAE:  3.0
# Bias:  -1.5
# Rsquare:  -0.1
# Probability of Detection:  0.14285714285714285
# Probability of False Detection:  0.1568627450980392
# False Alarm Rate:  0.8260869565217391
# Frequency Bias:  0.8214285714285714
#
# 25
# TA00076
# Number of Observation:  265
# RMSE:  10.6
# MAE:  6.5
# Bias:  -2.0
# Rsquare:  -0.2
# Probability of Detection:  0.5384615384615384
# Probability of False Detection:  0.3829787234042553
# False Alarm Rate:  0.49193548387096775
# Frequency Bias:  1.0598290598290598
#
# 26
# TA00069
# Number of Observation:  274
# RMSE:  7.6
# MAE:  3.0
# Bias:  -1.1
# Rsquare:  -0.3
# Probability of Detection:  0.08
# Probability of False Detection:  0.2827868852459016
# False Alarm Rate:  0.8
# Frequency Bias:  0.4
#
# 27
# TA00074
# Number of Observation:  363
# RMSE:  12.0
# MAE:  3.9
# Bias:  -2.8
# Rsquare:  0.0
# Probability of Detection:  0.1797752808988764
# Probability of False Detection:  0.21987951807228914
# False Alarm Rate:  0.4838709677419355
# Frequency Bias:  0.34831460674157305
#
# 28
# 636610-99999
# Number of Observation:  355
# RMSE:  11.5
# MAE:  6.4
# Bias:  -3.1
# Rsquare:  -0.3
# Probability of Detection:  0.37349397590361444
# Probability of False Detection:  0.4444444444444444
# False Alarm Rate:  0.48760330578512395
# Frequency Bias:  0.7289156626506024
#
# 29
# 637200-99999
# Number of Observation:  344
# RMSE:  13.3
# MAE:  5.1
# Bias:  -3.7
# Rsquare:  -0.2
# Probability of Detection:  0.13675213675213677
# Probability of False Detection:  0.3258064516129032
# False Alarm Rate:  0.5294117647058824
# Frequency Bias:  0.2905982905982906
#
# 30
# 643870-99999
# Number of Observation:  333
# RMSE:  19.9
# MAE:  6.7
# Bias:  -4.0
# Rsquare:  -0.1
# Probability of Detection:  0.14678899082568808
# Probability of False Detection:  0.3240418118466899
# False Alarm Rate:  0.6521739130434783
# Frequency Bias:  0.42201834862385323
#
# 31
# 636950-99999
# Number of Observation:  347
# RMSE:  15.0
# MAE:  5.7
# Bias:  -3.4
# Rsquare:  -0.2
# Probability of Detection:  0.15079365079365079
# Probability of False Detection:  0.34516129032258064
# False Alarm Rate:  0.4864864864864865
# Frequency Bias:  0.29365079365079366
#
# 32
# 637400-99999
# Number of Observation:  325
# RMSE:  7.8
# MAE:  3.0
# Bias:  -1.5
# Rsquare:  -0.2
# Probability of Detection:  0.12195121951219512
# Probability of False Detection:  0.24242424242424243
# False Alarm Rate:  0.6428571428571429
# Frequency Bias:  0.34146341463414637
#
# 33
# TA00056
# Number of Observation:  347
# RMSE:  10.3
# MAE:  3.9
# Bias:  -2.6
# Rsquare:  -0.1
# Probability of Detection:  0.12
# Probability of False Detection:  0.28205128205128205
# False Alarm Rate:  0.6571428571428571
# Frequency Bias:  0.35
#
# 34
# 637140-99999
# Number of Observation:  343
# RMSE:  8.8
# MAE:  4.3
# Bias:  -2.1
# Rsquare:  -0.3
# Probability of Detection:  0.2198581560283688
# Probability of False Detection:  0.38869257950530034
# False Alarm Rate:  0.48333333333333334
# Frequency Bias:  0.425531914893617
#
# 35
# TA00025
# Number of Observation:  363
# RMSE:  7.3
# MAE:  2.2
# Bias:  -0.1
# Rsquare:  -0.4
# Probability of Detection:  0.15217391304347827
# Probability of False Detection:  0.11926605504587157
# False Alarm Rate:  0.8055555555555556
# Frequency Bias:  0.782608695652174
#
# 36
# 643800-99999
# Number of Observation:  318
# RMSE:  11.5
# MAE:  5.8
# Bias:  -0.8
# Rsquare:  -0.7
# Probability of Detection:  0.2578125
# Probability of False Detection:  0.38461538461538464
# False Alarm Rate:  0.5352112676056338
# Frequency Bias:  0.5546875
#
# 37
# 643810-99999
# Number of Observation:  328
# RMSE:  8.5
# MAE:  4.3
# Bias:  0.5
# Rsquare:  -1.7
# Probability of Detection:  0.26956521739130435
# Probability of False Detection:  0.3333333333333333
# False Alarm Rate:  0.5921052631578947
# Frequency Bias:  0.6608695652173913
#
# 38
# TA00033
# Number of Observation:  363
# RMSE:  11.9
# MAE:  6.0
# Bias:  -0.4
# Rsquare:  -0.5
# Probability of Detection:  0.3233082706766917
# Probability of False Detection:  0.37656903765690375
# False Alarm Rate:  0.6532258064516129
# Frequency Bias:  0.9323308270676691
#
# 39
# TA00072
# Number of Observation:  193
# RMSE:  7.7
# MAE:  3.1
# Bias:  -1.6
# Rsquare:  -0.1
# Probability of Detection:  0.22
# Probability of False Detection:  0.22941176470588234
# False Alarm Rate:  0.5217391304347826
# Frequency Bias:  0.46
#
# 40
# 636120-99999
# Number of Observation:  358
# RMSE:  11.0
# MAE:  1.7
# Bias:  -1.2
# Rsquare:  -0.0
# Probability of Detection:  0.09302325581395349
# Probability of False Detection:  0.11641791044776119
# False Alarm Rate:  0.8260869565217391
# Frequency Bias:  0.5348837209302325
#
# 41
# TA00066
# Number of Observation:  208
# RMSE:  5.5
# MAE:  2.2
# Bias:  -1.5
# Rsquare:  -0.3
# Probability of Detection:  0.020833333333333332
# Probability of False Detection:  0.23267326732673269
# False Alarm Rate:  0.8333333333333334
# Frequency Bias:  0.125
#
# 42
# 637990-99999
# Number of Observation:  336
# RMSE:  7.0
# MAE:  2.4
# Bias:  -1.4
# Rsquare:  -0.2
# Probability of Detection:  0.0449438202247191
# Probability of False Detection:  0.2698412698412698
# False Alarm Rate:  0.8095238095238095
# Frequency Bias:  0.23595505617977527
#
# 43
# 637420-99999
# Number of Observation:  320
# RMSE:  10.5
# MAE:  3.6
# Bias:  -1.5
# Rsquare:  -0.2
# Probability of Detection:  0.12
# Probability of False Detection:  0.22758620689655173
# False Alarm Rate:  0.7
# Frequency Bias:  0.4
#
# 44
# TA00023
# Number of Observation:  363
# RMSE:  5.6
# MAE:  1.9
# Bias:  -0.2
# Rsquare:  -0.8
# Probability of Detection:  0.16666666666666666
# Probability of False Detection:  0.10670731707317073
# False Alarm Rate:  0.8
# Frequency Bias:  0.8333333333333334
#
# 45
# TA00031
# Number of Observation:  149
# RMSE:  9.2
# MAE:  5.8
# Bias:  0.5
# Rsquare:  -0.4
# Probability of Detection:  0.6557377049180327
# Probability of False Detection:  0.30434782608695654
# False Alarm Rate:  0.5
# Frequency Bias:  1.3114754098360655
#
# 46
# TA00021
# Number of Observation:  284
# RMSE:  8.6
# MAE:  3.4
# Bias:  -0.4
# Rsquare:  -0.2
# Probability of Detection:  0.23529411764705882
# Probability of False Detection:  0.19117647058823528
# False Alarm Rate:  0.85
# Frequency Bias:  1.5686274509803921
#
# 47
# TA00108
# Number of Observation:  343
# RMSE:  8.3
# MAE:  2.1
# Bias:  -0.8
# Rsquare:  -0.1
# Probability of Detection:  0.21739130434782608
# Probability of False Detection:  0.11650485436893204
# False Alarm Rate:  0.7058823529411765
# Frequency Bias:  0.7391304347826086
#
# 48
# TA00029
# Number of Observation:  363
# RMSE:  5.7
# MAE:  2.9
# Bias:  -0.5
# Rsquare:  -1.8
# Probability of Detection:  0.10897435897435898
# Probability of False Detection:  0.43573667711598746
# False Alarm Rate:  0.6136363636363636
# Frequency Bias:  0.28205128205128205
#
# 49
# TA00130
# Number of Observation:  363
# RMSE:  7.9
# MAE:  1.9
# Bias:  -0.4
# Rsquare:  -0.1
# Probability of Detection:  0.125
# Probability of False Detection:  0.1320754716981132
# False Alarm Rate:  0.8666666666666667
# Frequency Bias:  0.9375
#
# 50
# 636860-99999
# Number of Observation:  338
# RMSE:  10.5
# MAE:  5.5
# Bias:  -2.8
# Rsquare:  -0.1
# Probability of Detection:  0.3706293706293706
# Probability of False Detection:  0.3930131004366812
# False Alarm Rate:  0.5137614678899083
# Frequency Bias:  0.7622377622377622
#
# 51
# TA00133
# Number of Observation:  363
# RMSE:  10.0
# MAE:  3.2
# Bias:  -2.0
# Rsquare:  -0.2
# Probability of Detection:  0.0891089108910891
# Probability of False Detection:  0.27218934911242604
# False Alarm Rate:  0.64
# Frequency Bias:  0.24752475247524752
#
# 52
# TA00155
# Number of Observation:  363
# RMSE:  9.6
# MAE:  2.5
# Bias:  -0.9
# Rsquare:  -0.2
# Probability of Detection:  0.16129032258064516
# Probability of False Detection:  0.15709969788519637
# False Alarm Rate:  0.6875
# Frequency Bias:  0.5161290322580645
#
# 53
# TA00157
# Number of Observation:  363
# RMSE:  9.4
# MAE:  3.0
# Bias:  -1.4
# Rsquare:  -0.2
# Probability of Detection:  0.15789473684210525
# Probability of False Detection:  0.14678899082568808
# False Alarm Rate:  0.75
# Frequency Bias:  0.631578947368421
#
# 54
# TA00140
# Number of Observation:  338
# RMSE:  13.6
# MAE:  6.8
# Bias:  -2.4
# Rsquare:  -0.3
# Probability of Detection:  0.2986111111111111
# Probability of False Detection:  0.42436974789915966
# False Alarm Rate:  0.57
# Frequency Bias:  0.6944444444444444
#
# 55
# 643830-99999
# Number of Observation:  294
# RMSE:  13.9
# MAE:  6.6
# Bias:  -1.0
# Rsquare:  -0.5
# Probability of Detection:  0.256198347107438
# Probability of False Detection:  0.391304347826087
# False Alarm Rate:  0.515625
# Frequency Bias:  0.5289256198347108
#
# 56
# TA00054
# Number of Observation:  136
# RMSE:  11.5
# MAE:  6.4
# Bias:  -1.4
# Rsquare:  -0.6
# Probability of Detection:  0.26
# Probability of False Detection:  0.3854166666666667
# False Alarm Rate:  0.675
# Frequency Bias:  0.8
#
# 57
# 637050-99999
# Number of Observation:  216
# RMSE:  9.3
# MAE:  4.3
# Bias:  1.3
# Rsquare:  -0.9
# Probability of Detection:  0.3902439024390244
# Probability of False Detection:  0.1724137931034483
# False Alarm Rate:  0.7746478873239436
# Frequency Bias:  1.7317073170731707
#
# 58
# 643900-99999
# Number of Observation:  205
# RMSE:  5.9
# MAE:  2.2
# Bias:  1.4
# Rsquare:  -9.2
# Probability of Detection:  0.2857142857142857
# Probability of False Detection:  0.08875739644970414
# False Alarm Rate:  0.8333333333333334
# Frequency Bias:  1.7142857142857142
#
# 59
# TA00134
# Number of Observation:  252
# RMSE:  5.5
# MAE:  2.1
# Bias:  -0.9
# Rsquare:  -0.7
# Probability of Detection:  0.017241379310344827
# Probability of False Detection:  0.2384937238493724
# False Alarm Rate:  0.9230769230769231
# Frequency Bias:  0.22413793103448276
#
# 60
# TA00131
# Number of Observation:  361
# RMSE:  11.1
# MAE:  4.1
# Bias:  -2.9
# Rsquare:  -0.1
# Probability of Detection:  0.07142857142857142
# Probability of False Detection:  0.27492447129909364
# False Alarm Rate:  0.7666666666666667
# Frequency Bias:  0.30612244897959184
#
# 61
# TA00129
# Number of Observation:  363
# RMSE:  4.7
# MAE:  1.7
# Bias:  -0.0
# Rsquare:  -0.7
# Probability of Detection:  0.16
# Probability of False Detection:  0.13166144200626959
# False Alarm Rate:  0.8181818181818182
# Frequency Bias:  0.88
#
# 62
# can-git-gr1.umva
# Number of Observation:  288
# RMSE:  9.3
# MAE:  4.4
# Bias:  -2.6
# Rsquare:  -0.2
# Probability of Detection:  0.1702127659574468
# Probability of False Detection:  0.3046875
# False Alarm Rate:  0.5
# Frequency Bias:  0.3404255319148936
#
# 63
# cub-nta-gr1.umva
# Number of Observation:  299
# RMSE:  8.2
# MAE:  3.9
# Bias:  -1.9
# Rsquare:  -0.4
# Probability of Detection:  0.24242424242424243
# Probability of False Detection:  0.28957528957528955
# False Alarm Rate:  0.4
# Frequency Bias:  0.40404040404040403
#
# 64
# gas-mbu-gr3.umva
# Number of Observation:  301
# RMSE:  8.1
# MAE:  3.7
# Bias:  -1.8
# Rsquare:  -0.3
# Probability of Detection:  0.22916666666666666
# Probability of False Detection:  0.2857142857142857
# False Alarm Rate:  0.47619047619047616
# Frequency Bias:  0.4375
#
# 65
# gat-gat-gr3.umva
# Number of Observation:  310
# RMSE:  8.3
# MAE:  3.9
# Bias:  -1.8
# Rsquare:  -0.4
# Probability of Detection:  0.22857142857142856
# Probability of False Detection:  0.2977941176470588
# False Alarm Rate:  0.3684210526315789
# Frequency Bias:  0.3619047619047619
#
# 66
# git-git-gr1.umva
# Number of Observation:  283
# RMSE:  9.3
# MAE:  4.4
# Bias:  -2.2
# Rsquare:  -0.3
# Probability of Detection:  0.15730337078651685
# Probability of False Detection:  0.3
# False Alarm Rate:  0.5757575757575758
# Frequency Bias:  0.3707865168539326
#
# 67
# git-kuw-gr1.umva
# Number of Observation:  282
# RMSE:  12.2
# MAE:  6.2
# Bias:  -4.1
# Rsquare:  -0.3
# Probability of Detection:  0.14736842105263157
# Probability of False Detection:  0.324
# False Alarm Rate:  0.5625
# Frequency Bias:  0.3368421052631579
#
# 68
# git-muh-gr1.umva
# Number of Observation:  279
# RMSE:  11.9
# MAE:  6.0
# Bias:  -4.1
# Rsquare:  -0.3
# Probability of Detection:  0.12903225806451613
# Probability of False Detection:  0.324
# False Alarm Rate:  0.5862068965517241
# Frequency Bias:  0.3118279569892473
#
# 69
# kaj-kaj-gr1.umva
# Number of Observation:  299
# RMSE:  9.6
# MAE:  4.4
# Bias:  -2.2
# Rsquare:  -0.3
# Probability of Detection:  0.1717171717171717
# Probability of False Detection:  0.311787072243346
# False Alarm Rate:  0.5277777777777778
# Frequency Bias:  0.36363636363636365
#
# 70
# kan-mak-gr1.umva
# Number of Observation:  289
# RMSE:  9.4
# MAE:  4.7
# Bias:  -2.9
# Rsquare:  -0.3
# Probability of Detection:  0.1346153846153846
# Probability of False Detection:  0.35019455252918286
# False Alarm Rate:  0.5625
# Frequency Bias:  0.3076923076923077
#
# 71
# kar-karu-gr2.umva
# Number of Observation:  297
# RMSE:  10.5
# MAE:  4.6
# Bias:  -2.4
# Rsquare:  -0.2
# Probability of Detection:  0.2261904761904762
# Probability of False Detection:  0.2559055118110236
# False Alarm Rate:  0.5581395348837209
# Frequency Bias:  0.5119047619047619
#
# 72
# kav-kir-gr2.umva
# Number of Observation:  290
# RMSE:  8.9
# MAE:  4.2
# Bias:  -2.4
# Rsquare:  -0.3
# Probability of Detection:  0.18888888888888888
# Probability of False Detection:  0.28294573643410853
# False Alarm Rate:  0.46875
# Frequency Bias:  0.35555555555555557
#
# 73
# kav-mun-gr1.umva
# Number of Observation:  314
# RMSE:  9.1
# MAE:  4.8
# Bias:  -2.5
# Rsquare:  -0.4
# Probability of Detection:  0.26811594202898553
# Probability of False Detection:  0.38257575757575757
# False Alarm Rate:  0.26
# Frequency Bias:  0.36231884057971014
#
# 74
# kiv-nam-gr1.umva
# Number of Observation:  289
# RMSE:  9.6
# MAE:  4.5
# Bias:  -2.6
# Rsquare:  -0.3
# Probability of Detection:  0.16346153846153846
# Probability of False Detection:  0.3359073359073359
# False Alarm Rate:  0.43333333333333335
# Frequency Bias:  0.28846153846153844
#
# 75
# maga-mag-gr1.umva
# Number of Observation:  302
# RMSE:  8.9
# MAE:  4.4
# Bias:  -2.5
# Rsquare:  -0.2
# Probability of Detection:  0.23809523809523808
# Probability of False Detection:  0.311284046692607
# False Alarm Rate:  0.4444444444444444
# Frequency Bias:  0.42857142857142855
#
# 76
# mas-nya-gr1.umva
# Number of Observation:  306
# RMSE:  10.6
# MAE:  5.1
# Bias:  -3.0
# Rsquare:  -0.3
# Probability of Detection:  0.19469026548672566
# Probability of False Detection:  0.33955223880597013
# False Alarm Rate:  0.42105263157894735
# Frequency Bias:  0.336283185840708
#
# 77
# may-may-gr2.umva
# Number of Observation:  293
# RMSE:  7.9
# MAE:  3.8
# Bias:  -1.6
# Rsquare:  -0.4
# Probability of Detection:  0.22916666666666666
# Probability of False Detection:  0.29838709677419356
# False Alarm Rate:  0.5111111111111111
# Frequency Bias:  0.46875
#
# 78
# mug-mugo-gr2.umva
# Number of Observation:  243
# RMSE:  8.7
# MAE:  3.5
# Bias:  -2.1
# Rsquare:  -0.1
# Probability of Detection:  0.24242424242424243
# Probability of False Detection:  0.23809523809523808
# False Alarm Rate:  0.5151515151515151
# Frequency Bias:  0.5
#
# 79
# mug-nta-gr3.umva
# Number of Observation:  304
# RMSE:  10.1
# MAE:  4.5
# Bias:  -2.8
# Rsquare:  -0.2
# Probability of Detection:  0.24
# Probability of False Detection:  0.2923076923076923
# False Alarm Rate:  0.45454545454545453
# Frequency Bias:  0.44
#
# 80
# mug-rus-gr2.umva
# Number of Observation:  244
# RMSE:  10.1
# MAE:  4.1
# Bias:  -2.6
# Rsquare:  -0.1
# Probability of Detection:  0.23880597014925373
# Probability of False Detection:  0.24285714285714285
# False Alarm Rate:  0.5294117647058824
# Frequency Bias:  0.5074626865671642
#
# 81
# muhw-muh-gr1.umva
# Number of Observation:  297
# RMSE:  11.7
# MAE:  5.2
# Bias:  -3.1
# Rsquare:  -0.3
# Probability of Detection:  0.1978021978021978
# Probability of False Detection:  0.28294573643410853
# False Alarm Rate:  0.5384615384615384
# Frequency Bias:  0.42857142857142855
#
# 82
# mun-mun-gr2.umva
# Number of Observation:  292
# RMSE:  9.2
# MAE:  4.6
# Bias:  -2.6
# Rsquare:  -0.4
# Probability of Detection:  0.1388888888888889
# Probability of False Detection:  0.3590733590733591
# False Alarm Rate:  0.5454545454545454
# Frequency Bias:  0.3055555555555556
#
# 83
# mut-mak-gr2.umva
# Number of Observation:  291
# RMSE:  11.4
# MAE:  6.1
# Bias:  -3.6
# Rsquare:  -0.5
# Probability of Detection:  0.14285714285714285
# Probability of False Detection:  0.37065637065637064
# False Alarm Rate:  0.5
# Frequency Bias:  0.2857142857142857
#
# 84
# ngu-nya-gr3.umva
# Number of Observation:  307
# RMSE:  8.9
# MAE:  4.4
# Bias:  -2.5
# Rsquare:  -0.4
# Probability of Detection:  0.2018348623853211
# Probability of False Detection:  0.31985294117647056
# False Alarm Rate:  0.37142857142857144
# Frequency Bias:  0.3211009174311927
#
# 85
# nyabi-ny-gr1.umva
# Number of Observation:  288
# RMSE:  9.4
# MAE:  4.6
# Bias:  -2.6
# Rsquare:  -0.4
# Probability of Detection:  0.1348314606741573
# Probability of False Detection:  0.29844961240310075
# False Alarm Rate:  0.6
# Frequency Bias:  0.33707865168539325
#
# 86
# nya-mun-gr1.umva
# Number of Observation:  291
# RMSE:  9.3
# MAE:  4.6
# Bias:  -2.7
# Rsquare:  -0.4
# Probability of Detection:  0.12903225806451613
# Probability of False Detection:  0.3103448275862069
# False Alarm Rate:  0.6
# Frequency Bias:  0.3225806451612903
#
# 87
# nye-nzo-gr1.umva
# Number of Observation:  306
# RMSE:  10.3
# MAE:  4.8
# Bias:  -2.6
# Rsquare:  -0.3
# Probability of Detection:  0.2
# Probability of False Detection:  0.29739776951672864
# False Alarm Rate:  0.4594594594594595
# Frequency Bias:  0.37
#
# 88
# ny-nyagi-gr1.umva
# Number of Observation:  295
# RMSE:  11.1
# MAE:  5.9
# Bias:  -3.3
# Rsquare:  -0.5
# Probability of Detection:  0.15447154471544716
# Probability of False Detection:  0.4015444015444015
# False Alarm Rate:  0.4722222222222222
# Frequency Bias:  0.2926829268292683
#
# 89
# nzi-mas-gr1.umva
# Number of Observation:  306
# RMSE:  9.9
# MAE:  4.9
# Bias:  -3.0
# Rsquare:  -0.2
# Probability of Detection:  0.22522522522522523
# Probability of False Detection:  0.3282442748091603
# False Alarm Rate:  0.4318181818181818
# Frequency Bias:  0.3963963963963964
#
# 90
# rem-muy-gr1.umva
# Number of Observation:  290
# RMSE:  11.4
# MAE:  6.1
# Bias:  -3.4
# Rsquare:  -0.5
# Probability of Detection:  0.1953125
# Probability of False Detection:  0.4153225806451613
# False Alarm Rate:  0.40476190476190477
# Frequency Bias:  0.328125
#
# 91
# rug-kiv-gr1.umva
# Number of Observation:  305
# RMSE:  9.1
# MAE:  4.2
# Bias:  -1.8
# Rsquare:  -0.3
# Probability of Detection:  0.23655913978494625
# Probability of False Detection:  0.27099236641221375
# False Alarm Rate:  0.4883720930232558
# Frequency Bias:  0.46236559139784944
#
# 92
# rug-rug-gr2.umva
# Number of Observation:  303
# RMSE:  11.1
# MAE:  4.5
# Bias:  -2.8
# Rsquare:  -0.2
# Probability of Detection:  0.2692307692307692
# Probability of False Detection:  0.2900763358778626
# False Alarm Rate:  0.3170731707317073
# Frequency Bias:  0.3942307692307692
#
# 93
# ruh-ruh-gr1.umva
# Number of Observation:  282
# RMSE:  8.8
# MAE:  4.3
# Bias:  -2.1
# Rsquare:  -0.5
# Probability of Detection:  0.13978494623655913
# Probability of False Detection:  0.321285140562249
# False Alarm Rate:  0.6060606060606061
# Frequency Bias:  0.3548387096774194
#
# 94
# rwa-bug-gr1.umva
# Number of Observation:  292
# RMSE:  9.7
# MAE:  5.0
# Bias:  -3.0
# Rsquare:  -0.5
# Probability of Detection:  0.1559633027522936
# Probability of False Detection:  0.34980988593155893
# False Alarm Rate:  0.41379310344827586
# Frequency Bias:  0.26605504587155965
#
# 95
# rwa-tab-gr3.umva
# Number of Observation:  302
# RMSE:  9.9
# MAE:  4.4
# Bias:  -2.5
# Rsquare:  -0.3
# Probability of Detection:  0.19607843137254902
# Probability of False Detection:  0.3048327137546468
# False Alarm Rate:  0.3939393939393939
# Frequency Bias:  0.3235294117647059
#
# 96
# sha-sha-gr1.umva
# Number of Observation:  309
# RMSE:  10.3
# MAE:  4.7
# Bias:  -2.8
# Rsquare:  -0.2
# Probability of Detection:  0.21875
# Probability of False Detection:  0.2819548872180451
# False Alarm Rate:  0.5116279069767442
# Frequency Bias:  0.4479166666666667
#
# 97
# shi-rur-gr1.umva
# Number of Observation:  287
# RMSE:  10.0
# MAE:  4.6
# Bias:  -2.9
# Rsquare:  -0.1
# Probability of Detection:  0.20652173913043478
# Probability of False Detection:  0.2885375494071146
# False Alarm Rate:  0.4411764705882353
# Frequency Bias:  0.3695652173913043
#
# 98
# tab-tab-gr3.umva
# Number of Observation:  300
# RMSE:  8.4
# MAE:  4.0
# Bias:  -2.2
# Rsquare:  -0.3
# Probability of Detection:  0.22340425531914893
# Probability of False Detection:  0.27547169811320754
# False Alarm Rate:  0.4
# Frequency Bias:  0.3723404255319149
#
# 99
# tem-rus-gr5.umva
# Number of Observation:  305
# RMSE:  9.1
# MAE:  4.4
# Bias:  -2.6
# Rsquare:  -0.3
# Probability of Detection:  0.23404255319148937
# Probability of False Detection:  0.2696629213483146
# False Alarm Rate:  0.42105263157894735
# Frequency Bias:  0.40425531914893614
#
# 100
# yanz-kig-gr3.umva
# Number of Observation:  296
# RMSE:  10.9
# MAE:  5.6
# Bias:  -3.5
# Rsquare:  -0.4
# Probability of Detection:  0.15315315315315314
# Probability of False Detection:  0.36015325670498083
# False Alarm Rate:  0.5142857142857142
# Frequency Bias:  0.3153153153153153
#
# 101
# muh-gah-gr1.umva
# Number of Observation:  288
# RMSE:  9.2
# MAE:  4.4
# Bias:  -1.3
# Rsquare:  -0.2
# Probability of Detection:  0.3944954128440367
# Probability of False Detection:  0.30985915492957744
# False Alarm Rate:  0.4266666666666667
# Frequency Bias:  0.6880733944954128
