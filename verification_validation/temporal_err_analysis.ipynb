# %%
import netCDF4 as nc
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import numpy.ma as ma
import os
import joblib
import xarray as xr
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
data = pd.read_csv('/content/drive/MyDrive/rainfall-forecast/verification_validation/final_station_data_daily_v2_imerg.csv')

# %%
data
# Out:
#       Unnamed: 0  TA00073  ...  yanz-kig-gr3.umva  muh-gah-gr1.umva
# 0     2016-01-01      0.0  ...                NaN               NaN
# 1     2016-01-02      0.0  ...                NaN               NaN
# 2     2016-01-03      0.0  ...                NaN               NaN
# 3     2016-01-04      0.0  ...                NaN               NaN
# 4     2016-01-05      0.8  ...                NaN               NaN
# ...          ...      ...  ...                ...               ...
# 1822  2020-12-27      0.1  ...                NaN               NaN
# 1823  2020-12-28      0.0  ...                NaN               NaN
# 1824  2020-12-29      0.1  ...                NaN               NaN
# 1825  2020-12-30      2.9  ...                NaN               NaN
# 1826  2020-12-31     14.5  ...                NaN               NaN
#
# [1827 rows x 104 columns]
